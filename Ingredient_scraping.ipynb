# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvalofek/Ingredient-Recommendation/blob/main/Ingredient_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generating a ingredient pair dataset from The Food Bible book:
# Referenced:
# https://andrew-muller.medium.com/getting-text-from-epub-files-in-python-fbfe5df5c2da

# %% [markdown]
# I found an epub version of the book which I use for this scraping. I am assuming it is uploaded and the path to it is stored in the PATH variable down below.

# %%
# !pip install ebooklib
# Out:
# Requirement already satisfied: ebooklib in /usr/local/lib/python3.7/dist-packages (0.17.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from ebooklib) (1.15.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from ebooklib) (4.2.6)

# %%
import ebooklib
from ebooklib import epub
from bs4 import BeautifulSoup
from collections import defaultdict
import re
import random

from pprint import pprint
import sqlite3

# %%
PATH = '/content/flavorbible.epub'
food_bible = epub.read_epub(PATH)

# %%
chap_content = {}
# chapter 3 has all the ingredient pairing, so we go in and get the content for 
# everything with 3 in the chapter name
for item in food_bible.get_items_of_type(ebooklib.ITEM_DOCUMENT):
  name =item.get_name() 
  if '3' in name:
    chap_content[name] = BeautifulSoup(item.get_content(), 'html.parser')

# %% [markdown]
# Some notation the book uses:
# <p class="btx1">KEY: Flavors mentioned in regular type are pairings suggested by one or more experts.</p>
# <p class="btx1">Those in <strong>bold</strong> were recommended by a number of experts.</p>
# <p class="btx1">Those in <strong>BOLD CAPS</strong> were very highly recommended by an even greater number of experts.</p>
# <p class="btx13">Those in *<strong>BOLD CAPS</strong> with an asterisk (*) are “Holy Grail” pairings that are the most highly recommended by the greatest number of experts.</p>

# %% [markdown]
# ## Setting the goals
# Now that we have the data in a convenient form, we set some goals for the scrape:
# Each edge should be given a number, indicating the strength of that connection as described in the KEY above.
# I assign:
# * Regular pairing - 1
# * Bold pairing - 2
# * Bold & capitalized - 3
# * Bold, capitalized, and asterisk - 5 (to bump it to a quantity of a "Holy Grail")
#
# At the end of the scrape, we want to generate a bidirectional graph with weighted connections. For convenince, I think I will store this as a list of tuples in the form: (ingredient 1, ingredient 2, weight of connections)

# %% [markdown]
# ## Weighing function

# %%
# Functions to capture the different keys:
def weigh_edge(text):
  """ 
  Check conditions for the input text to see where it falls in the key
  """
  try:
    if '*' in text:
      # Asterisk --> Holy grail
      return 5
    if text.lower() != text:
      # Capitalized --> 3
      return 3
    if 'strong' in text.lower():
      # Bolded
      return 2
  except AttributeError:
    None
  return 1

# %%
# Test weigh_edge:
# normal 
print(weigh_edge('milk'))

## Only bolded -- 2
print(weigh_edge('<strong>bananas</strong>'))

## Bold and cap - 3
print(weigh_edge('<strong>BEEF,</strong>'))

## Holy grail - 5
print(weigh_edge('<strong>*PORK</strong>'))


# list - 1
print(weigh_edge(['apples','ginger','lemon','quince','sugar']))
# Out:
# 1
# 2
# 3
# 5
# 1

# %% [markdown]
# ## Initial scrape
# Turns out the fomratting is not consistent and sometimes we get 'ul' that are meant to be the header

# %% [markdown]
# ### We also need a way to get rid of the variable length - complex pairs
# To do this we create a dict whose entries are (ingredient, next key). This allows us to create a singly-linked list build inside a dict object, which therefore allows for variable length sequences to be stored.
#
# If a next key does not exist, we store a None in the next_key to indicate the sequence is over.

# %%
def chain_pairings(key, pair_list, pair_dict, used_keys):
  if len(pair_list)==1:
    pair_dict[key] = ((pair_list[0], None))
    return
  
  # get a key that wasn't used before and add it to used keys... not ideal but its something
  new_key = random.randint(0, 2**16)
  while new_key in used_keys:
    new_key = random.randint(0, 2**16)
  used_keys.add(new_key)

  # Chain the rest of the list
  pair_dict[key] = (pair_list[0], new_key)
  chain_pairings(new_key, pair_list[1:], pair_dict, used_keys)

# %%
def scrape_chapter(chapter, pairings, current_ingredient,variable_pairings, used_keys):  
  new = 2
  description_words = ['Season', 'Weight', 'Volume', 'Techniques'] ## Words used to describe current inggredient
  for tag in chapter.find_all('p'):
    class_name = tag.get('class')
    if class_name is not None:
      formatted_class = class_name[0].strip().lower()
      if formatted_class == 'lh1' or formatted_class == 'lh':
        # If this is the ingredient header, start a new entry in the dict and update
        # current ingredient
        current_ingredient = tag.get_text().lower().strip()
        new = 0
      elif formatted_class == 'ul':
        ingredient = tag.get_text().strip()

        if ':' in ingredient:
          # Noticed descriptions for the ingredients were also labeled ul, but they 
          # where followed by a : so we use that to ignore them. 
          continue
        
        # get edge weight
        weight = weigh_edge(ingredient)      
        
        ing_split_plus = ingredient.split('+')
        if len(ing_split_plus) > 1:
          # for more than pair ingredient combinations
          ingredient = [ing.strip() for ing in ing_split_plus]
          key = random.randint(0, 2**16)
          used_keys.add(key)
          chain_pairings(key, ingredient, variable_pairings, used_keys)
          ingredient = str(key)

        else: 
          # Drop astericks if they are there - helps make data uniform
          ingredient = re.sub('\*', '', ingredient).lower()
        
        if ingredient is None or ingredient == '':
          # If we get none of empty string, don't add to dict
          continue
        
        pairings.append((current_ingredient, ingredient, weight))
        new +=1
  return pairings, current_ingredient

# %%
# Test
pairings = list()
variable_pairings = dict()
used_keys = set()
current_ingredient = None
pairings, current_ingredient = scrape_chapter(chap_content['Text/FlavorBible_chap-3a.html'],
                                              pairings, current_ingredient,
                                              variable_pairings, used_keys)
pprint(pairings)
# Out:
# [('achiote seeds', 'beef', 1),
#  ('achiote seeds', 'chicken', 1),
#  ('achiote seeds', 'chiles', 1),
#  ('achiote seeds', 'citrus (e.g., sour orange)', 1),
#  ('achiote seeds', 'fish', 1),
#  ('achiote seeds', 'game birds (e.g., duck, quail)', 1),
#  ('achiote seeds', 'garlic', 1),
#  ('achiote seeds', 'mexican cuisine, esp. yucatán oil', 3),
#  ('achiote seeds', 'pork', 1),
#  ('achiote seeds', 'shellfish, e.g., lobster, shrimp', 1),
#  ('achiote seeds', 'shrimp', 1),
#  ('achiote seeds', '10644', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'almonds', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'barley', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'breads', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'cardamom', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'chile pepper', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'cinnamon', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'cloves', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'coriander', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'cucumber', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'cumin', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'dill', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'fennel', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'fruits, esp. dried', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'ginger', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'grapes', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'kebabs', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'lamb', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'mint', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'mushrooms', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'nuts, e.g., almonds', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'pasta', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'rice, basmati', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'sesame', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'tomatoes and tomato sauce', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'turmeric', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'yogurt', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', '63373', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', '10634', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'bananas', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'bell peppers',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'braised dishes',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'chicken', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'chile peppers, esp. west african',
#   3),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'coconuts', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'corn', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'fish, esp. coastal',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'fruits, esp. tropical',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'garlic', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'goat', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'greens, esp. steamed or stewed',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'mangoes', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'melons', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'okra', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'onions', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'papayas', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'peanuts', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'peas, esp. black-eyed',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'plantains', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'soups', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'stews, esp. meat or vegetable',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'sweet potatoes',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'tomatoes', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'watermelon',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'yams, esp. west african',
#   3),
#  ('african cuisine (north) (see also moroccan cuisine)', 'bell peppers', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'braised dishes', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'chicken', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'chickpeas', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'couscous', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'cucumbers', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'cumin', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'eggplant', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'fish', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'garlic', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'lamb', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'mint', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'parsley', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'rice', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'stewed dishes', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'tomatoes', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'wheat', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', '9820', 3),
#  ('african cuisine (south)', 'beans', 1),
#  ('african cuisine (south)', 'carrots', 1),
#  ('african cuisine (south)', 'chile peppers', 1),
#  ('african cuisine (south)', 'cinnamon', 1),
#  ('african cuisine (south)', 'cloves', 1),
#  ('african cuisine (south)', 'fenugreek', 1),
#  ('african cuisine (south)', 'garlic', 1),
#  ('african cuisine (south)', 'ginger', 1),
#  ('african cuisine (south)', 'lamb', 1),
#  ('african cuisine (south)', 'onions', 1),
#  ('african cuisine (south)', 'peas', 1),
#  ('african cuisine (south)', 'pumpkin', 1),
#  ('african cuisine (south)', 'stews', 1),
#  ('african cuisine (south)', 'tomatoes', 1),
#  ('african cuisine (south)', 'turmeric', 1),
#  ('african cuisine (south)', '29068', 1),
#  ('african cuisine (west)', 'bananas', 1),
#  ('african cuisine (west)', 'bell peppers', 1),
#  ('african cuisine (west)', 'braised dishes', 1),
#  ('african cuisine (west)', 'chicken', 1),
#  ('african cuisine (west)', 'chile peppers', 1),
#  ('african cuisine (west)', 'corn', 1),
#  ('african cuisine (west)', 'goat', 1),
#  ('african cuisine (west)', 'mangoes', 1),
#  ('african cuisine (west)', 'okra', 1),
#  ('african cuisine (west)', 'papayas', 1),
#  ('african cuisine (west)', 'peanuts', 1),
#  ('african cuisine (west)', 'plantains', 1),
#  ('african cuisine (west)', 'rice', 1),
#  ('african cuisine (west)', 'soups', 1),
#  ('african cuisine (west)', 'stewed dishes', 1),
#  ('african cuisine (west)', 'sweet potatoes', 1),
#  ('african cuisine (west)', 'tomatoes', 1),
#  ('african cuisine (west)', 'wheat', 1),
#  ('african cuisine (west)', 'yams', 1),
#  ('african cuisine (west)', '41026', 1),
#  ('allspice', 'baked goods', 1),
#  ('allspice', 'beans', 1),
#  ('allspice',
#   'beef, esp. braised, corned, grilled, ground, raw, roasted, or stewed',
#   3),
#  ('allspice', 'beets', 1),
#  ('allspice', 'breads, esp. breakfast', 1),
#  ('allspice', 'cabbage', 1),
#  ('allspice', 'cakes', 1),
#  ('allspice', 'caribbean cuisine', 3),
#  ('allspice', 'carrots', 1),
#  ('allspice', 'chicken (e.g., jamaican style)', 3),
#  ('allspice', 'chickpeas', 1),
#  ('allspice', 'chile peppers', 1),
#  ('allspice', 'cinnamon', 1),
#  ('allspice', 'cloves', 1),
#  ('allspice', 'cookies', 1),
#  ('allspice', 'coriander', 1),
#  ('allspice', 'currants, esp. black', 1),
#  ('allspice', 'curries and curry powder', 1),
#  ('allspice', 'eastern mediterranean cuisine', 3),
#  ('allspice', 'eggplant', 1),
#  ('allspice', 'english cuisine', 3),
#  ('allspice', 'fish, esp. grilled', 1),
#  ('allspice', 'fruits, fruit compotes, and jams', 1),
#  ('allspice', 'game and game birds (e.g., quail)', 1),
#  ('allspice', 'garlic', 1),
#  ('allspice', 'ginger', 1),
#  ('allspice', 'goat', 1),
#  ('allspice', 'grains', 1),
#  ('allspice', 'ham', 1),
#  ('allspice', 'herring, pickled', 1),
#  ('allspice', 'indian cuisine', 3),
#  ('allspice', 'jamaican cuisine (e.g., jerk dishes)', 3),
#  ('allspice', 'ketchup', 1),
#  ('allspice', 'lamb', 1),
#  ('allspice', 'mace', 1),
#  ('allspice', 'meats, red, esp. braised, grilled, or roasted', 3),
#  ('allspice', 'mexican cuisine', 3),
#  ('allspice', 'middle eastern cuisine', 3),
#  ('allspice', 'mushrooms', 1),
#  ('allspice', 'mustard', 1),
#  ('allspice', 'north american cuisine', 3),
#  ('allspice', 'nutmeg', 1),
#  ('allspice', 'nuts', 1),
#  ('allspice', 'onions', 1),
#  ('allspice', 'pepper, black', 1),
#  ('allspice', 'pies', 1),
#  ('allspice', 'pineapple', 1),
#  ('allspice', 'pork', 1),
#  ('allspice', 'pumpkin', 3),
#  ('allspice', 'rabbit', 1),
#  ('allspice', 'rice', 1),
#  ('allspice', 'rosemary', 1),
#  ('allspice', 'salsas and sauces', 1),
#  ('allspice', 'sauerkraut', 1),
#  ('allspice', 'sausages', 1),
#  ('allspice', 'soups', 1),
#  ('allspice', 'spiced cakes', 1),
#  ('allspice', 'spinach', 1),
#  ('allspice', 'squash, winter', 1),
#  ('allspice', 'stews', 1),
#  ('allspice', 'stocks and broths, chicken', 1),
#  ('allspice', 'sweet potatoes', 1),
#  ('allspice', 'thyme', 1),
#  ('allspice', 'tomatoes', 1),
#  ('allspice', 'turnips', 1),
#  ('allspice', 'vegetables, esp. root', 1),
#  ('allspice', 'west indies cuisine', 3),
#  ('allspice', '6964', 1),
#  ('allspice', '51044', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'amaretto', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'anise, esp. green', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'apples', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'apricots', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'beans', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'blackberries', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'brandy', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'butter, unsalted', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'butterscotch', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'caramel', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cardamom', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cayenne', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cherries, esp. sour', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'chicken', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'chocolate, white', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cinnamon', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'coconut', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'coffee', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cornmeal', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'corn syrup', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'crab', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cranberries', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cream', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cream cheese', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'crème fraîche', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'currants', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'figs', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'fish', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'french pastries', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'fruits, most', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'garlic', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'grapes', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'greek cuisine', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'greens, salad', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'hazelnuts', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'honey', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'ice cream', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'indian cuisine', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'italian sauces', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'lamb', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'lavender', 1),
#  ('almond oil (see oil, almond)\r\n  almonds',
#   'liqueurs, fruit (including orange)',
#   1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'mascarpone', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'mediterranean cuisine', 3),
#  ('almond oil (see oil, almond)\r\n  almonds',
#   'mexican beverages and mole sauces',
#   3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'milk, sweetened condensed', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'molasses', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'moroccan cuisine', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'nectarines', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'oats', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'olive oil', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'olives', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'paprika', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'passion fruit', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'peaches', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'pears', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'pecans', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'pepper, ground', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'pine nuts', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'plums', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'praline', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'prunes', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'quince', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'raisins, esp. white', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'raspberries', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'rhubarb', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'rice', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'rosemary', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'rum', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'shellfish', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'sherry', 1),
#  ('almond oil (see oil, almond)\r\n  almonds',
#   'spanish cuisine, esp. sauces',
#   3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'strawberries', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'tea', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'turkish cuisine', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'vanilla', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'walnuts', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', '44872', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', '60445', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', '12141', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', '51802', 1),
#  ('amaretto (sweet almond liqueur)', 'almonds', 1),
#  ('amaretto (sweet almond liqueur)', 'apricots', 1),
#  ('amaretto (sweet almond liqueur)', 'butter', 1),
#  ('amaretto (sweet almond liqueur)', 'cherries', 1),
#  ('amaretto (sweet almond liqueur)', 'chocolate', 1),
#  ('amaretto (sweet almond liqueur)', 'coffee', 1),
#  ('amaretto (sweet almond liqueur)', 'cream', 1),
#  ('amaretto (sweet almond liqueur)', 'hazelnuts', 1),
#  ('amaretto (sweet almond liqueur)', 'italian cuisine', 3),
#  ('amaretto (sweet almond liqueur)', 'peaches', 1),
#  ('amaretto (sweet almond liqueur)', 'pork', 1),
#  ('amaretto (sweet almond liqueur)', 'sugar', 1),
#  ('anchovies', 'almonds', 1),
#  ('anchovies', 'basil', 1),
#  ('anchovies', 'beans, green', 1),
#  ('anchovies', 'bell peppers, esp. roasted', 1),
#  ('anchovies', 'capers', 1),
#  ('anchovies', 'carrots', 1),
#  ('anchovies', 'cauliflower', 1),
#  ('anchovies', 'celery', 1),
#  ('anchovies', 'chives', 1),
#  ('anchovies', 'eggs, hard-boiled', 1),
#  ('anchovies', 'fennel', 1),
#  ('anchovies', 'garlic', 3),
#  ('anchovies', 'lemon, juice', 1),
#  ('anchovies', 'lobster', 1),
#  ('anchovies', 'mayonnaise', 1),
#  ('anchovies', 'mediterranean cuisine', 3),
#  ('anchovies', 'mustard (e.g., dijon)', 3),
#  ('anchovies', 'nectarines', 1),
#  ('anchovies', 'olive oil', 3),
#  ('anchovies', 'olives (e.g., black, green, niçoise)', 1),
#  ('anchovies', 'onions', 1),
#  ('anchovies', 'orange, zest', 1),
#  ('anchovies', 'parsley, flat-leaf', 1),
#  ('anchovies', 'pasta', 1),
#  ('anchovies', 'peppers, piquillo', 1),
#  ('anchovies', 'pizza', 1),
#  ('anchovies', 'potatoes', 1),
#  ('anchovies', 'puttanesca sauce (key ingredient)', 1),
#  ('anchovies', 'red pepper flakes', 1),
#  ('anchovies', 'romaine lettuce', 1),
#  ('anchovies', 'rosemary', 1),
#  ('anchovies', 'salads, esp. caesar (key ingredient)', 3),
#  ('anchovies', 'salmon', 1),
#  ('anchovies', 'shallots', 1),
#  ('anchovies', 'sherry, px', 3),
#  ('anchovies', 'tapenade (key ingredient)', 1),
#  ('anchovies', 'thyme', 1),
#  ('anchovies', 'tomatoes', 1),
#  ('anchovies', 'tuna', 1),
#  ('anchovies', '42072', 1),
#  ('angelica', 'anise', 1),
#  ('angelica', 'apricots', 1),
#  ('angelica', 'candy', 1),
#  ('angelica', 'cream and ice cream', 1),
#  ('angelica', 'custards', 1),
#  ('angelica', 'desserts', 1),
#  ('angelica', 'fish', 1),
#  ('angelica', 'fruits', 1),
#  ('angelica', 'hazelnuts', 1),
#  ('angelica', 'juniper berries', 1),
#  ('angelica', 'lavender', 1),
#  ('angelica', 'lemon balm', 1),
#  ('angelica', 'liqueurs', 1),
#  ('angelica', 'mushrooms', 1),
#  ('angelica', 'oranges', 1),
#  ('angelica', 'pepper, black', 1),
#  ('angelica', 'plums', 1),
#  ('angelica', 'rhubarb', 5),
#  ('angelica', 'salads', 1),
#  ('angelica', 'shellfish', 1),
#  ('angelica', 'strawberries', 1),
#  ('angelica', '17564', 1),
#  ('anise (see also anise, star, and fennel)', 'almonds', 1),
#  ('anise (see also anise, star, and fennel)', 'apples', 1),
#  ('anise (see also anise, star, and fennel)',
#   'baked goods, esp. cakes, cookies',
#   1),
#  ('anise (see also anise, star, and fennel)', 'beets', 1),
#  ('anise (see also anise, star, and fennel)', 'breads, esp. rye', 1),
#  ('anise (see also anise, star, and fennel)', 'cabbage', 1),
#  ('anise (see also anise, star, and fennel)', 'cakes', 1),
#  ('anise (see also anise, star, and fennel)', 'cardamom', 1),
#  ('anise (see also anise, star, and fennel)', 'carrots', 1),
#  ('anise (see also anise, star, and fennel)', 'cauliflower', 1),
#  ('anise (see also anise, star, and fennel)',
#   'cheese, esp. goat and ricotta',
#   1),
#  ('anise (see also anise, star, and fennel)', 'chestnuts', 1),
#  ('anise (see also anise, star, and fennel)', 'chinese cuisine', 3),
#  ('anise (see also anise, star, and fennel)', 'cinnamon', 1),
#  ('anise (see also anise, star, and fennel)', 'cloves', 1),
#  ('anise (see also anise, star, and fennel)', 'coffee', 1),
#  ('anise (see also anise, star, and fennel)', 'cookies', 1),
#  ('anise (see also anise, star, and fennel)', 'crab', 1),
#  ('anise (see also anise, star, and fennel)', 'cream', 1),
#  ('anise (see also anise, star, and fennel)', 'cumin', 1),
#  ('anise (see also anise, star, and fennel)', 'dates', 1),
#  ('anise (see also anise, star, and fennel)', 'desserts', 1),
#  ('anise (see also anise, star, and fennel)', 'duck', 1),
#  ('anise (see also anise, star, and fennel)', 'fennel seeds', 1),
#  ('anise (see also anise, star, and fennel)', 'figs', 1),
#  ('anise (see also anise, star, and fennel)', 'fish', 3),
#  ('anise (see also anise, star, and fennel)', 'fruit', 1),
#  ('anise (see also anise, star, and fennel)', 'garlic', 1),
#  ('anise (see also anise, star, and fennel)', 'ginger', 1),
#  ('anise (see also anise, star, and fennel)', 'hazelnuts', 1),
#  ('anise (see also anise, star, and fennel)', 'lemon', 1),
#  ('anise (see also anise, star, and fennel)', 'lentils', 1),
#  ('anise (see also anise, star, and fennel)', 'mayonnaise', 1),
#  ('anise (see also anise, star, and fennel)', 'mediterranean cuisine', 3),
#  ('anise (see also anise, star, and fennel)', 'melon', 1),
#  ('anise (see also anise, star, and fennel)', 'middle eastern cuisine', 3),
#  ('anise (see also anise, star, and fennel)', 'mole sauce', 1),
#  ('anise (see also anise, star, and fennel)', 'moroccan cuisine', 3),
#  ('anise (see also anise, star, and fennel)', 'mussels', 1),
#  ('anise (see also anise, star, and fennel)', 'nutmeg', 1),
#  ('anise (see also anise, star, and fennel)', 'nuts', 1),
#  ('anise (see also anise, star, and fennel)', 'orange', 1),
#  ('anise (see also anise, star, and fennel)', 'parsnips', 1),
#  ('anise (see also anise, star, and fennel)', 'peaches', 1),
#  ('anise (see also anise, star, and fennel)', 'pears', 1),
#  ('anise (see also anise, star, and fennel)', 'pepper', 1),
#  ('anise (see also anise, star, and fennel)', 'pickles', 1),
#  ('anise (see also anise, star, and fennel)', 'pineapple', 1),
#  ('anise (see also anise, star, and fennel)', 'plums', 1),
#  ('anise (see also anise, star, and fennel)', 'pork', 1),
#  ('anise (see also anise, star, and fennel)', 'portuguese cuisine', 3),
#  ('anise (see also anise, star, and fennel)', 'provençal cuisine (french)', 3),
#  ('anise (see also anise, star, and fennel)', 'prunes', 1),
#  ('anise (see also anise, star, and fennel)', 'pumpkin', 1),
#  ('anise (see also anise, star, and fennel)', 'quince', 1),
#  ('anise (see also anise, star, and fennel)', 'raisins', 1),
#  ('anise (see also anise, star, and fennel)', 'rhubarb', 1),
#  ('anise (see also anise, star, and fennel)', 'salumi', 1),
#  ('anise (see also anise, star, and fennel)', 'sauerkraut', 1),
#  ('anise (see also anise, star, and fennel)', 'scandinavian cuisine', 3),
#  ('anise (see also anise, star, and fennel)', 'shellfish', 1),
#  ('anise (see also anise, star, and fennel)', 'soups, esp. fish', 1),
#  ('anise (see also anise, star, and fennel)', 'star anise', 1),
#  ('anise (see also anise, star, and fennel)', 'stews, esp. fish', 3),
#  ('anise (see also anise, star, and fennel)', 'strawberries', 1),
#  ('anise (see also anise, star, and fennel)', 'sugar', 1),
#  ('anise (see also anise, star, and fennel)', 'sweet potatoes', 1),
#  ('anise (see also anise, star, and fennel)', 'tea', 1),
#  ('anise (see also anise, star, and fennel)', 'vanilla', 1),
#  ('anise (see also anise, star, and fennel)', 'vegetables, root', 1),
#  ('anise (see also anise, star, and fennel)', 'vietnamese cuisine', 3),
#  ('anise (see also anise, star, and fennel)', 'walnuts', 1),
#  ('anise hyssop', 'basil', 1),
#  ('anise hyssop', 'beans, green', 1),
#  ('anise hyssop', 'beets', 1),
#  ('anise hyssop', 'berries, esp. blueberries', 1),
#  ('anise hyssop', 'beverages', 1),
#  ('anise hyssop', 'carrots', 1),
#  ('anise hyssop', 'cherries', 1),
#  ('anise hyssop', 'chervil', 1),
#  ('anise hyssop', 'chicken', 1),
#  ('anise hyssop', 'cream and ice cream', 1),
#  ('anise hyssop', 'currants', 1),
#  ('anise hyssop', 'custards', 1),
#  ('anise hyssop', 'desserts', 1),
#  ('anise hyssop', 'fennel bulb', 1),
#  ('anise hyssop', 'fish', 1),
#  ('anise hyssop', 'fruits, esp. summer', 3),
#  ('anise hyssop', 'honey', 1),
#  ('anise hyssop', 'lavender', 1),
#  ('anise hyssop', 'lemon', 1),
#  ('anise hyssop', 'lychees', 1),
#  ('anise hyssop', 'marjoram', 1),
#  ('anise hyssop', 'melons', 1),
#  ('anise hyssop', 'mint', 1),
#  ('anise hyssop', 'nectarines', 1),
#  ('anise hyssop', 'oranges', 1),
#  ('anise hyssop', 'parsley', 1),
#  ('anise hyssop', 'parsnips', 1),
#  ('anise hyssop', 'peaches', 1),
#  ('anise hyssop', 'pears', 1),
#  ('anise hyssop', 'plums', 1),
#  ('anise hyssop', 'pork', 1),
#  ('anise hyssop', 'raspberries', 1),
#  ('anise hyssop', 'rice', 1),
#  ('anise hyssop', 'shellfish (e.g., shrimp)', 1),
#  ('anise hyssop', 'shrimp', 1),
#  ('anise hyssop', 'spinach', 1),
#  ('anise hyssop', 'squash, winter', 1),
#  ('anise hyssop', 'stone fruits (e.g., peaches)', 1),
#  ('anise hyssop', 'sweet potatoes', 1),
#  ('anise hyssop', 'tarragon', 1),
#  ('anise hyssop', 'teas', 1),
#  ('anise hyssop', 'tomatoes', 1),
#  ('anise hyssop', 'vegetables, root', 1),
#  ('anise hyssop', 'watermelon', 1),
#  ('anise hyssop', 'zucchini', 1),
#  ('anise, star', 'baked goods (e.g., breads, pastries)', 1),
#  ('anise, star', 'beef', 1),
#  ('anise, star', 'beverages', 1),
#  ('anise, star', 'cardamom', 1),
#  ('anise, star', 'chestnuts', 1),
#  ('anise, star', 'chicken', 1),
#  ('anise, star', 'chile peppers', 1),
#  ('anise, star', 'chili powder', 1),
#  ('anise, star', 'chinese cuisine', 3),
#  ('anise, star', 'chocolate, esp. milk', 1),
#  ('anise, star', 'cinnamon', 1),
#  ('anise, star', 'citrus zest', 1),
#  ('anise, star', 'cloves', 1),
#  ('anise, star', 'coriander', 1),
#  ('anise, star', 'cumin', 1),
#  ('anise, star', 'curry powder (ingredient)', 1),
#  ('anise, star', 'duck', 1),
#  ('anise, star', 'eggs', 1),
#  ('anise, star', 'fennel seeds', 1),
#  ('anise, star', 'figs', 1),
#  ('anise, star', 'fish', 1),
#  ('anise, star', 'five-spice powder', 3),
#  ('anise, star', 'fruits, esp. tropical', 1),
#  ('anise, star', 'garlic', 1),
#  ('anise, star', 'ginger', 1),
#  ('anise, star', 'indian cuisine', 3),
#  ('anise, star', 'kumquats', 1),
#  ('anise, star', 'leeks', 1),
#  ('anise, star', 'lemongrass', 1),
#  ('anise, star', 'lime, zest', 1),
#  ('anise, star', 'liqueurs', 1),
#  ('anise, star', 'mace', 1),
#  ('anise, star', 'malaysian cuisine', 3),
#  ('anise, star', 'mangoes', 1),
#  ('anise, star', 'maple syrup', 1),
#  ('anise, star', 'meats, esp. fatty', 1),
#  ('anise, star', 'nutmeg', 1),
#  ('anise, star', 'orange, zest', 1),
#  ('anise, star', 'oxtails', 1),
#  ('anise, star', 'pears, esp. poached', 1),
#  ('anise, star', 'pineapple', 1),
#  ('anise, star', 'plums, esp. poached', 1),
#  ('anise, star', 'pork', 1),
#  ('anise, star', 'poultry', 1),
#  ('anise, star', 'pumpkin', 1),
#  ('anise, star', 'raspberries', 1),
#  ('anise, star', 'root vegetables', 1),
#  ('anise, star', 'salmon', 1),
#  ('anise, star', 'sauces', 1),
#  ('anise, star', 'scallions', 1),
#  ('anise, star', 'scallops', 1),
#  ('anise, star', 'shellfish', 1),
#  ('anise, star', 'shrimp', 1),
#  ('anise, star', 'soups', 1),
#  ('anise, star', 'soy sauce', 1),
#  ('anise, star', 'stews', 1),
#  ('anise, star', 'sweet potatoes', 1),
#  ('anise, star', 'tamarind', 1),
#  ('anise, star', 'teas', 1),
#  ('anise, star', 'tuna', 1),
#  ('anise, star', 'turmeric', 1),
#  ('anise, star', 'vanilla', 1),
#  ('anise, star', 'vegetables, esp. root', 1),
#  ('anise, star', 'vietnamese cuisine (e.g.,pho)', 3),
#  ('anise, star', 'wine, rice', 1),
#  ('anise, star', '29578', 1),
#  ('anise, star', '60369', 1),
#  ('anise, star', '62888', 1),
#  ('apples', 'almonds', 1),
#  ('apples', 'apple cider or juice', 1),
#  ('apples', 'applejack', 1),
#  ('apples', 'armagnac', 3),
#  ('apples', 'bacon', 1),
#  ('apples', 'bay leaf', 1),
#  ('apples', 'beef', 1),
#  ('apples', 'blackberries', 1),
#  ('apples', 'bourbon', 1),
#  ('apples', 'brandy, esp. apple', 1),
#  ('apples', 'brioche', 1),
#  ('apples', 'butter, unsalted', 3),
#  ('apples', 'butterscotch', 1),
#  ('apples', 'cabbage, red', 1),
#  ('apples', 'calvados', 3),
#  ('apples', 'caramel', 3),
#  ('apples', 'cardamom', 1),
#  ('apples', 'celery', 1),
#  ('apples', 'celery root', 1),
#  ('apples', 'chestnuts', 1),
#  ('apples', 'chicken', 1),
#  ('apples', 'chives', 1),
#  ('apples', 'cider', 1),
#  ('apples', 'cinnamon', 5),
#  ('apples', 'cloves', 1),
#  ('apples', 'cognac', 1),
#  ('apples', 'cointreau', 3),
#  ('apples', 'coriander', 1),
#  ('apples', 'cranberries', 1),
#  ('apples', 'cream and ice cream', 3),
#  ('apples', 'crème anglaise (sauce)', 1),
#  ('apples', 'crème fraîche', 1),
#  ('apples', 'cumin', 1),
#  ('apples', 'currants, esp. black, and currant jelly', 1),
#  ('apples', 'curry powder', 1),
#  ('apples', 'custards', 1),
#  ('apples', 'dates', 1),
#  ('apples', 'duck', 1),
#  ('apples', 'eggplant', 1),
#  ('apples', 'fennel', 1),
#  ('apples', 'french cuisine, esp. from normandy', 3),
#  ('apples', 'frisée', 1),
#  ('apples', 'ginger', 1),
#  ('apples', 'goose', 1),
#  ('apples', 'hazelnuts', 1),
#  ('apples', 'honey, esp. chestnut, wildflower', 1),
#  ('apples', 'horseradish', 1),
#  ('apples', 'ice cream', 1),
#  ('apples', 'kirsch', 3),
#  ('apples', 'lavender', 1),
#  ('apples', 'lemon thyme', 1),
#  ('apples', 'lychees', 1),
#  ('apples', 'madeira', 3),
#  ('apples', 'maple syrup', 1),
#  ('apples', 'mayonnaise', 1),
#  ('apples', 'meringue', 1),
#  ('apples', 'molasses', 1),
#  ('apples', 'mustard', 1),
#  ('apples', 'nutmeg', 1),
#  ('apples', 'nuts', 1),
#  ('apples', 'oatmeal and oats', 1),
#  ('apples', 'olive oil', 1),
#  ('apples', 'onions, esp. green, red', 1),
#  ('apples', 'parsley', 1),
#  ('apples', 'peanuts and peanut butter', 1),
#  ('apples', 'pears', 1),
#  ('apples', 'pecans', 1),
#  ('apples', 'pepper, black', 1),
#  ('apples', 'pies', 1),
#  ('apples', 'pineapple', 1),
#  ('apples', 'pine nuts', 1),
#  ('apples', 'pistachios', 1),
#  ('apples', 'plums', 1),
#  ('apples', 'pomegranates', 1),
#  ('apples', 'pork', 1),
#  ('apples', 'poultry', 1),
#  ('apples', 'prunes', 1),
#  ('apples', 'puff pastry', 1),
#  ('apples', 'pumpkin', 1),
#  ('apples', 'quince', 1),
#  ('apples', 'raisins, esp. seedless, white', 1),
#  ('apples', 'rhubarb', 1),
#  ('apples', 'rice and rice pudding', 1),
#  ('apples', 'rosemary', 1),
#  ('apples', 'salt, kosher', 1),
#  ('apples', 'sauerkraut', 1),
#  ('apples', 'sherry', 1),
#  ('apples', 'soups', 1),
#  ('apples', 'sour cream', 1),
#  ('apples', 'star anise', 1),
#  ('apples', 'sweet potatoes', 1),
#  ('apples', 'tarragon', 1),
#  ('apples', 'tarts', 1),
#  ('apples', 'thyme', 1),
#  ('apples', 'vanilla', 1),
#  ('apples', 'verjus', 1),
#  ('apples', 'vermouth', 1),
#  ('apples', 'walnuts', 3),
#  ('apples', 'yogurt', 1),
#  ('apples', '61929', 1),
#  ('apples', '28065', 3),
#  ('apples', '26551', 1),
#  ('apples', '60137', 1),
#  ('apples', '45299', 3),
#  ('apples', '58023', 1),
#  ('apples', '8676', 1),
#  ('apples', '33159', 1),
#  ('apples', '9351', 1),
#  ('apples', '29177', 1),
#  ('apples', '49268', 1),
#  ('apples', '41356', 1),
#  ('apples', '41027', 1),
#  ('apples', '11323', 1),
#  ('apples', '757', 1),
#  ('apples', '61859', 1),
#  ('apples', '13559', 1),
#  ('apples', '59486', 1),
#  ('apples', '34511', 1),
#  ('apricots — in general', 'allspice', 1),
#  ('apricots — in general', 'almonds', 3),
#  ('apricots — in general', 'amaretto', 1),
#  ('apricots — in general', 'anise', 1),
#  ('apricots — in general', 'apples', 1),
#  ('apricots — in general', 'apricot brandy', 1),
#  ('apricots — in general', 'bananas', 1),
#  ('apricots — in general', 'blackberries', 1),
#  ('apricots — in general', 'blueberries', 1),
#  ('apricots — in general', 'brandy', 1),
#  ('apricots — in general', 'butter, unsalted', 1),
#  ('apricots — in general', 'caramel', 1),
#  ('apricots — in general', 'cardamom', 1),
#  ('apricots — in general', 'cayenne', 1),
#  ('apricots — in general', 'cheese (e.g., brie, reblochon, ricotta)', 3),
#  ('apricots — in general', 'cheesecake', 1),
#  ('apricots — in general', 'cherries', 1),
#  ('apricots — in general', 'chicken', 1),
#  ('apricots — in general', 'chocolate, white', 1),
#  ('apricots — in general', 'cinnamon', 1),
#  ('apricots — in general', 'coconut', 1),
#  ('apricots — in general', 'coffee and espresso', 1),
#  ('apricots — in general', 'cognac', 1),
#  ('apricots — in general', 'coriander', 1),
#  ('apricots — in general', 'cranberries', 1),
#  ('apricots — in general', 'cream and ice cream', 3),
#  ('apricots — in general', 'crème anglaise', 1),
#  ('apricots — in general', 'custards (e.g., crème brûlée)', 1),
#  ('apricots — in general', 'duck', 1),
#  ('apricots — in general', 'foie gras', 1),
#  ('apricots — in general', 'game', 1),
#  ('apricots — in general', 'garlic', 1),
#  ('apricots — in general', 'ginger', 1),
#  ('apricots — in general', 'hazelnuts', 1),
#  ('apricots — in general', 'honey', 1),
#  ('apricots — in general', 'ice cream, esp. vanilla', 1),
#  ('apricots — in general', 'kirsch', 3),
#  ('apricots — in general', 'lamb', 1),
#  ('apricots — in general', 'lemon verbena', 1),
#  ('apricots — in general', 'maple syrup', 1),
#  ('apricots — in general', 'mascarpone', 1),
#  ('apricots — in general', 'mediterranean cuisine', 3),
#  ('apricots — in general', 'meringue', 1),
#  ('apricots — in general', 'middle eastern stews', 3),
#  ('apricots — in general', 'mint (garnish)', 1),
#  ('apricots — in general', 'moroccan cuisine', 3),
#  ('apricots — in general', 'nectarines', 1),
#  ('apricots — in general', 'nutmeg', 1),
#  ('apricots — in general', 'nuts', 1),
#  ('apricots — in general', 'oats and oatmeal', 1),
#  ('apricots — in general', 'onions, esp. yellow', 1),
#  ('apricots — in general', 'orange liqueur', 1),
#  ('apricots — in general', 'peaches', 1),
#  ('apricots — in general', 'pepper, black', 1),
#  ('apricots — in general', 'pineapple', 1),
#  ('apricots — in general', 'pine nuts', 1),
#  ('apricots — in general', 'pistachios', 1),
#  ('apricots — in general', 'plums', 1),
#  ('apricots — in general', 'pork', 1),
#  ('apricots — in general', 'poultry', 1),
#  ('apricots — in general', 'praline', 1),
#  ('apricots — in general', 'prunes', 1),
#  ('apricots — in general', 'raisins', 1),
#  ('apricots — in general', 'raspberries', 1),
#  ('apricots — in general', 'rice pudding', 1),
#  ('apricots — in general', 'rosemary', 1),
#  ('apricots — in general', 'rum', 1),
#  ('apricots — in general', 'saffron', 1),
#  ('apricots — in general', 'salads, esp. fruit, green', 1),
#  ('apricots — in general', 'sauternes', 3),
#  ('apricots — in general', 'sour cream', 1),
#  ('apricots — in general', 'strawberries', 1),
#  ('apricots — in general', 'vanilla', 5),
#  ('apricots — in general', 'vinegar, red wine', 1),
#  ('apricots — in general', 'walnuts', 1),
#  ('apricots — in general', 'yogurt', 1),
#  ('apricots — in general', '2579', 1),
#  ('apricots — in general', '60593', 3),
#  ('apricots — in general', '59580', 1),
#  ('apricots — in general', '48959', 1),
#  ('apricots — in general', '9906', 1),
#  ('apricots, dried', 'allspice', 1),
#  ('apricots, dried', 'cherries, dried', 1),
#  ('apricots, dried', 'cinnamon', 1),
#  ('apricots, dried', 'currants', 1),
#  ('apricots, dried', 'custard', 1),
#  ('apricots, dried', 'french toast', 3),
#  ('apricots, dried', 'ginger', 1),
#  ('apricots, dried', 'hazelnuts', 1),
#  ('apricots, dried', 'honey', 1),
#  ('apricots, dried', 'ice cream', 1),
#  ('apricots, dried', 'madeira', 3),
#  ('apricots, dried', 'moroccan cuisine', 3),
#  ('apricots, dried', 'pancakes/crepes', 1),
#  ('apricots, dried', 'pistachios', 1),
#  ('apricots, dried', 'pork', 1),
#  ('apricots, dried', 'prunes', 1),
#  ('apricots, dried', 'pumpkin seeds', 1),
#  ('apricots, dried', 'raisins', 1),
#  ('apricots, dried', 'rice pudding', 1),
#  ('apricots, dried', 'sugar', 1),
#  ('apricots, dried', 'tamarind paste', 1),
#  ('apricots, dried', 'vanilla', 1),
#  ('apricots, dried', 'wine, sweet white (e.g., muscat)', 3),
#  ('apricots, dried', '9916', 1),
#  ('argentinian cuisine (see also latin american cuisine)', 'beef', 1),
#  ('argentinian cuisine (see also latin american cuisine)', 'corn', 1),
#  ('argentinian cuisine (see also latin american cuisine)', 'peaches', 1),
#  ('argentinian cuisine (see also latin american cuisine)', 'pumpkin', 1),
#  ('argentinian cuisine (see also latin american cuisine)', 'sweet potatoes', 1),
#  ('aroma', 'chocolate', 1),
#  ('aroma', 'cinnamon', 1),
#  ('aroma', 'herbs', 1),
#  ('aroma', 'pineapple', 1),
#  ('aroma', 'sous-vide cooking', 1),
#  ('aroma', 'spices', 1),
#  ('aroma', 'star anise', 1),
#  ('aroma', 'truffles', 1),
#  ('aroma', 'vanilla', 1),
#  ('artichokes', 'anchovies', 1),
#  ('artichokes', 'arugula', 1),
#  ('artichokes', 'bacon', 1),
#  ('artichokes', 'basil', 1),
#  ('artichokes', 'bay leaf', 1),
#  ('artichokes', 'beans, fava', 1),
#  ('artichokes', 'beets', 1),
#  ('artichokes', 'bell peppers, esp. roasted', 1),
#  ('artichokes', 'bread crumbs', 1),
#  ('artichokes', 'butter', 1),
#  ('artichokes', 'capers', 1),
#  ('artichokes', 'carrots', 1),
#  ('artichokes', 'cashews', 1),
#  ('artichokes', 'celery', 1),
#  ('artichokes', 'chervil', 1),
#  ('artichokes', 'chicken', 1),
#  ('artichokes', 'chives', 1),
#  ('artichokes', 'coriander', 1),
#  ('artichokes', 'cream', 1),
#  ('artichokes', 'crème fraîche', 1),
#  ('artichokes', 'french cuisine', 3),
#  ('artichokes', 'garlic', 3),
#  ('artichokes', 'grapefruit', 1),
#  ('artichokes', 'ham (e.g., serrano)', 3),
#  ('artichokes', 'hazelnuts', 1),
#  ('artichokes', 'hollandaise sauce', 1),
#  ('artichokes', 'italian cuisine', 3),
#  ('artichokes', 'leeks', 1),
#  ('artichokes', 'lobster', 1),
#  ('artichokes', 'mayonnaise', 1),
#  ('artichokes', 'mediterranean cuisine', 3),
#  ('artichokes', 'mint', 3),
#  ('artichokes', 'moroccan cuisine', 3),
#  ('artichokes', 'mushrooms', 1),
#  ('artichokes', 'mustard, dijon', 3),
#  ('artichokes', 'olive oil', 3),
#  ('artichokes', 'onions, esp. sweet and yellow', 3),
#  ('artichokes', 'orange', 1),
#  ('artichokes', 'pancetta', 1),
#  ('artichokes', 'parsley, flat-leaf', 3),
#  ('artichokes', 'pesto', 1),
#  ('artichokes', 'piquillo peppers', 1),
#  ('artichokes', 'potatoes', 1),
#  ('artichokes', 'prosciutto', 1),
#  ('artichokes', 'radicchio', 1),
#  ('artichokes', 'red pepper flakes', 1),
#  ('artichokes', 'rice', 1),
#  ('artichokes', 'risotto', 1),
#  ('artichokes', 'rosemary', 1),
#  ('artichokes', 'saffron', 1),
#  ('artichokes', 'sage', 1),
#  ('artichokes', 'salads', 1),
#  ('artichokes', 'salt, kosher', 3),
#  ('artichokes', 'savory', 1),
#  ('artichokes', 'shallots', 1),
#  ('artichokes', 'shellfish (e.g., crab)', 1),
#  ('artichokes', 'sherry, dry', 1),
#  ('artichokes', 'shrimp', 1),
#  ('artichokes', 'soy sauce', 1),
#  ('artichokes', 'spanish cuisine', 3),
#  ('artichokes', 'spinach', 1),
#  ('artichokes', 'stock, chicken', 1),
#  ('artichokes', 'sugar (pinch)', 1),
#  ('artichokes', 'tapenade', 1),
#  ('artichokes', 'tarragon, fresh', 1),
#  ('artichokes', 'thyme, fresh', 3),
#  ('artichokes', 'tomatoes', 3),
#  ('artichokes', 'truffles, black', 1),
#  ('artichokes', 'tuna', 1),
#  ('artichokes', 'vinaigrette', 1),
#  ('artichokes', 'walnuts', 1),
#  ('artichokes', 'wine, dry white', 3),
#  ('artichokes', 'yogurt', 1),
#  ('artichokes', '11622', 1),
#  ('artichokes', '40806', 3),
#  ('artichokes', '38509', 1),
#  ('artichokes', '17662', 1),
#  ('artichokes', '17354', 1),
#  ('artichokes', '27067', 1),
#  ('artichokes', '63331', 1),
#  ('artichokes', '52746', 3),
#  ('artichokes', '14323', 1),
#  ('artichokes', '57475', 1),
#  ('artichokes', '43310', 1),
#  ('artichokes', '42025', 1),
#  ('artichokes', '48999', 3),
#  ('artichokes, jerusalem', 'bacon', 1),
#  ('artichokes, jerusalem', 'bay leaf', 1),
#  ('artichokes, jerusalem', 'butter', 1),
#  ('artichokes, jerusalem', 'celery', 1),
#  ('artichokes, jerusalem', 'cheese, goat', 1),
#  ('artichokes, jerusalem', 'chervil', 1),
#  ('artichokes, jerusalem', 'chives', 1),
#  ('artichokes, jerusalem', 'coriander', 1),
#  ('artichokes, jerusalem', 'cream', 1),
#  ('artichokes, jerusalem', 'cumin', 1),
#  ('artichokes, jerusalem', 'dill', 1),
#  ('artichokes, jerusalem', 'fennel leaves', 1),
#  ('artichokes, jerusalem', 'fennel seeds', 1),
#  ('artichokes, jerusalem', 'garlic', 1),
#  ('artichokes, jerusalem', 'ginger', 1),
#  ('artichokes, jerusalem', 'hazelnuts', 1),
#  ('artichokes, jerusalem', 'leeks', 1),
#  ('artichokes, jerusalem', 'lemon, juice', 1),
#  ('artichokes, jerusalem', 'mace', 1),
#  ('artichokes, jerusalem', 'meats, esp. roasted', 1),
#  ('artichokes, jerusalem', 'morels', 1),
#  ('artichokes, jerusalem', 'nutmeg', 1),
#  ('artichokes, jerusalem', 'olive oil', 1),
#  ('artichokes, jerusalem', 'onions', 1),
#  ('artichokes, jerusalem', 'parsley, flat-leaf', 1),
#  ('artichokes, jerusalem', 'pepper, black', 1),
#  ('artichokes, jerusalem', 'potatoes', 1),
#  ('artichokes, jerusalem', 'rosemary', 1),
#  ('artichokes, jerusalem', 'sage', 1),
#  ('artichokes, jerusalem', 'salmon', 1),
#  ('artichokes, jerusalem', 'salt, sea', 1),
#  ('artichokes, jerusalem', 'shallots', 1),
#  ('artichokes, jerusalem', 'stock, chicken', 1),
#  ('artichokes, jerusalem', 'tarragon', 1),
#  ('artichokes, jerusalem', 'thyme', 1),
#  ('artichokes, jerusalem', 'vinegar', 1),
#  ('artichokes, jerusalem', 'wine, dry white', 1),
#  ('artichokes, jerusalem', '18364', 3),
#  ('artichokes, jerusalem', '44841', 3),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'basil', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'beans, white',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'bell peppers, esp. red',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'chicken', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'cilantro', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'clams', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'corn', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'cucumbers', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'dill', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'eggs, esp. hard-boiled',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'endive', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'fennel', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'fish (e.g., salmon, tuna)',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'garlic', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'grapes', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'italian cuisine',
#   3),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'lemon juice',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'lettuces', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'lovage', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'mediterranean cuisine',
#   3),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'mesclun salad greens (key ingredient)',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'mint', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'mushrooms', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'mussels', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'nuts', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'olive oil', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'olives, black',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'oranges, esp. blood',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'pancetta', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'parsley', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'pasta', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'pears', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'pesto', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'pine nuts', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'potatoes', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'prosciutto', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'radicchio', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'radishes', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'risotto', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'salads and salad greens',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'salt, esp. sea',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'shallots', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'shellfish (e.g., shrimp)',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'tomatoes', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'tuna', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'vinaigrettes',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'red wine, sherry, white wine',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'watercress', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', '47411', 3),
#  ('arugula (see also lettuces — bitter greens and chicories)', '34030', 3),
#  ('arugula (see also lettuces — bitter greens and chicories)', '8004', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', '7717', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', '14894', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', '5294', 1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'anchovies',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'artichokes',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'basil',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'bay leaf',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'beets',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'bread crumbs',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'butter, brown',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'butter, unsalted',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'capers',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'caraway seeds',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'carrots',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'cayenne',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'chervil',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'chives',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'crab',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'cream, heavy',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'crème fraîche',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'dill',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'eggs and egg dishes (e.g., coddled, hard-boiled omelets)',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'fava beans',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'french cuisine',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'garlic',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'ginger',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'ham',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'hollandaise sauce',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'italian cuisine',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'leeks',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'lemon thyme',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'lime, juice',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'lobster',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'marsala wine',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'mascarpone',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'mayonnaise',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'mushrooms, esp. cremini, morels, shiitakes',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'mustard, dijon',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'olive oil',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'onions, esp. spring, yellow',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'orange',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'oysters',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'pancetta',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'parsley, flat-leaf',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'pasta',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'peas',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'peppers, piquillo',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'pistachios',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'potatoes',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'prosciutto',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'ramps',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'rice and risotto',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'saffron',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'sage',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'salmon',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'savory',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'scallions',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'sesame seeds',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'shallots',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'shrimp',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'soups',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'sour cream',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'soy sauce',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'spinach',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'tarragon',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'thyme, fresh',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'tomatoes',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'turnips',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'vermouth',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'wine, dry white (e.g., muscat)',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   'yogurt',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   '32803',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   '54901',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   '29822',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   '34143',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   '1538',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   '12363',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   '62891',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   '39337',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   '62790',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   '4384',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   '34533',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   '41195',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n'
#   '  asparagus',
#   '2690',
#   1),
#  ('asparagus, white', 'butter', 1),
#  ('asparagus, white', 'cheese, parmesan', 3),
#  ('asparagus, white', 'chicken', 1),
#  ('asparagus, white', 'crab', 1),
#  ('asparagus, white', 'ham', 1),
#  ('asparagus, white', 'hazelnuts', 1),
#  ('asparagus, white', 'lemon', 1),
#  ('asparagus, white', 'mushrooms (e.g., cepes, morels, porcini)', 1),
#  ('asparagus, white', 'mustard', 1),
#  ('asparagus, white', 'oil, truffle', 1),
#  ('asparagus, white', 'olive oil', 1),
#  ('asparagus, white', 'parsley', 1),
#  ('asparagus, white', 'pepper, black', 1),
#  ('asparagus, white', 'salt, sea', 1),
#  ('asparagus, white', 'shallots', 1),
#  ('asparagus, white', 'shrimp', 1),
#  ('asparagus, white', 'stock, chicken', 1),
#  ('asparagus, white', 'sugar (pinch)', 1),
#  ('asparagus, white', 'tarragon', 1),
#  ('asparagus, white', 'vinaigrette', 1),
#  ('asparagus, white', 'wine, riesling', 3),
#  ('asparagus, white', '46121', 3),
#  ('asparagus, white', '18823', 1),
#  ('asparagus, white', '44284', 1),
#  ('asparagus, white', 'apples (astringent-sweet)', 1),
#  ('asparagus, white', 'artichokes', 1),
#  ('asparagus, white', 'asparagus', 1),
#  ('asparagus, white', 'bananas, unripe (astringent-sweet)', 1),
#  ('asparagus, white', 'basil', 1),
#  ('asparagus, white', 'beans', 1),
#  ('asparagus, white', 'berries', 1),
#  ('asparagus, white', 'broccoli', 1),
#  ('asparagus, white', 'buckwheat', 1),
#  ('asparagus, white', 'cashews', 1),
#  ('asparagus, white', 'cauliflower', 1),
#  ('asparagus, white', 'coffee', 1),
#  ('asparagus, white', 'cranberries', 1),
#  ('asparagus, white', 'figs (astringent-sweet)', 1),
#  ('asparagus, white', 'grapes (astringent-sour-sweet)', 1),
#  ('asparagus, white', 'hazelnuts', 1),
#  ('asparagus, white', 'herbs', 1),
#  ('asparagus, white', 'honey', 1),
#  ('asparagus, white', 'legumes', 1),
#  ('asparagus, white', 'lentils', 1),
#  ('asparagus, white', 'lettuce', 1),
#  ('asparagus, white', 'mace', 1),
#  ('asparagus, white', 'marjoram', 1),
#  ('asparagus, white', 'okra', 1),
#  ('asparagus, white', 'parsley', 1),
#  ('asparagus, white', 'peaches (astringent-sweet)', 1),
#  ('asparagus, white', 'pears (astringent-sweet)', 1),
#  ('asparagus, white', 'persimmons', 1),
#  ('asparagus, white', 'plums (astringent-sweet)', 1),
#  ('asparagus, white', 'pomegranates (astringent-sour-sweet)', 1),
#  ('asparagus, white', 'quinoa', 1),
#  ('asparagus, white', 'rhubarb', 1),
#  ('asparagus, white', 'rye', 1),
#  ('asparagus, white', 'saffron', 1),
#  ('asparagus, white', 'sprouts', 1),
#  ('asparagus, white', 'tea', 1),
#  ('asparagus, white', 'turmeric', 1),
#  ('asparagus, white', 'turnips', 1),
#  ('asparagus, white', 'vegetables, raw', 1),
#  ('asparagus, white', 'walnuts', 1),
#  ('australian cuisine', 'barbecued foods', 1),
#  ('australian cuisine', 'beef', 1),
#  ('australian cuisine', 'cheese', 1),
#  ('australian cuisine', 'fish', 1),
#  ('australian cuisine', 'fruits, fresh', 1),
#  ('australian cuisine', 'lamb', 1),
#  ('australian cuisine', 'nuts, macadamia', 1),
#  ('australian cuisine', 'seafood', 1),
#  ('australian cuisine', 'shellfish, esp. shrimp', 1),
#  ('australian cuisine', 'vegetables, fresh', 1),
#  ('australian cuisine', 'wines', 1),
#  ('austrian cuisine', 'beer', 1),
#  ('austrian cuisine', 'cinnamon', 1),
#  ('austrian cuisine', 'coffee', 1),
#  ('austrian cuisine', 'cream', 1),
#  ('austrian cuisine', 'desserts', 1),
#  ('austrian cuisine', 'dumplings', 1),
#  ('austrian cuisine', 'goulash', 1),
#  ('austrian cuisine', 'marjoram', 1),
#  ('austrian cuisine', 'meat, esp. beef or pork', 1),
#  ('austrian cuisine', 'paprika', 1),
#  ('austrian cuisine', 'parsley', 1),
#  ('austrian cuisine', 'pastries', 1),
#  ('austrian cuisine', 'potatoes', 1),
#  ('austrian cuisine', 'schnitzel', 1),
#  ('austrian cuisine', 'soups, esp. with dumplings or noodles', 1),
#  ('austrian cuisine', 'stews', 1),
#  ('austrian cuisine', 'strudel', 1),
#  ('austrian cuisine', 'wine', 1),
#  ('autumn', 'broccoli', 1),
#  ('autumn', 'cakes, esp. served warm', 1),
#  ('autumn', 'caramel', 1),
#  ('autumn', 'cauliflower', 1),
#  ('autumn', 'chile peppers', 1),
#  ('autumn', 'dates', 1),
#  ('autumn', 'duck', 1),
#  ('autumn', 'fennel', 1),
#  ('autumn', 'foie gras', 1),
#  ('autumn', 'grains', 1),
#  ('autumn', 'heavier dishes', 1),
#  ('autumn', 'lentils', 1),
#  ('autumn', 'nuts', 1),
#  ('autumn', 'polenta', 1),
#  ('autumn', 'scallops', 1),
#  ('autumn', 'seeds, sunflower', 1),
#  ('autumn',
#   'spices, warming (e.g., black peppercorns, cayenne, cinnamon, chili powder, '
#   'clove, cumin, mustard, etc.)',
#   1),
#  ('autumn', 'stuffing', 1),
#  ('autumn', 'sweetbreads', 1),
#  ('autumn', 'turkey', 1),
#  ('autumn', 'vinegar, red wine', 1),
#  ('autumn', 'walnuts', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'bacon', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'basil and thai basil', 3),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'beans, black', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'bell peppers, esp. red', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'butter, unsalted', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados',
#   'central american cuisine',
#   3),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'chayote', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'chervil', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'chicken', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'chives', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'cilantro', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'corn and masa', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'crab', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'cream, heavy', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'crème fraîche', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'cucumbers', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'cumin', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'dashi', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'endive, esp. belgian', 3),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'fennel', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'fish', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'frisée', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'fruits, esp. tropical', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'garlic', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'grapefruit', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados',
#   'guacamole (key ingredient)',
#   1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'jicama', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'lime, juice', 3),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'lobster', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'mangoes', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'mayonnaise', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'mexican cuisine', 3),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'oil, canola', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'olive oil', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados',
#   'onions, esp. red, spring, white',
#   3),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'orange', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'parsley, flat-leaf', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'radishes', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'rocket', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'sake', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados',
#   'salads, esp. green, seafood',
#   1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'salsa', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'sandwiches', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'scallions', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados',
#   'shellfish (e.g., shrimp)',
#   1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'shrimp', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados',
#   'smoked fish (e.g., trout)',
#   1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'soups', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'sour cream', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'southwestern cuisine', 3),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'soy sauce', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'spinach', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'tabasco sauce', 3),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'tarragon', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'tequila', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'tomatillos', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'tomatoes', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'vinaigrette', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'walnuts, oil', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', 'yogurt', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', '59434', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', '13335', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', '54876', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', '21925', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', '26664', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', '19469', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', '7443', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', '53470', 1),
#  ('avocado oil (see oil, avocado)\r\n  avocados', '23010', 1)]

# %%
# Get all the pairings!
pairings = list()
variable_pairings = dict()
used_keys = set()
for chapter in chap_content.values():
  pairings, current_ingredient = scrape_chapter(chapter, pairings, current_ingredient, variable_pairings, used_keys)

# %%
# Number of edges
len(pairings)
# Out:
# 22219

# %% [markdown]
# ### Counting Nodes

# %%
# We put all the ingredients into a set so we can count the nodes
ingredients = set()
for ing1, ing2, _ in pairings:
  try: 
    int(ing2)
    continue
  except ValueError:
    ingredients.add(ing1)

# %%
# Number of Nodes
len(ingredients)
# Out:
# 602

# %% [markdown]
# ### Splitting pairings into normal (pairs) and complex (for 3+ ingredients)

# %%
# Recovering only the two ingredient pairings:
complex_pairings = []
two_ing_pairings = []
for ing1, ing2, weight in pairings:
  try: 
    int(ing2) 
    complex_pairings.append((ing1, ing2))
  except ValueError:
    two_ing_pairings.append((ing1, ing2, weight))

# %%
two_ing_pairings
# Out:
# [('achiote seeds', 'beef', 1),
#  ('achiote seeds', 'chicken', 1),
#  ('achiote seeds', 'chiles', 1),
#  ('achiote seeds', 'citrus (e.g., sour orange)', 1),
#  ('achiote seeds', 'fish', 1),
#  ('achiote seeds', 'game birds (e.g., duck, quail)', 1),
#  ('achiote seeds', 'garlic', 1),
#  ('achiote seeds', 'mexican cuisine, esp. yucatán oil', 3),
#  ('achiote seeds', 'pork', 1),
#  ('achiote seeds', 'shellfish, e.g., lobster, shrimp', 1),
#  ('achiote seeds', 'shrimp', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'almonds', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'barley', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'breads', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'cardamom', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'chile pepper', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'cinnamon', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'cloves', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'coriander', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'cucumber', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'cumin', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'dill', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'fennel', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'fruits, esp. dried', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'ginger', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'grapes', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'kebabs', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'lamb', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'mint', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'mushrooms', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'nuts, e.g., almonds', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'pasta', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'rice, basmati', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'sesame', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine',
#   'tomatoes and tomato sauce',
#   1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'turmeric', 1),
#  ('acidity (see sourness)\r\n  afghan cuisine', 'yogurt', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'bananas', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'bell peppers',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'braised dishes',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'chicken', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'chile peppers, esp. west african',
#   3),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'coconuts', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'corn', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'fish, esp. coastal',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'fruits, esp. tropical',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'garlic', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'goat', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'greens, esp. steamed or stewed',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'mangoes', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'melons', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'okra', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'onions', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'papayas', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'peanuts', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'peas, esp. black-eyed',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'plantains',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'soups', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'stews, esp. meat or vegetable',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'sweet potatoes',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)', 'tomatoes', 1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'watermelon',
#   1),
#  ('african cuisine (see also ethiopian and moroccan cuisines)',
#   'yams, esp. west african',
#   3),
#  ('african cuisine (north) (see also moroccan cuisine)', 'bell peppers', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'braised dishes', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'chicken', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'chickpeas', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'couscous', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'cucumbers', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'cumin', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'eggplant', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'fish', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'garlic', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'lamb', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'mint', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'parsley', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'rice', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'stewed dishes', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'tomatoes', 1),
#  ('african cuisine (north) (see also moroccan cuisine)', 'wheat', 1),
#  ('african cuisine (south)', 'beans', 1),
#  ('african cuisine (south)', 'carrots', 1),
#  ('african cuisine (south)', 'chile peppers', 1),
#  ('african cuisine (south)', 'cinnamon', 1),
#  ('african cuisine (south)', 'cloves', 1),
#  ('african cuisine (south)', 'fenugreek', 1),
#  ('african cuisine (south)', 'garlic', 1),
#  ('african cuisine (south)', 'ginger', 1),
#  ('african cuisine (south)', 'lamb', 1),
#  ('african cuisine (south)', 'onions', 1),
#  ('african cuisine (south)', 'peas', 1),
#  ('african cuisine (south)', 'pumpkin', 1),
#  ('african cuisine (south)', 'stews', 1),
#  ('african cuisine (south)', 'tomatoes', 1),
#  ('african cuisine (south)', 'turmeric', 1),
#  ('african cuisine (west)', 'bananas', 1),
#  ('african cuisine (west)', 'bell peppers', 1),
#  ('african cuisine (west)', 'braised dishes', 1),
#  ('african cuisine (west)', 'chicken', 1),
#  ('african cuisine (west)', 'chile peppers', 1),
#  ('african cuisine (west)', 'corn', 1),
#  ('african cuisine (west)', 'goat', 1),
#  ('african cuisine (west)', 'mangoes', 1),
#  ('african cuisine (west)', 'okra', 1),
#  ('african cuisine (west)', 'papayas', 1),
#  ('african cuisine (west)', 'peanuts', 1),
#  ('african cuisine (west)', 'plantains', 1),
#  ('african cuisine (west)', 'rice', 1),
#  ('african cuisine (west)', 'soups', 1),
#  ('african cuisine (west)', 'stewed dishes', 1),
#  ('african cuisine (west)', 'sweet potatoes', 1),
#  ('african cuisine (west)', 'tomatoes', 1),
#  ('african cuisine (west)', 'wheat', 1),
#  ('african cuisine (west)', 'yams', 1),
#  ('allspice', 'baked goods', 1),
#  ('allspice', 'beans', 1),
#  ('allspice',
#   'beef, esp. braised, corned, grilled, ground, raw, roasted, or stewed',
#   3),
#  ('allspice', 'beets', 1),
#  ('allspice', 'breads, esp. breakfast', 1),
#  ('allspice', 'cabbage', 1),
#  ('allspice', 'cakes', 1),
#  ('allspice', 'caribbean cuisine', 3),
#  ('allspice', 'carrots', 1),
#  ('allspice', 'chicken (e.g., jamaican style)', 3),
#  ('allspice', 'chickpeas', 1),
#  ('allspice', 'chile peppers', 1),
#  ('allspice', 'cinnamon', 1),
#  ('allspice', 'cloves', 1),
#  ('allspice', 'cookies', 1),
#  ('allspice', 'coriander', 1),
#  ('allspice', 'currants, esp. black', 1),
#  ('allspice', 'curries and curry powder', 1),
#  ('allspice', 'eastern mediterranean cuisine', 3),
#  ('allspice', 'eggplant', 1),
#  ('allspice', 'english cuisine', 3),
#  ('allspice', 'fish, esp. grilled', 1),
#  ('allspice', 'fruits, fruit compotes, and jams', 1),
#  ('allspice', 'game and game birds (e.g., quail)', 1),
#  ('allspice', 'garlic', 1),
#  ('allspice', 'ginger', 1),
#  ('allspice', 'goat', 1),
#  ('allspice', 'grains', 1),
#  ('allspice', 'ham', 1),
#  ('allspice', 'herring, pickled', 1),
#  ('allspice', 'indian cuisine', 3),
#  ('allspice', 'jamaican cuisine (e.g., jerk dishes)', 3),
#  ('allspice', 'ketchup', 1),
#  ('allspice', 'lamb', 1),
#  ('allspice', 'mace', 1),
#  ('allspice', 'meats, red, esp. braised, grilled, or roasted', 3),
#  ('allspice', 'mexican cuisine', 3),
#  ('allspice', 'middle eastern cuisine', 3),
#  ('allspice', 'mushrooms', 1),
#  ('allspice', 'mustard', 1),
#  ('allspice', 'north american cuisine', 3),
#  ('allspice', 'nutmeg', 1),
#  ('allspice', 'nuts', 1),
#  ('allspice', 'onions', 1),
#  ('allspice', 'pepper, black', 1),
#  ('allspice', 'pies', 1),
#  ('allspice', 'pineapple', 1),
#  ('allspice', 'pork', 1),
#  ('allspice', 'pumpkin', 3),
#  ('allspice', 'rabbit', 1),
#  ('allspice', 'rice', 1),
#  ('allspice', 'rosemary', 1),
#  ('allspice', 'salsas and sauces', 1),
#  ('allspice', 'sauerkraut', 1),
#  ('allspice', 'sausages', 1),
#  ('allspice', 'soups', 1),
#  ('allspice', 'spiced cakes', 1),
#  ('allspice', 'spinach', 1),
#  ('allspice', 'squash, winter', 1),
#  ('allspice', 'stews', 1),
#  ('allspice', 'stocks and broths, chicken', 1),
#  ('allspice', 'sweet potatoes', 1),
#  ('allspice', 'thyme', 1),
#  ('allspice', 'tomatoes', 1),
#  ('allspice', 'turnips', 1),
#  ('allspice', 'vegetables, esp. root', 1),
#  ('allspice', 'west indies cuisine', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'amaretto', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'anise, esp. green', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'apples', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'apricots', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'beans', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'blackberries', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'brandy', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'butter, unsalted', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'butterscotch', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'caramel', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cardamom', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cayenne', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cherries, esp. sour', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'chicken', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'chocolate, white', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cinnamon', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'coconut', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'coffee', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cornmeal', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'corn syrup', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'crab', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cranberries', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cream', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'cream cheese', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'crème fraîche', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'currants', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'figs', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'fish', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'french pastries', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'fruits, most', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'garlic', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'grapes', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'greek cuisine', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'greens, salad', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'hazelnuts', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'honey', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'ice cream', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'indian cuisine', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'italian sauces', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'lamb', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'lavender', 1),
#  ('almond oil (see oil, almond)\r\n  almonds',
#   'liqueurs, fruit (including orange)',
#   1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'mascarpone', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'mediterranean cuisine', 3),
#  ('almond oil (see oil, almond)\r\n  almonds',
#   'mexican beverages and mole sauces',
#   3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'milk, sweetened condensed', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'molasses', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'moroccan cuisine', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'nectarines', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'oats', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'olive oil', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'olives', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'paprika', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'passion fruit', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'peaches', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'pears', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'pecans', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'pepper, ground', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'pine nuts', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'plums', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'praline', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'prunes', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'quince', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'raisins, esp. white', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'raspberries', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'rhubarb', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'rice', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'rosemary', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'rum', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'shellfish', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'sherry', 1),
#  ('almond oil (see oil, almond)\r\n  almonds',
#   'spanish cuisine, esp. sauces',
#   3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'strawberries', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'tea', 1),
#  ('almond oil (see oil, almond)\r\n  almonds', 'turkish cuisine', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'vanilla', 3),
#  ('almond oil (see oil, almond)\r\n  almonds', 'walnuts', 1),
#  ('amaretto (sweet almond liqueur)', 'almonds', 1),
#  ('amaretto (sweet almond liqueur)', 'apricots', 1),
#  ('amaretto (sweet almond liqueur)', 'butter', 1),
#  ('amaretto (sweet almond liqueur)', 'cherries', 1),
#  ('amaretto (sweet almond liqueur)', 'chocolate', 1),
#  ('amaretto (sweet almond liqueur)', 'coffee', 1),
#  ('amaretto (sweet almond liqueur)', 'cream', 1),
#  ('amaretto (sweet almond liqueur)', 'hazelnuts', 1),
#  ('amaretto (sweet almond liqueur)', 'italian cuisine', 3),
#  ('amaretto (sweet almond liqueur)', 'peaches', 1),
#  ('amaretto (sweet almond liqueur)', 'pork', 1),
#  ('amaretto (sweet almond liqueur)', 'sugar', 1),
#  ('anchovies', 'almonds', 1),
#  ('anchovies', 'basil', 1),
#  ('anchovies', 'beans, green', 1),
#  ('anchovies', 'bell peppers, esp. roasted', 1),
#  ('anchovies', 'capers', 1),
#  ('anchovies', 'carrots', 1),
#  ('anchovies', 'cauliflower', 1),
#  ('anchovies', 'celery', 1),
#  ('anchovies', 'chives', 1),
#  ('anchovies', 'eggs, hard-boiled', 1),
#  ('anchovies', 'fennel', 1),
#  ('anchovies', 'garlic', 3),
#  ('anchovies', 'lemon, juice', 1),
#  ('anchovies', 'lobster', 1),
#  ('anchovies', 'mayonnaise', 1),
#  ('anchovies', 'mediterranean cuisine', 3),
#  ('anchovies', 'mustard (e.g., dijon)', 3),
#  ('anchovies', 'nectarines', 1),
#  ('anchovies', 'olive oil', 3),
#  ('anchovies', 'olives (e.g., black, green, niçoise)', 1),
#  ('anchovies', 'onions', 1),
#  ('anchovies', 'orange, zest', 1),
#  ('anchovies', 'parsley, flat-leaf', 1),
#  ('anchovies', 'pasta', 1),
#  ('anchovies', 'peppers, piquillo', 1),
#  ('anchovies', 'pizza', 1),
#  ('anchovies', 'potatoes', 1),
#  ('anchovies', 'puttanesca sauce (key ingredient)', 1),
#  ('anchovies', 'red pepper flakes', 1),
#  ('anchovies', 'romaine lettuce', 1),
#  ('anchovies', 'rosemary', 1),
#  ('anchovies', 'salads, esp. caesar (key ingredient)', 3),
#  ('anchovies', 'salmon', 1),
#  ('anchovies', 'shallots', 1),
#  ('anchovies', 'sherry, px', 3),
#  ('anchovies', 'tapenade (key ingredient)', 1),
#  ('anchovies', 'thyme', 1),
#  ('anchovies', 'tomatoes', 1),
#  ('anchovies', 'tuna', 1),
#  ('angelica', 'anise', 1),
#  ('angelica', 'apricots', 1),
#  ('angelica', 'candy', 1),
#  ('angelica', 'cream and ice cream', 1),
#  ('angelica', 'custards', 1),
#  ('angelica', 'desserts', 1),
#  ('angelica', 'fish', 1),
#  ('angelica', 'fruits', 1),
#  ('angelica', 'hazelnuts', 1),
#  ('angelica', 'juniper berries', 1),
#  ('angelica', 'lavender', 1),
#  ('angelica', 'lemon balm', 1),
#  ('angelica', 'liqueurs', 1),
#  ('angelica', 'mushrooms', 1),
#  ('angelica', 'oranges', 1),
#  ('angelica', 'pepper, black', 1),
#  ('angelica', 'plums', 1),
#  ('angelica', 'rhubarb', 5),
#  ('angelica', 'salads', 1),
#  ('angelica', 'shellfish', 1),
#  ('angelica', 'strawberries', 1),
#  ('anise (see also anise, star, and fennel)', 'almonds', 1),
#  ('anise (see also anise, star, and fennel)', 'apples', 1),
#  ('anise (see also anise, star, and fennel)',
#   'baked goods, esp. cakes, cookies',
#   1),
#  ('anise (see also anise, star, and fennel)', 'beets', 1),
#  ('anise (see also anise, star, and fennel)', 'breads, esp. rye', 1),
#  ('anise (see also anise, star, and fennel)', 'cabbage', 1),
#  ('anise (see also anise, star, and fennel)', 'cakes', 1),
#  ('anise (see also anise, star, and fennel)', 'cardamom', 1),
#  ('anise (see also anise, star, and fennel)', 'carrots', 1),
#  ('anise (see also anise, star, and fennel)', 'cauliflower', 1),
#  ('anise (see also anise, star, and fennel)',
#   'cheese, esp. goat and ricotta',
#   1),
#  ('anise (see also anise, star, and fennel)', 'chestnuts', 1),
#  ('anise (see also anise, star, and fennel)', 'chinese cuisine', 3),
#  ('anise (see also anise, star, and fennel)', 'cinnamon', 1),
#  ('anise (see also anise, star, and fennel)', 'cloves', 1),
#  ('anise (see also anise, star, and fennel)', 'coffee', 1),
#  ('anise (see also anise, star, and fennel)', 'cookies', 1),
#  ('anise (see also anise, star, and fennel)', 'crab', 1),
#  ('anise (see also anise, star, and fennel)', 'cream', 1),
#  ('anise (see also anise, star, and fennel)', 'cumin', 1),
#  ('anise (see also anise, star, and fennel)', 'dates', 1),
#  ('anise (see also anise, star, and fennel)', 'desserts', 1),
#  ('anise (see also anise, star, and fennel)', 'duck', 1),
#  ('anise (see also anise, star, and fennel)', 'fennel seeds', 1),
#  ('anise (see also anise, star, and fennel)', 'figs', 1),
#  ('anise (see also anise, star, and fennel)', 'fish', 3),
#  ('anise (see also anise, star, and fennel)', 'fruit', 1),
#  ('anise (see also anise, star, and fennel)', 'garlic', 1),
#  ('anise (see also anise, star, and fennel)', 'ginger', 1),
#  ('anise (see also anise, star, and fennel)', 'hazelnuts', 1),
#  ('anise (see also anise, star, and fennel)', 'lemon', 1),
#  ('anise (see also anise, star, and fennel)', 'lentils', 1),
#  ('anise (see also anise, star, and fennel)', 'mayonnaise', 1),
#  ('anise (see also anise, star, and fennel)', 'mediterranean cuisine', 3),
#  ('anise (see also anise, star, and fennel)', 'melon', 1),
#  ('anise (see also anise, star, and fennel)', 'middle eastern cuisine', 3),
#  ('anise (see also anise, star, and fennel)', 'mole sauce', 1),
#  ('anise (see also anise, star, and fennel)', 'moroccan cuisine', 3),
#  ('anise (see also anise, star, and fennel)', 'mussels', 1),
#  ('anise (see also anise, star, and fennel)', 'nutmeg', 1),
#  ('anise (see also anise, star, and fennel)', 'nuts', 1),
#  ('anise (see also anise, star, and fennel)', 'orange', 1),
#  ('anise (see also anise, star, and fennel)', 'parsnips', 1),
#  ('anise (see also anise, star, and fennel)', 'peaches', 1),
#  ('anise (see also anise, star, and fennel)', 'pears', 1),
#  ('anise (see also anise, star, and fennel)', 'pepper', 1),
#  ('anise (see also anise, star, and fennel)', 'pickles', 1),
#  ('anise (see also anise, star, and fennel)', 'pineapple', 1),
#  ('anise (see also anise, star, and fennel)', 'plums', 1),
#  ('anise (see also anise, star, and fennel)', 'pork', 1),
#  ('anise (see also anise, star, and fennel)', 'portuguese cuisine', 3),
#  ('anise (see also anise, star, and fennel)', 'provençal cuisine (french)', 3),
#  ('anise (see also anise, star, and fennel)', 'prunes', 1),
#  ('anise (see also anise, star, and fennel)', 'pumpkin', 1),
#  ('anise (see also anise, star, and fennel)', 'quince', 1),
#  ('anise (see also anise, star, and fennel)', 'raisins', 1),
#  ('anise (see also anise, star, and fennel)', 'rhubarb', 1),
#  ('anise (see also anise, star, and fennel)', 'salumi', 1),
#  ('anise (see also anise, star, and fennel)', 'sauerkraut', 1),
#  ('anise (see also anise, star, and fennel)', 'scandinavian cuisine', 3),
#  ('anise (see also anise, star, and fennel)', 'shellfish', 1),
#  ('anise (see also anise, star, and fennel)', 'soups, esp. fish', 1),
#  ('anise (see also anise, star, and fennel)', 'star anise', 1),
#  ('anise (see also anise, star, and fennel)', 'stews, esp. fish', 3),
#  ('anise (see also anise, star, and fennel)', 'strawberries', 1),
#  ('anise (see also anise, star, and fennel)', 'sugar', 1),
#  ('anise (see also anise, star, and fennel)', 'sweet potatoes', 1),
#  ('anise (see also anise, star, and fennel)', 'tea', 1),
#  ('anise (see also anise, star, and fennel)', 'vanilla', 1),
#  ('anise (see also anise, star, and fennel)', 'vegetables, root', 1),
#  ('anise (see also anise, star, and fennel)', 'vietnamese cuisine', 3),
#  ('anise (see also anise, star, and fennel)', 'walnuts', 1),
#  ('anise hyssop', 'basil', 1),
#  ('anise hyssop', 'beans, green', 1),
#  ('anise hyssop', 'beets', 1),
#  ('anise hyssop', 'berries, esp. blueberries', 1),
#  ('anise hyssop', 'beverages', 1),
#  ('anise hyssop', 'carrots', 1),
#  ('anise hyssop', 'cherries', 1),
#  ('anise hyssop', 'chervil', 1),
#  ('anise hyssop', 'chicken', 1),
#  ('anise hyssop', 'cream and ice cream', 1),
#  ('anise hyssop', 'currants', 1),
#  ('anise hyssop', 'custards', 1),
#  ('anise hyssop', 'desserts', 1),
#  ('anise hyssop', 'fennel bulb', 1),
#  ('anise hyssop', 'fish', 1),
#  ('anise hyssop', 'fruits, esp. summer', 3),
#  ('anise hyssop', 'honey', 1),
#  ('anise hyssop', 'lavender', 1),
#  ('anise hyssop', 'lemon', 1),
#  ('anise hyssop', 'lychees', 1),
#  ('anise hyssop', 'marjoram', 1),
#  ('anise hyssop', 'melons', 1),
#  ('anise hyssop', 'mint', 1),
#  ('anise hyssop', 'nectarines', 1),
#  ('anise hyssop', 'oranges', 1),
#  ('anise hyssop', 'parsley', 1),
#  ('anise hyssop', 'parsnips', 1),
#  ('anise hyssop', 'peaches', 1),
#  ('anise hyssop', 'pears', 1),
#  ('anise hyssop', 'plums', 1),
#  ('anise hyssop', 'pork', 1),
#  ('anise hyssop', 'raspberries', 1),
#  ('anise hyssop', 'rice', 1),
#  ('anise hyssop', 'shellfish (e.g., shrimp)', 1),
#  ('anise hyssop', 'shrimp', 1),
#  ('anise hyssop', 'spinach', 1),
#  ('anise hyssop', 'squash, winter', 1),
#  ('anise hyssop', 'stone fruits (e.g., peaches)', 1),
#  ('anise hyssop', 'sweet potatoes', 1),
#  ('anise hyssop', 'tarragon', 1),
#  ('anise hyssop', 'teas', 1),
#  ('anise hyssop', 'tomatoes', 1),
#  ('anise hyssop', 'vegetables, root', 1),
#  ('anise hyssop', 'watermelon', 1),
#  ('anise hyssop', 'zucchini', 1),
#  ('anise, star', 'baked goods (e.g., breads, pastries)', 1),
#  ('anise, star', 'beef', 1),
#  ('anise, star', 'beverages', 1),
#  ('anise, star', 'cardamom', 1),
#  ('anise, star', 'chestnuts', 1),
#  ('anise, star', 'chicken', 1),
#  ('anise, star', 'chile peppers', 1),
#  ('anise, star', 'chili powder', 1),
#  ('anise, star', 'chinese cuisine', 3),
#  ('anise, star', 'chocolate, esp. milk', 1),
#  ('anise, star', 'cinnamon', 1),
#  ('anise, star', 'citrus zest', 1),
#  ('anise, star', 'cloves', 1),
#  ('anise, star', 'coriander', 1),
#  ('anise, star', 'cumin', 1),
#  ('anise, star', 'curry powder (ingredient)', 1),
#  ('anise, star', 'duck', 1),
#  ('anise, star', 'eggs', 1),
#  ('anise, star', 'fennel seeds', 1),
#  ('anise, star', 'figs', 1),
#  ('anise, star', 'fish', 1),
#  ('anise, star', 'five-spice powder', 3),
#  ('anise, star', 'fruits, esp. tropical', 1),
#  ('anise, star', 'garlic', 1),
#  ('anise, star', 'ginger', 1),
#  ('anise, star', 'indian cuisine', 3),
#  ('anise, star', 'kumquats', 1),
#  ('anise, star', 'leeks', 1),
#  ('anise, star', 'lemongrass', 1),
#  ('anise, star', 'lime, zest', 1),
#  ('anise, star', 'liqueurs', 1),
#  ('anise, star', 'mace', 1),
#  ('anise, star', 'malaysian cuisine', 3),
#  ('anise, star', 'mangoes', 1),
#  ('anise, star', 'maple syrup', 1),
#  ('anise, star', 'meats, esp. fatty', 1),
#  ('anise, star', 'nutmeg', 1),
#  ('anise, star', 'orange, zest', 1),
#  ('anise, star', 'oxtails', 1),
#  ('anise, star', 'pears, esp. poached', 1),
#  ('anise, star', 'pineapple', 1),
#  ('anise, star', 'plums, esp. poached', 1),
#  ('anise, star', 'pork', 1),
#  ('anise, star', 'poultry', 1),
#  ('anise, star', 'pumpkin', 1),
#  ('anise, star', 'raspberries', 1),
#  ('anise, star', 'root vegetables', 1),
#  ('anise, star', 'salmon', 1),
#  ('anise, star', 'sauces', 1),
#  ('anise, star', 'scallions', 1),
#  ('anise, star', 'scallops', 1),
#  ('anise, star', 'shellfish', 1),
#  ('anise, star', 'shrimp', 1),
#  ('anise, star', 'soups', 1),
#  ('anise, star', 'soy sauce', 1),
#  ('anise, star', 'stews', 1),
#  ('anise, star', 'sweet potatoes', 1),
#  ('anise, star', 'tamarind', 1),
#  ('anise, star', 'teas', 1),
#  ('anise, star', 'tuna', 1),
#  ('anise, star', 'turmeric', 1),
#  ('anise, star', 'vanilla', 1),
#  ('anise, star', 'vegetables, esp. root', 1),
#  ('anise, star', 'vietnamese cuisine (e.g.,pho)', 3),
#  ('anise, star', 'wine, rice', 1),
#  ('apples', 'almonds', 1),
#  ('apples', 'apple cider or juice', 1),
#  ('apples', 'applejack', 1),
#  ('apples', 'armagnac', 3),
#  ('apples', 'bacon', 1),
#  ('apples', 'bay leaf', 1),
#  ('apples', 'beef', 1),
#  ('apples', 'blackberries', 1),
#  ('apples', 'bourbon', 1),
#  ('apples', 'brandy, esp. apple', 1),
#  ('apples', 'brioche', 1),
#  ('apples', 'butter, unsalted', 3),
#  ('apples', 'butterscotch', 1),
#  ('apples', 'cabbage, red', 1),
#  ('apples', 'calvados', 3),
#  ('apples', 'caramel', 3),
#  ('apples', 'cardamom', 1),
#  ('apples', 'celery', 1),
#  ('apples', 'celery root', 1),
#  ('apples', 'chestnuts', 1),
#  ('apples', 'chicken', 1),
#  ('apples', 'chives', 1),
#  ('apples', 'cider', 1),
#  ('apples', 'cinnamon', 5),
#  ('apples', 'cloves', 1),
#  ('apples', 'cognac', 1),
#  ('apples', 'cointreau', 3),
#  ('apples', 'coriander', 1),
#  ('apples', 'cranberries', 1),
#  ('apples', 'cream and ice cream', 3),
#  ('apples', 'crème anglaise (sauce)', 1),
#  ('apples', 'crème fraîche', 1),
#  ('apples', 'cumin', 1),
#  ('apples', 'currants, esp. black, and currant jelly', 1),
#  ('apples', 'curry powder', 1),
#  ('apples', 'custards', 1),
#  ('apples', 'dates', 1),
#  ('apples', 'duck', 1),
#  ('apples', 'eggplant', 1),
#  ('apples', 'fennel', 1),
#  ('apples', 'french cuisine, esp. from normandy', 3),
#  ('apples', 'frisée', 1),
#  ('apples', 'ginger', 1),
#  ('apples', 'goose', 1),
#  ('apples', 'hazelnuts', 1),
#  ('apples', 'honey, esp. chestnut, wildflower', 1),
#  ('apples', 'horseradish', 1),
#  ('apples', 'ice cream', 1),
#  ('apples', 'kirsch', 3),
#  ('apples', 'lavender', 1),
#  ('apples', 'lemon thyme', 1),
#  ('apples', 'lychees', 1),
#  ('apples', 'madeira', 3),
#  ('apples', 'maple syrup', 1),
#  ('apples', 'mayonnaise', 1),
#  ('apples', 'meringue', 1),
#  ('apples', 'molasses', 1),
#  ('apples', 'mustard', 1),
#  ('apples', 'nutmeg', 1),
#  ('apples', 'nuts', 1),
#  ('apples', 'oatmeal and oats', 1),
#  ('apples', 'olive oil', 1),
#  ('apples', 'onions, esp. green, red', 1),
#  ('apples', 'parsley', 1),
#  ('apples', 'peanuts and peanut butter', 1),
#  ('apples', 'pears', 1),
#  ('apples', 'pecans', 1),
#  ('apples', 'pepper, black', 1),
#  ('apples', 'pies', 1),
#  ('apples', 'pineapple', 1),
#  ('apples', 'pine nuts', 1),
#  ('apples', 'pistachios', 1),
#  ('apples', 'plums', 1),
#  ('apples', 'pomegranates', 1),
#  ('apples', 'pork', 1),
#  ('apples', 'poultry', 1),
#  ('apples', 'prunes', 1),
#  ('apples', 'puff pastry', 1),
#  ('apples', 'pumpkin', 1),
#  ('apples', 'quince', 1),
#  ('apples', 'raisins, esp. seedless, white', 1),
#  ('apples', 'rhubarb', 1),
#  ('apples', 'rice and rice pudding', 1),
#  ('apples', 'rosemary', 1),
#  ('apples', 'salt, kosher', 1),
#  ('apples', 'sauerkraut', 1),
#  ('apples', 'sherry', 1),
#  ('apples', 'soups', 1),
#  ('apples', 'sour cream', 1),
#  ('apples', 'star anise', 1),
#  ('apples', 'sweet potatoes', 1),
#  ('apples', 'tarragon', 1),
#  ('apples', 'tarts', 1),
#  ('apples', 'thyme', 1),
#  ('apples', 'vanilla', 1),
#  ('apples', 'verjus', 1),
#  ('apples', 'vermouth', 1),
#  ('apples', 'walnuts', 3),
#  ('apples', 'yogurt', 1),
#  ('apricots — in general', 'allspice', 1),
#  ('apricots — in general', 'almonds', 3),
#  ('apricots — in general', 'amaretto', 1),
#  ('apricots — in general', 'anise', 1),
#  ('apricots — in general', 'apples', 1),
#  ('apricots — in general', 'apricot brandy', 1),
#  ('apricots — in general', 'bananas', 1),
#  ('apricots — in general', 'blackberries', 1),
#  ('apricots — in general', 'blueberries', 1),
#  ('apricots — in general', 'brandy', 1),
#  ('apricots — in general', 'butter, unsalted', 1),
#  ('apricots — in general', 'caramel', 1),
#  ('apricots — in general', 'cardamom', 1),
#  ('apricots — in general', 'cayenne', 1),
#  ('apricots — in general', 'cheese (e.g., brie, reblochon, ricotta)', 3),
#  ('apricots — in general', 'cheesecake', 1),
#  ('apricots — in general', 'cherries', 1),
#  ('apricots — in general', 'chicken', 1),
#  ('apricots — in general', 'chocolate, white', 1),
#  ('apricots — in general', 'cinnamon', 1),
#  ('apricots — in general', 'coconut', 1),
#  ('apricots — in general', 'coffee and espresso', 1),
#  ('apricots — in general', 'cognac', 1),
#  ('apricots — in general', 'coriander', 1),
#  ('apricots — in general', 'cranberries', 1),
#  ('apricots — in general', 'cream and ice cream', 3),
#  ('apricots — in general', 'crème anglaise', 1),
#  ('apricots — in general', 'custards (e.g., crème brûlée)', 1),
#  ('apricots — in general', 'duck', 1),
#  ('apricots — in general', 'foie gras', 1),
#  ('apricots — in general', 'game', 1),
#  ('apricots — in general', 'garlic', 1),
#  ('apricots — in general', 'ginger', 1),
#  ('apricots — in general', 'hazelnuts', 1),
#  ('apricots — in general', 'honey', 1),
#  ('apricots — in general', 'ice cream, esp. vanilla', 1),
#  ('apricots — in general', 'kirsch', 3),
#  ('apricots — in general', 'lamb', 1),
#  ('apricots — in general', 'lemon verbena', 1),
#  ('apricots — in general', 'maple syrup', 1),
#  ('apricots — in general', 'mascarpone', 1),
#  ('apricots — in general', 'mediterranean cuisine', 3),
#  ('apricots — in general', 'meringue', 1),
#  ('apricots — in general', 'middle eastern stews', 3),
#  ('apricots — in general', 'mint (garnish)', 1),
#  ('apricots — in general', 'moroccan cuisine', 3),
#  ('apricots — in general', 'nectarines', 1),
#  ('apricots — in general', 'nutmeg', 1),
#  ('apricots — in general', 'nuts', 1),
#  ('apricots — in general', 'oats and oatmeal', 1),
#  ('apricots — in general', 'onions, esp. yellow', 1),
#  ('apricots — in general', 'orange liqueur', 1),
#  ('apricots — in general', 'peaches', 1),
#  ('apricots — in general', 'pepper, black', 1),
#  ('apricots — in general', 'pineapple', 1),
#  ('apricots — in general', 'pine nuts', 1),
#  ('apricots — in general', 'pistachios', 1),
#  ('apricots — in general', 'plums', 1),
#  ('apricots — in general', 'pork', 1),
#  ('apricots — in general', 'poultry', 1),
#  ('apricots — in general', 'praline', 1),
#  ('apricots — in general', 'prunes', 1),
#  ('apricots — in general', 'raisins', 1),
#  ('apricots — in general', 'raspberries', 1),
#  ('apricots — in general', 'rice pudding', 1),
#  ('apricots — in general', 'rosemary', 1),
#  ('apricots — in general', 'rum', 1),
#  ('apricots — in general', 'saffron', 1),
#  ('apricots — in general', 'salads, esp. fruit, green', 1),
#  ('apricots — in general', 'sauternes', 3),
#  ('apricots — in general', 'sour cream', 1),
#  ('apricots — in general', 'strawberries', 1),
#  ('apricots — in general', 'vanilla', 5),
#  ('apricots — in general', 'vinegar, red wine', 1),
#  ('apricots — in general', 'walnuts', 1),
#  ('apricots — in general', 'yogurt', 1),
#  ('apricots, dried', 'allspice', 1),
#  ('apricots, dried', 'cherries, dried', 1),
#  ('apricots, dried', 'cinnamon', 1),
#  ('apricots, dried', 'currants', 1),
#  ('apricots, dried', 'custard', 1),
#  ('apricots, dried', 'french toast', 3),
#  ('apricots, dried', 'ginger', 1),
#  ('apricots, dried', 'hazelnuts', 1),
#  ('apricots, dried', 'honey', 1),
#  ('apricots, dried', 'ice cream', 1),
#  ('apricots, dried', 'madeira', 3),
#  ('apricots, dried', 'moroccan cuisine', 3),
#  ('apricots, dried', 'pancakes/crepes', 1),
#  ('apricots, dried', 'pistachios', 1),
#  ('apricots, dried', 'pork', 1),
#  ('apricots, dried', 'prunes', 1),
#  ('apricots, dried', 'pumpkin seeds', 1),
#  ('apricots, dried', 'raisins', 1),
#  ('apricots, dried', 'rice pudding', 1),
#  ('apricots, dried', 'sugar', 1),
#  ('apricots, dried', 'tamarind paste', 1),
#  ('apricots, dried', 'vanilla', 1),
#  ('apricots, dried', 'wine, sweet white (e.g., muscat)', 3),
#  ('argentinian cuisine (see also latin american cuisine)', 'beef', 1),
#  ('argentinian cuisine (see also latin american cuisine)', 'corn', 1),
#  ('argentinian cuisine (see also latin american cuisine)', 'peaches', 1),
#  ('argentinian cuisine (see also latin american cuisine)', 'pumpkin', 1),
#  ('argentinian cuisine (see also latin american cuisine)',
#   'sweet potatoes',
#   1),
#  ('aroma', 'chocolate', 1),
#  ('aroma', 'cinnamon', 1),
#  ('aroma', 'herbs', 1),
#  ('aroma', 'pineapple', 1),
#  ('aroma', 'sous-vide cooking', 1),
#  ('aroma', 'spices', 1),
#  ('aroma', 'star anise', 1),
#  ('aroma', 'truffles', 1),
#  ('aroma', 'vanilla', 1),
#  ('artichokes', 'anchovies', 1),
#  ('artichokes', 'arugula', 1),
#  ('artichokes', 'bacon', 1),
#  ('artichokes', 'basil', 1),
#  ('artichokes', 'bay leaf', 1),
#  ('artichokes', 'beans, fava', 1),
#  ('artichokes', 'beets', 1),
#  ('artichokes', 'bell peppers, esp. roasted', 1),
#  ('artichokes', 'bread crumbs', 1),
#  ('artichokes', 'butter', 1),
#  ('artichokes', 'capers', 1),
#  ('artichokes', 'carrots', 1),
#  ('artichokes', 'cashews', 1),
#  ('artichokes', 'celery', 1),
#  ('artichokes', 'chervil', 1),
#  ('artichokes', 'chicken', 1),
#  ('artichokes', 'chives', 1),
#  ('artichokes', 'coriander', 1),
#  ('artichokes', 'cream', 1),
#  ('artichokes', 'crème fraîche', 1),
#  ('artichokes', 'french cuisine', 3),
#  ('artichokes', 'garlic', 3),
#  ('artichokes', 'grapefruit', 1),
#  ('artichokes', 'ham (e.g., serrano)', 3),
#  ('artichokes', 'hazelnuts', 1),
#  ('artichokes', 'hollandaise sauce', 1),
#  ('artichokes', 'italian cuisine', 3),
#  ('artichokes', 'leeks', 1),
#  ('artichokes', 'lobster', 1),
#  ('artichokes', 'mayonnaise', 1),
#  ('artichokes', 'mediterranean cuisine', 3),
#  ('artichokes', 'mint', 3),
#  ('artichokes', 'moroccan cuisine', 3),
#  ('artichokes', 'mushrooms', 1),
#  ('artichokes', 'mustard, dijon', 3),
#  ('artichokes', 'olive oil', 3),
#  ('artichokes', 'onions, esp. sweet and yellow', 3),
#  ('artichokes', 'orange', 1),
#  ('artichokes', 'pancetta', 1),
#  ('artichokes', 'parsley, flat-leaf', 3),
#  ('artichokes', 'pesto', 1),
#  ('artichokes', 'piquillo peppers', 1),
#  ('artichokes', 'potatoes', 1),
#  ('artichokes', 'prosciutto', 1),
#  ('artichokes', 'radicchio', 1),
#  ('artichokes', 'red pepper flakes', 1),
#  ('artichokes', 'rice', 1),
#  ('artichokes', 'risotto', 1),
#  ('artichokes', 'rosemary', 1),
#  ('artichokes', 'saffron', 1),
#  ('artichokes', 'sage', 1),
#  ('artichokes', 'salads', 1),
#  ('artichokes', 'salt, kosher', 3),
#  ('artichokes', 'savory', 1),
#  ('artichokes', 'shallots', 1),
#  ('artichokes', 'shellfish (e.g., crab)', 1),
#  ('artichokes', 'sherry, dry', 1),
#  ('artichokes', 'shrimp', 1),
#  ('artichokes', 'soy sauce', 1),
#  ('artichokes', 'spanish cuisine', 3),
#  ('artichokes', 'spinach', 1),
#  ('artichokes', 'stock, chicken', 1),
#  ('artichokes', 'sugar (pinch)', 1),
#  ('artichokes', 'tapenade', 1),
#  ('artichokes', 'tarragon, fresh', 1),
#  ('artichokes', 'thyme, fresh', 3),
#  ('artichokes', 'tomatoes', 3),
#  ('artichokes', 'truffles, black', 1),
#  ('artichokes', 'tuna', 1),
#  ('artichokes', 'vinaigrette', 1),
#  ('artichokes', 'walnuts', 1),
#  ('artichokes', 'wine, dry white', 3),
#  ('artichokes', 'yogurt', 1),
#  ('artichokes, jerusalem', 'bacon', 1),
#  ('artichokes, jerusalem', 'bay leaf', 1),
#  ('artichokes, jerusalem', 'butter', 1),
#  ('artichokes, jerusalem', 'celery', 1),
#  ('artichokes, jerusalem', 'cheese, goat', 1),
#  ('artichokes, jerusalem', 'chervil', 1),
#  ('artichokes, jerusalem', 'chives', 1),
#  ('artichokes, jerusalem', 'coriander', 1),
#  ('artichokes, jerusalem', 'cream', 1),
#  ('artichokes, jerusalem', 'cumin', 1),
#  ('artichokes, jerusalem', 'dill', 1),
#  ('artichokes, jerusalem', 'fennel leaves', 1),
#  ('artichokes, jerusalem', 'fennel seeds', 1),
#  ('artichokes, jerusalem', 'garlic', 1),
#  ('artichokes, jerusalem', 'ginger', 1),
#  ('artichokes, jerusalem', 'hazelnuts', 1),
#  ('artichokes, jerusalem', 'leeks', 1),
#  ('artichokes, jerusalem', 'lemon, juice', 1),
#  ('artichokes, jerusalem', 'mace', 1),
#  ('artichokes, jerusalem', 'meats, esp. roasted', 1),
#  ('artichokes, jerusalem', 'morels', 1),
#  ('artichokes, jerusalem', 'nutmeg', 1),
#  ('artichokes, jerusalem', 'olive oil', 1),
#  ('artichokes, jerusalem', 'onions', 1),
#  ('artichokes, jerusalem', 'parsley, flat-leaf', 1),
#  ('artichokes, jerusalem', 'pepper, black', 1),
#  ('artichokes, jerusalem', 'potatoes', 1),
#  ('artichokes, jerusalem', 'rosemary', 1),
#  ('artichokes, jerusalem', 'sage', 1),
#  ('artichokes, jerusalem', 'salmon', 1),
#  ('artichokes, jerusalem', 'salt, sea', 1),
#  ('artichokes, jerusalem', 'shallots', 1),
#  ('artichokes, jerusalem', 'stock, chicken', 1),
#  ('artichokes, jerusalem', 'tarragon', 1),
#  ('artichokes, jerusalem', 'thyme', 1),
#  ('artichokes, jerusalem', 'vinegar', 1),
#  ('artichokes, jerusalem', 'wine, dry white', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'basil', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'beans, white',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'bell peppers, esp. red',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'chicken', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'cilantro', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'clams', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'corn', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'cucumbers', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'dill', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'eggs, esp. hard-boiled',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'endive', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'fennel', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'fish (e.g., salmon, tuna)',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'garlic', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'grapes', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'italian cuisine',
#   3),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'lemon juice',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'lettuces', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'lovage', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'mediterranean cuisine',
#   3),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'mesclun salad greens (key ingredient)',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'mint', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'mushrooms', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'mussels', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'nuts', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'olive oil', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'olives, black',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'oranges, esp. blood',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'pancetta', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'parsley', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'pasta', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'pears', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'pesto', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'pine nuts', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'potatoes', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'prosciutto',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'radicchio', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'radishes', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'risotto', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'salads and salad greens',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'salt, esp. sea',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'shallots', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'shellfish (e.g., shrimp)',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'tomatoes', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)', 'tuna', 1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'vinaigrettes',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'red wine, sherry, white wine',
#   1),
#  ('arugula (see also lettuces — bitter greens and chicories)',
#   'watercress',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'anchovies',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'artichokes',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'basil',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'bay leaf',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'beets',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'bread crumbs',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'butter, brown',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'butter, unsalted',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'capers',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'caraway seeds',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'carrots',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'cayenne',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'chervil',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'chives',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'crab',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'cream, heavy',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'crème fraîche',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'dill',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'eggs and egg dishes (e.g., coddled, hard-boiled omelets)',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'fava beans',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'french cuisine',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'garlic',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'ginger',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'ham',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'hollandaise sauce',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'italian cuisine',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'leeks',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'lemon thyme',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'lime, juice',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'lobster',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'marsala wine',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'mascarpone',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'mayonnaise',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'mushrooms, esp. cremini, morels, shiitakes',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'mustard, dijon',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'olive oil',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'onions, esp. spring, yellow',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'orange',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'oysters',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'pancetta',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'parsley, flat-leaf',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'pasta',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'peas',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'peppers, piquillo',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'pistachios',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'potatoes',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'prosciutto',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'ramps',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'rice and risotto',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'saffron',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'sage',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'salmon',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'savory',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'scallions',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'sesame seeds',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'shallots',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'shrimp',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'soups',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'sour cream',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'soy sauce',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'spinach',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'tarragon',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'thyme, fresh',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'tomatoes',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'turnips',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'vermouth',
#   1),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'wine, dry white (e.g., muscat)',
#   3),
#  ('asian cuisine (see chinese, japanese, vietnamese, etc. cuisines)\r\n  asparagus',
#   'yogurt',
#   1),
#  ('asparagus, white', 'butter', 1),
#  ('asparagus, white', 'cheese, parmesan', 3),
#  ('asparagus, white', 'chicken', 1),
#  ('asparagus, white', 'crab', 1),
#  ('asparagus, white', 'ham', 1),
#  ('asparagus, white', 'hazelnuts', 1),
#  ('asparagus, white', 'lemon', 1),
#  ('asparagus, white', 'mushrooms (e.g., cepes, morels, porcini)', 1),
#  ('asparagus, white', 'mustard', 1),
#  ('asparagus, white', 'oil, truffle', 1),
#  ('asparagus, white', 'olive oil', 1),
#  ('asparagus, white', 'parsley', 1),
#  ('asparagus, white', 'pepper, black', 1),
#  ('asparagus, white', 'salt, sea', 1),
#  ('asparagus, white', 'shallots', 1),
#  ('asparagus, white', 'shrimp', 1),
#  ('asparagus, white', 'stock, chicken', 1),
#  ('asparagus, white', 'sugar (pinch)', 1),
#  ('asparagus, white', 'tarragon', 1),
#  ('asparagus, white', 'vinaigrette', 1),
#  ('asparagus, white', 'wine, riesling', 3),
#  ('asparagus, white', 'apples (astringent-sweet)', 1),
#  ('asparagus, white', 'artichokes', 1),
#  ('asparagus, white', 'asparagus', 1),
#  ('asparagus, white', 'bananas, unripe (astringent-sweet)', 1),
#  ('asparagus, white', 'basil', 1),
#  ('asparagus, white', 'beans', 1),
#  ('asparagus, white', 'berries', 1),
#  ('asparagus, white', 'broccoli', 1),
#  ('asparagus, white', 'buckwheat', 1),
#  ('asparagus, white', 'cashews', 1),
#  ('asparagus, white', 'cauliflower', 1),
#  ('asparagus, white', 'coffee', 1),
#  ('asparagus, white', 'cranberries', 1),
#  ('asparagus, white', 'figs (astringent-sweet)', 1),
#  ('asparagus, white', 'grapes (astringent-sour-sweet)', 1),
#  ('asparagus, white', 'hazelnuts', 1),
#  ('asparagus, white', 'herbs', 1),
#  ('asparagus, white', 'honey', 1),
#  ('asparagus, white', 'legumes', 1),
#  ('asparagus, white', 'lentils', 1),
#  ('asparagus, white', 'lettuce', 1),
#  ('asparagus, white', 'mace', 1),
#  ('asparagus, white', 'marjoram', 1),
#  ('asparagus, white', 'okra', 1),
#  ('asparagus, white', 'parsley', 1),
#  ('asparagus, white', 'peaches (astringent-sweet)', 1),
#  ('asparagus, white', 'pears (astringent-sweet)', 1),
#  ('asparagus, white', 'persimmons', 1),
#  ('asparagus, white', 'plums (astringent-sweet)', 1),
#  ...]

# %%
len(two_ing_pairings)
# Out:
# 20763

# %% [markdown]
# ### Some cleaning of data

# %%
from collections import Counter

# %%
# Check the most common words in the ingredients:

words = []
for ing1, ing2, _ in two_ing_pairings:
  words.extend(ing1.split(' ') + ing2.split(' '))

word_counts = Counter(words)
word_counts.most_common(50)
# Out:
# [('—', 3368),
#  ('(see', 3120),
#  ('in', 2428),
#  ('also', 2426),
#  ('cuisine', 1780),
#  ('general', 1713),
#  ('and', 1358),
#  ('esp.', 1007),
#  ('general)', 656),
#  ('(aka', 642),
#  ('cheese,', 600),
#  ('squash,', 560),
#  ('oil', 541),
#  ('beans,', 511),
#  ('beef', 498),
#  ('white', 498),
#  ('oil,', 483),
#  ('(e.g.,', 472),
#  ('cream', 470),
#  ('pork', 467),
#  ('nuts', 464),
#  ('fish', 434),
#  ('chicken', 403),
#  ('mushrooms', 399),
#  ('garlic', 394),
#  ('lemon', 379),
#  ('black', 376),
#  ('potatoes', 371),
#  ('red', 358),
#  ('ginger', 340),
#  ('thyme', 340),
#  ('seeds', 336),
#  ('fennel', 336),
#  ('juice', 324),
#  ('vinegar,', 319),
#  ('sauce', 315),
#  ('tomatoes', 309),
#  ('sweet', 307),
#  ('greens', 307),
#  ('leaf', 289),
#  ('olive', 288),
#  ('celery', 281),
#  ('chile', 277),
#  ('mint', 274),
#  ('coconut', 273),
#  ('pepper,', 272),
#  ('peppers', 271),
#  ('/', 268),
#  ('basil', 267),
#  ('cinnamon', 258)]

# %%
splitters = ['—', 'esp.', '(e.g.', 'eg', 'esp', 'and', 'or', 'aka', '/', 'see', 'also', 'e.g.']
deleters = ['also', 'in general']
length = 0


while length != len(two_ing_pairings):
  length = len(two_ing_pairings)
  for idx, (ing1, ing2, weight) in enumerate(two_ing_pairings):
    for splitter in splitters:
      ing1_ = re.sub(r'[.,!?:;\"\'-()]', '', ing1)
      ing2_ = re.sub(r'[.,!?:;\"\'-()]', '', ing2)

      if splitter in ing1_.split(' '):
        print('->', splitter, '<-')
        print('inp: ', ing1_)
        new_vals = ing1_.split(splitter)
        new_vals = [val.strip() for val in new_vals if val != '']
        print('Deleting...', two_ing_pairings[idx])
        del two_ing_pairings[idx]
        for val in new_vals:
          if val == '':
            continue
          delete_flag = False
          for delete in deleters:
            if delete == val.strip():
              delete_flag = True
              break
          if delete_flag:
            continue
          val_ = re.sub('\,|\;|\)|\(|-', '', val.strip())
          #print('~~', val)
          print('ADDING:', (val_, ing2_, weight))
          two_ing_pairings.append((val_, ing2_, weight))

      ## ing2
      if splitter in ing2_.split(' '):
        new_vals = ing2_.split(splitter)
        new_vals = [val.strip() for val in new_vals if val != '']
        print('Deleting...', two_ing_pairings[idx])
        del two_ing_pairings[idx]
        for val in new_vals:
          if val == '':
            continue
          delete_flag = False
          for delete in deleters:
            if delete == val.strip():
              delete_flag = True
              break
          if delete_flag:
            continue
          val_ = re.sub('\,|\;|\)|\(|-', '', val.strip())
          #print('~~', val)
          print('ADDING:', (ing1_, val_, weight))
          two_ing_pairings.append((ing1_, val_, weight))
# Out:
# Streaming output truncated to the last 5000 lines.
# ADDING: ('pecans', 'breads cookies pies', 1)
# -> — <-
# inp:  nuts — in general
# Deleting... ('nuts — in general', 'grapes', 1)
# ADDING: ('nuts', 'grapes', 1)
# -> — <-
# inp:  nuts — in general
# Deleting... ('nuts — in general', 'rum', 1)
# ADDING: ('nuts', 'rum', 1)
# -> — <-
# inp:  nuts — in general
# Deleting... ('nuts — in general', 'arugula', 1)
# ADDING: ('nuts', 'arugula', 1)
# -> — <-
# inp:  nuts — in general
# Deleting... ('nuts — in general', 'lemon', 1)
# ADDING: ('nuts', 'lemon', 1)
# -> — <-
# inp:  nuts — in general
# Deleting... ('nuts — in general', 'avoid', 3)
# ADDING: ('nuts', 'avoid', 3)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'asparagus white', 1)
# ADDING: ('game', 'asparagus white', 1)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'curry paste thai yellow', 3)
# ADDING: ('game', 'curry paste thai yellow', 3)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'pine nuts', 1)
# ADDING: ('game', 'pine nuts', 1)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'asparagus accompaniment', 1)
# ADDING: ('fish', 'asparagus accompaniment', 1)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'coriander', 1)
# ADDING: ('fish', 'coriander', 1)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'licorice', 1)
# ADDING: ('fish', 'licorice', 1)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'potatoes', 3)
# ADDING: ('fish', 'potatoes', 3)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'tomatoes sun-dried', 1)
# ADDING: ('fish', 'tomatoes sun-dried', 1)
# -> — <-
# inp:  greens — in general
# Deleting... ('greens — in general', 'almonds', 1)
# ADDING: ('greens', 'almonds', 1)
# -> — <-
# inp:  greens — in general
# Deleting... ('greens — in general', 'indian cuisine', 3)
# ADDING: ('greens', 'indian cuisine', 3)
# -> — <-
# inp:  greens — in general
# Deleting... ('greens — in general', 'prosciutto', 1)
# ADDING: ('greens', 'prosciutto', 1)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'bay leaf', 1)
# ADDING: ('game', 'bay leaf', 1)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'mustard', 1)
# ADDING: ('game', 'mustard', 1)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'sweet potatoes', 1)
# ADDING: ('game', 'sweet potatoes', 1)
# -> — <-
# inp:  lettuces — bitter greens
# Deleting... ('lettuces — bitter greens', 'basil', 1)
# ADDING: ('lettuces', 'basil', 1)
# ADDING: ('bitter greens', 'basil', 1)
# -> — <-
# inp:  lettuces — bitter greens
# Deleting... ('lettuces — bitter greens', 'clams', 1)
# ADDING: ('lettuces', 'clams', 1)
# ADDING: ('bitter greens', 'clams', 1)
# -> — <-
# inp:  lettuces — bitter greens
# Deleting... ('lettuces — bitter greens', 'endive', 1)
# ADDING: ('lettuces', 'endive', 1)
# ADDING: ('bitter greens', 'endive', 1)
# -> — <-
# inp:  lettuces — bitter greens
# Deleting... ('lettuces — bitter greens', 'italian cuisine', 3)
# ADDING: ('lettuces', 'italian cuisine', 3)
# ADDING: ('bitter greens', 'italian cuisine', 3)
# -> — <-
# inp:  lettuces — bitter greens
# Deleting... ('lettuces — bitter greens', 'mesclun salad greens key ingredient', 1)
# ADDING: ('lettuces', 'mesclun salad greens key ingredient', 1)
# ADDING: ('bitter greens', 'mesclun salad greens key ingredient', 1)
# -> — <-
# inp:  lettuces — bitter greens
# Deleting... ('lettuces — bitter greens', 'olive oil', 1)
# ADDING: ('lettuces', 'olive oil', 1)
# ADDING: ('bitter greens', 'olive oil', 1)
# -> — <-
# inp:  lettuces — bitter greens
# Deleting... ('lettuces — bitter greens', 'pasta', 1)
# ADDING: ('lettuces', 'pasta', 1)
# ADDING: ('bitter greens', 'pasta', 1)
# -> — <-
# inp:  lettuces — bitter greens
# Deleting... ('lettuces — bitter greens', 'prosciutto', 1)
# ADDING: ('lettuces', 'prosciutto', 1)
# ADDING: ('bitter greens', 'prosciutto', 1)
# -> see <-
# inp:  basil see
# Deleting... ('basil see', 'eggs', 3)
# ADDING: ('basil', 'eggs', 3)
# -> see <-
# inp:  basil see
# Deleting... ('basil see', 'green curries', 3)
# ADDING: ('basil', 'green curries', 3)
# -> also <-
# inp:  also basil thai
# Deleting... ('also basil thai', 'green curries', 3)
# ADDING: ('basil thai', 'green curries', 3)
# -> — <-
# inp:  cheese — in general
# Deleting... ('cheese — in general', 'dates figs', 1)
# ADDING: ('cheese', 'dates figs', 1)
# -> also <-
# inp:  also specific greens
# Deleting... ('also specific greens', 'new and/or red', 1)
# ADDING: ('specific greens', 'new and/or red', 1)
# -> see <-
# inp:  temperature see
# Deleting... ('temperature see', 'chilled dishes', 1)
# ADDING: ('temperature', 'chilled dishes', 1)
# -> also <-
# inp:  also cantaloupe honeydew etc
# Deleting... ('also cantaloupe honeydew etc', 'in cocktails', 1)
# ADDING: ('cantaloupe honeydew etc', 'in cocktails', 1)
# -> — <-
# inp:  melon/ muskmelons — in general
# Deleting... ('melon/ muskmelons — in general', 'ice creams', 1)
# ADDING: ('melon/ muskmelons', 'ice creams', 1)
# -> also <-
# inp:  also snap peas
# Deleting... ('also snap peas', 'carrot juice', 3)
# ADDING: ('snap peas', 'carrot juice', 3)
# -> — <-
# inp:  lettuces — bitter greens
# Deleting... ('lettuces — bitter greens', 'cilantro', 1)
# ADDING: ('lettuces', 'cilantro', 1)
# ADDING: ('bitter greens', 'cilantro', 1)
# -> — <-
# inp:  lettuces — bitter greens
# Deleting... ('lettuces — bitter greens', 'parsley', 1)
# ADDING: ('lettuces', 'parsley', 1)
# ADDING: ('bitter greens', 'parsley', 1)
# -> and <-
# inp:  also basil thai and lemon basil
# Deleting... ('also basil thai and lemon basil', 'cream', 1)
# ADDING: ('also basil thai', 'cream', 1)
# ADDING: ('lemon basil', 'cream', 1)
# -> also <-
# inp:  also basil thai and lemon basil
# Deleting... ('basil thai', 'mussels', 1)
# ADDING: ('basil thai and lemon basil', 'cream', 1)
# -> and <-
# inp:  also bass sea and bass striped
# Deleting... ('also bass sea and bass striped', 'tomatoes', 1)
# ADDING: ('also bass sea', 'tomatoes', 1)
# ADDING: ('bass striped', 'tomatoes', 1)
# -> also <-
# inp:  also bass sea and bass striped
# Deleting... ('beans cannellini', 'clams', 1)
# ADDING: ('bass sea and bass striped', 'tomatoes', 1)
# -> — <-
# inp:  beef — in general
# Deleting... ('beef — in general', 'p', 1)
# ADDING: ('beef', 'p', 1)
# -> aka <-
# inp:  chard aka swiss chard
# Deleting... ('chard aka swiss chard', 'yellow', 1)
# ADDING: ('chard', 'yellow', 1)
# ADDING: ('swiss chard', 'yellow', 1)
# Deleting... ('also specific cheeses', 'dates esp medjool', 3)
# ADDING: ('also specific cheeses', 'dates', 3)
# ADDING: ('also specific cheeses', 'medjool', 3)
# -> also <-
# inp:  also specific cheeses
# Deleting... ('cheese blue', 'mustard dijon', 3)
# ADDING: ('specific cheeses', 'dates esp medjool', 3)
# Deleting... ('chèvre', 'cherries sour or sweet', 1)
# ADDING: ('chèvre', 'cherries sour', 1)
# ADDING: ('chèvre', 'sweet', 1)
# -> — <-
# inp:  cheese goat — fresh
# Deleting... ('cheese goat — fresh', 'greens salad', 1)
# ADDING: ('cheese goat', 'greens salad', 1)
# ADDING: ('fresh', 'greens salad', 1)
# -> — <-
# inp:  endive lettuces — bitter greens
# Deleting... ('endive lettuces — bitter greens', 'cilantro', 1)
# ADDING: ('endive lettuces', 'cilantro', 1)
# ADDING: ('bitter greens', 'cilantro', 1)
# -> or <-
# inp:  coldness of indoor or outdoor temperature see
# Deleting... ('coldness of indoor or outdoor temperature see', 'dishes', 1)
# ADDING: ('coldness of indo', 'dishes', 1)
# ADDING: ('outdo', 'dishes', 1)
# ADDING: ('temperature see', 'dishes', 1)
# -> see <-
# inp:  coldness of indoor or outdoor temperature see
# Deleting... ('outdo', 'cream and cream-based sauces and dishes', 1)
# ADDING: ('coldness of indoor or outdoor temperature', 'dishes', 1)
# -> see <-
# inp:  in general see individual fish seafood
# Deleting... ('in general see individual fish seafood', 'white', 1)
# ADDING: ('individual fish seafood', 'white', 1)
# Deleting... ('in general see also specific greens', 'cheese esp grated', 3)
# ADDING: ('in general see also specific greens', 'cheese', 3)
# ADDING: ('in general see also specific greens', 'grated', 3)
# -> see <-
# inp:  in general see also specific greens
# Deleting... ('also specific greens', 'cheese esp grated', 3)
# ADDING: ('also specific greens', 'cheese esp grated', 3)
# -> also <-
# inp:  in general see also specific greens
# Deleting... ('greens salad', 'croutons', 1)
# ADDING: ('in general see', 'cheese esp grated', 3)
# ADDING: ('specific greens', 'cheese esp grated', 3)
# -> — <-
# inp:  lamb — in general
# Deleting... ('lamb — in general', 'new', 1)
# ADDING: ('lamb', 'new', 1)
# -> — <-
# inp:  lettuces — mesclun greens ie mixed baby lettuces
# Deleting... ('lettuces — mesclun greens ie mixed baby lettuces', 'vinaigrettes', 1)
# ADDING: ('lettuces', 'vinaigrettes', 1)
# ADDING: ('mesclun greens ie mixed baby lettuces', 'vinaigrettes', 1)
# -> — <-
# inp:  melon/ muskmelons — in general
# Deleting... ('melon/ muskmelons — in general', 'mint', 3)
# ADDING: ('melon/ muskmelons', 'mint', 3)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'artichokes jerusalem', 3)
# ADDING: ('fish', 'artichokes jerusalem', 3)
# -> — <-
# inp:  mushrooms — in general
# Deleting... ('mushrooms — in general', 'paprika', 1)
# ADDING: ('mushrooms', 'paprika', 1)
# Deleting... ('specific mushrooms', 'sherry dry eg manzanilla', 1)
# ADDING: ('specific mushrooms', 'sherry dry', 1)
# ADDING: ('specific mushrooms', 'manzanilla', 1)
# -> — <-
# inp:  nuts — in general
# Deleting... ('nuts — in general', 'artichokes', 1)
# ADDING: ('nuts', 'artichokes', 1)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'arugula', 1)
# ADDING: ('game', 'arugula', 1)
# -> and <-
# inp:  leeks onions and scallions
# Deleting... ('leeks onions and scallions', 'cheese parmesan', 3)
# ADDING: ('leeks onions', 'cheese parmesan', 3)
# ADDING: ('scallions', 'cheese parmesan', 3)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'arugula', 1)
# ADDING: ('fish', 'arugula', 1)
# -> see <-
# inp:  salmon see
# Deleting... ('salmon see', 'parsley flat-leaf', 3)
# ADDING: ('salmon', 'parsley flat-leaf', 3)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'scallions', 1)
# ADDING: ('fish', 'scallions', 1)
# -> — <-
# inp:  greens — in general
# Deleting... ('greens — in general', 'bacon', 1)
# ADDING: ('greens', 'bacon', 1)
# Deleting... ('greens', 'onions esp sweet', 1)
# ADDING: ('greens', 'onions', 1)
# ADDING: ('greens', 'sweet', 1)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'bacon', 1)
# ADDING: ('game', 'bacon', 1)
# -> also <-
# inp:  also ethiopian
# Deleting... ('also ethiopian', 'west african', 3)
# ADDING: ('ethiopian', 'west african', 3)
# Deleting... ('african cuisine', 'meat or vegetable', 1)
# ADDING: ('african cuisine', 'meat', 1)
# ADDING: ('african cuisine', 'vegetable', 1)
# -> also <-
# inp:  also anise star
# Deleting... ('also anise star', 'soups', 1)
# ADDING: ('anise star', 'soups', 1)
# -> also <-
# inp:  also basil thai
# Deleting... ('also basil thai', 'omelets', 3)
# ADDING: ('basil thai', 'omelets', 3)
# -> also <-
# inp:  also basil thai
# Deleting... ('also basil thai', 'soups', 3)
# ADDING: ('basil thai', 'soups', 3)
# -> also <-
# inp:  also specific cheeses
# Deleting... ('also specific cheeses', 'neutralflavored', 1)
# ADDING: ('specific cheeses', 'neutralflavored', 1)
# -> — <-
# inp:  nuts — in general
# Deleting... ('nuts — in general', 'breads cookies pies', 1)
# ADDING: ('nuts', 'breads cookies pies', 1)
# -> also <-
# inp:  also pumpkin squash acorn
# Deleting... ('also pumpkin squash acorn', 'porcini', 1)
# ADDING: ('pumpkin squash acorn', 'porcini', 1)
# -> — <-
# inp:  nuts — in general
# Deleting... ('nuts — in general', 'pancakes waffles', 1)
# ADDING: ('nuts', 'pancakes waffles', 1)
# -> also <-
# inp:  also ethiopian
# Deleting... ('also ethiopian', 'meat', 1)
# ADDING: ('ethiopian', 'meat', 1)
# Deleting... ('basil thai', 'gs and', 3)
# ADDING: ('basil thai', 'gs', 3)
# -> see <-
# inp:  basil see
# Deleting... ('basil see', 'cream', 1)
# ADDING: ('basil', 'cream', 1)
# -> see <-
# inp:  bass see
# Deleting... ('bass see', 'tomatoes', 1)
# ADDING: ('bass', 'tomatoes', 1)
# -> — <-
# inp:  cheese — in general
# Deleting... ('cheese — in general', 'medjool', 3)
# ADDING: ('cheese', 'medjool', 3)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'fino', 1)
# ADDING: ('fish', 'fino', 1)
# -> — <-
# inp:  mushrooms — in general
# Deleting... ('mushrooms — in general', 'manzanilla', 1)
# ADDING: ('mushrooms', 'manzanilla', 1)
# -> — <-
# inp:  nuts — in general
# Deleting... ('nuts — in general', 'pasta sauces', 1)
# ADDING: ('nuts', 'pasta sauces', 1)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'frisée', 1)
# ADDING: ('fish', 'frisée', 1)
# -> — <-
# inp:  greens — in general
# Deleting... ('greens — in general', 'striped bass', 1)
# ADDING: ('greens', 'striped bass', 1)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'yellow', 1)
# ADDING: ('game', 'yellow', 1)
# Deleting... ('basil thai', 'gs and', 3)
# ADDING: ('basil thai', 'gs', 3)
# -> and <-
# inp:  specific fish and shellfish
# Deleting... ('specific fish and shellfish', 'apples', 1)
# ADDING: ('specific fish', 'apples', 1)
# ADDING: ('shellfish', 'apples', 1)
# -> see <-
# inp:  anise see
# Deleting... ('anise see', 'cookies', 1)
# ADDING: ('anise', 'cookies', 1)
# -> see <-
# inp:  arugula see
# Deleting... ('arugula see', 'nuts', 1)
# ADDING: ('arugula', 'nuts', 1)
# -> and <-
# inp:  bitter greens and chicories
# Deleting... ('bitter greens and chicories', 'nuts', 1)
# ADDING: ('bitter greens', 'nuts', 1)
# ADDING: ('chicories', 'nuts', 1)
# -> see <-
# inp:  basil see
# Deleting... ('basil see', 'cinnamon', 1)
# ADDING: ('basil', 'cinnamon', 1)
# -> see <-
# inp:  basil see
# Deleting... ('basil see', 'tarragon', 1)
# ADDING: ('basil', 'tarragon', 1)
# -> see <-
# inp:  bass see
# Deleting... ('bass see', 'sole', 1)
# ADDING: ('bass', 'sole', 1)
# -> see <-
# inp:  beans cannellini see
# Deleting... ('beans cannellini see', 'onions', 3)
# ADDING: ('beans cannellini', 'onions', 3)
# -> also <-
# inp:  also beans white
# Deleting... ('also beans white', 'spanish', 3)
# ADDING: ('beans white', 'spanish', 3)
# Deleting... ('beef', 'onions esp green pearl white', 3)
# ADDING: ('beef', 'onions', 3)
# ADDING: ('beef', 'green pearl white', 3)
# Deleting... ('short ribs', 'green pearl white or yellow', 3)
# ADDING: ('short ribs', 'green pearl white', 3)
# ADDING: ('short ribs', 'yellow', 3)
# -> aka <-
# inp:  chickpeas aka garbanzo beans
# Deleting... ('chickpeas aka garbanzo beans', 'smoked', 1)
# ADDING: ('chickpeas', 'smoked', 1)
# ADDING: ('garbanzo beans', 'smoked', 1)
# Deleting... ('garbanzo beans', 'paprika esp smoked', 1)
# ADDING: ('garbanzo beans', 'paprika', 1)
# ADDING: ('garbanzo beans', 'smoked', 1)
# -> see <-
# inp:  in general see
# Deleting... ('in general see', 'madeira', 3)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'madeira', 3)
# ADDING: ('game', 'madeira', 3)
# -> see <-
# inp:  in general see
# Deleting... ('in general see', 'sweet potatoes', 1)
# -> — <-
# inp:  greens — in general
# Deleting... ('greens — in general', 'sweet potatoes', 1)
# ADDING: ('greens', 'sweet potatoes', 1)
# -> see <-
# inp:  kaffir lime leaf see
# Deleting... ('kaffir lime leaf see', 'lime juice', 1)
# ADDING: ('kaffir lime leaf', 'lime juice', 1)
# -> and <-
# inp:  kaffir limes and kaffir lime leaf
# Deleting... ('kaffir limes and kaffir lime leaf', 'lime juice', 1)
# ADDING: ('kaffir limes', 'lime juice', 1)
# ADDING: ('kaffir lime leaf', 'lime juice', 1)
# -> and <-
# inp:  bitter greens and chicories
# Deleting... ('bitter greens and chicories', 'rices', 1)
# ADDING: ('bitter greens', 'rices', 1)
# ADDING: ('chicories', 'rices', 1)
# -> — <-
# inp:  lettuces — bitter greens
# Deleting... ('lettuces — bitter greens', 'rices', 1)
# ADDING: ('lettuces', 'rices', 1)
# ADDING: ('bitter greens', 'rices', 1)
# Deleting... ('also cantaloupe honeydew etc', 'anise seeds and anise hyssop', 1)
# ADDING: ('also cantaloupe honeydew etc', 'anise seeds', 1)
# ADDING: ('also cantaloupe honeydew etc', 'anise hyssop', 1)
# -> also <-
# inp:  also cantaloupe honeydew etc
# Deleting... ('also cantaloupe honeydew etc', 'anise seeds', 1)
# ADDING: ('cantaloupe honeydew etc', 'anise seeds and anise hyssop', 1)
# -> see <-
# inp:  monkfish see
# Deleting... ('monkfish see', 'cardamom', 1)
# ADDING: ('monkfish', 'cardamom', 1)
# -> see <-
# inp:  in general see
# Deleting... ('in general see', 'chestnuts', 1)
# -> — <-
# inp:  mushrooms — in general
# Deleting... ('mushrooms — in general', 'chestnuts', 1)
# ADDING: ('mushrooms', 'chestnuts', 1)
# Deleting... ('porcini', 'cream / milk', 1)
# ADDING: ('porcini', 'cream', 1)
# ADDING: ('porcini', 'milk', 1)
# -> — <-
# inp:  mushrooms — porcini
# Deleting... ('mushrooms — porcini', 'cream', 1)
# ADDING: ('mushrooms', 'cream', 1)
# ADDING: ('porcini', 'cream', 1)
# -> also <-
# inp:  also nuts
# Deleting... ('also nuts', 'indonesian cuisine', 3)
# ADDING: ('nuts', 'indonesian cuisine', 3)
# -> also <-
# inp:  also snap peas
# Deleting... ('also snap peas', 'cinnamon', 1)
# ADDING: ('snap peas', 'cinnamon', 1)
# -> — <-
# inp:  peas — in general
# Deleting... ('peas — in general', 'cinnamon', 1)
# ADDING: ('peas', 'cinnamon', 1)
# Deleting... ('pistachios', 'cream and ice cream', 1)
# ADDING: ('pistachios', 'cream', 1)
# ADDING: ('pistachios', 'ice cream', 1)
# -> — <-
# inp:  also nuts — in general
# Deleting... ('also nuts — in general', 'ice cream', 1)
# ADDING: ('also nuts', 'ice cream', 1)
# -> also <-
# inp:  also nuts — in general
# Deleting... ('pork', 'mint', 1)
# ADDING: ('nuts — in general', 'ice cream', 1)
# -> see <-
# inp:  rabbit see
# Deleting... ('rabbit see', 'carrots', 1)
# ADDING: ('rabbit', 'carrots', 1)
# -> see <-
# inp:  salmon see
# Deleting... ('salmon see', 'cardamom', 1)
# ADDING: ('salmon', 'cardamom', 1)
# Deleting... ('salmon', 'rice eg basmati sushi', 1)
# ADDING: ('salmon', 'rice', 1)
# ADDING: ('salmon', 'basmati sushi', 1)
# -> — <-
# inp:  also fish — in general
# Deleting... ('also fish — in general', 'basmati sushi', 1)
# ADDING: ('also fish', 'basmati sushi', 1)
# -> also <-
# inp:  also fish — in general
# Deleting... ('chorizo', 'carrots', 1)
# ADDING: ('fish — in general', 'basmati sushi', 1)
# -> see <-
# inp:  spinach see
# Deleting... ('spinach see', 'curry', 1)
# ADDING: ('spinach', 'curry', 1)
# -> see <-
# inp:  squash acorn see
# Deleting... ('squash acorn see', 'nutmeg', 1)
# ADDING: ('squash acorn', 'nutmeg', 1)
# -> see <-
# inp:  squash butternut see
# Deleting... ('squash butternut see', 'parsnips', 1)
# ADDING: ('squash butternut', 'parsnips', 1)
# -> see <-
# inp:  squash winter see
# Deleting... ('squash winter see', 'bacon', 1)
# ADDING: ('squash winter', 'bacon', 1)
# -> see <-
# inp:  tangerines see oranges mandarin tarragon
# Deleting... ('tangerines see oranges mandarin tarragon', 'fruit green', 1)
# ADDING: ('tangerines', 'fruit green', 1)
# ADDING: ('oranges mandarin tarragon', 'fruit green', 1)
# Deleting... ('oranges mandarin tarragon', 'salads eg fruit green', 1)
# ADDING: ('oranges mandarin tarragon', 'salads', 1)
# ADDING: ('oranges mandarin tarragon', 'fruit green', 1)
# -> see <-
# inp:  white truffle oil see
# Deleting... ('white truffle oil see', 'risotto', 1)
# ADDING: ('white truffle oil', 'risotto', 1)
# -> and <-
# inp:  truffles white and white truffle oil
# Deleting... ('truffles white and white truffle oil', 'risotto', 1)
# ADDING: ('truffles white', 'risotto', 1)
# ADDING: ('white truffle oil', 'risotto', 1)
# Deleting... ('venison see', 'cherries dried or fresh esp black', 1)
# ADDING: ('venison see', 'cherries dried or fresh', 1)
# ADDING: ('venison see', 'black', 1)
# Deleting... ('venison', 'black', 1)
# ADDING: ('venison see', 'cherries dried', 1)
# ADDING: ('venison see', 'fresh esp black', 1)
# -> see <-
# inp:  venison see
# Deleting... ('venison', 'cherries dried', 1)
# ADDING: ('venison', 'cherries dried or fresh esp black', 1)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'cherries dried', 1)
# ADDING: ('game', 'cherries dried', 1)
# -> see <-
# inp:  fruit tropical see
# Deleting... ('fruit tropical see', 'ice cream', 1)
# ADDING: ('fruit tropical', 'ice cream', 1)
# -> or <-
# inp:  hotness of indoor or outdoor temperature
# Deleting... ('hotness of indoor or outdoor temperature', 'chilled dishes', 1)
# ADDING: ('hotness of indo', 'chilled dishes', 1)
# ADDING: ('outdo', 'chilled dishes', 1)
# ADDING: ('temperature', 'chilled dishes', 1)
# -> or <-
# inp:  hotness of indoor or outdoor temperature
# Deleting... ('hotness of indoor or outdoor temperature', 'beverages', 1)
# ADDING: ('hotness of indo', 'beverages', 1)
# ADDING: ('outdo', 'beverages', 1)
# ADDING: ('temperature', 'beverages', 1)
# -> see <-
# inp:  pecans see
# Deleting... ('pecans see', 'baked goods', 1)
# ADDING: ('pecans', 'baked goods', 1)
# -> also <-
# inp:  also nuts
# Deleting... ('also nuts', 'breads cookies pies', 1)
# ADDING: ('nuts', 'breads cookies pies', 1)
# -> see <-
# inp:  arugula see
# Deleting... ('arugula see', 'cilantro', 1)
# ADDING: ('arugula', 'cilantro', 1)
# -> see <-
# inp:  arugula see
# Deleting... ('arugula see', 'parsley', 1)
# ADDING: ('arugula', 'parsley', 1)
# -> also <-
# inp:  also basil thai
# Deleting... ('also basil thai', 'cream', 1)
# ADDING: ('basil thai', 'cream', 1)
# -> also <-
# inp:  also bass sea
# Deleting... ('also bass sea', 'tomatoes', 1)
# ADDING: ('bass sea', 'tomatoes', 1)
# -> see <-
# inp:  in general see
# Deleting... ('in general see', 'dates', 3)
# -> see <-
# inp:  in general see
# Deleting... ('in general see', 'medjool', 3)
# -> see <-
# inp:  chicory see
# Deleting... ('chicory see', 'cilantro', 1)
# ADDING: ('chicory', 'cilantro', 1)
# -> or <-
# inp:  coldness of indoor or outdoor temperature
# Deleting... ('coldness of indoor or outdoor temperature', 'cream', 1)
# ADDING: ('coldness of indo', 'cream', 1)
# ADDING: ('outdo', 'cream', 1)
# ADDING: ('temperature', 'cream', 1)
# -> see <-
# inp:  temperature see
# Deleting... ('temperature see', 'creambased sauces', 1)
# ADDING: ('temperature', 'creambased sauces', 1)
# -> also <-
# inp:  also specific greens
# Deleting... ('also specific greens', 'cheese', 3)
# ADDING: ('specific greens', 'cheese', 3)
# -> — <-
# inp:  greens — in general see
# Deleting... ('greens — in general see', 'grated', 3)
# ADDING: ('greens', 'grated', 3)
# ADDING: ('in general see', 'grated', 3)
# -> see <-
# inp:  greens — in general see
# Deleting... ('lamb', 'red', 1)
# ADDING: ('greens — in general', 'grated', 3)
# -> see <-
# inp:  mesclun greens ie mixed baby lettuces see
# Deleting... ('mesclun greens ie mixed baby lettuces see', 'vinaigrettes', 1)
# ADDING: ('mesclun greens ie mixed baby lettuces', 'vinaigrettes', 1)
# -> see <-
# inp:  wild leeks see
# Deleting... ('wild leeks see', 'cheese parmesan', 3)
# ADDING: ('wild leeks', 'cheese parmesan', 3)
# -> see <-
# inp:  spinach see
# Deleting... ('spinach see', 'onions', 1)
# ADDING: ('spinach', 'onions', 1)
# -> also <-
# inp:  also greens
# Deleting... ('also greens', 'sweet', 1)
# ADDING: ('greens', 'sweet', 1)
# Deleting... ('basil thai', 'gs and', 3)
# ADDING: ('basil thai', 'gs', 3)
# -> see <-
# inp:  in general see
# Deleting... ('in general see', 'anise seeds', 1)
# -> see <-
# inp:  in general see
# Deleting... ('in general see', 'anise hyssop', 1)
# -> see <-
# inp:  peanut butter see
# Deleting... ('peanut butter see', 'indonesian cuisine', 3)
# ADDING: ('peanut butter', 'indonesian cuisine', 3)
# -> and <-
# inp:  peanuts and peanut butter
# Deleting... ('peanuts and peanut butter', 'indonesian cuisine', 3)
# ADDING: ('peanuts', 'indonesian cuisine', 3)
# ADDING: ('peanut butter', 'indonesian cuisine', 3)
# -> see <-
# inp:  pistachios see
# Deleting... ('pistachios see', 'cream', 1)
# ADDING: ('pistachios', 'cream', 1)
# -> also <-
# inp:  also nuts
# Deleting... ('also nuts', 'ice cream', 1)
# ADDING: ('nuts', 'ice cream', 1)
# Deleting... ('nuts', 'cream and ice cream', 1)
# ADDING: ('nuts', 'cream', 1)
# ADDING: ('nuts', 'ice cream', 1)
# -> see <-
# inp:  salmon see
# Deleting... ('salmon see', 'rice', 1)
# ADDING: ('salmon', 'rice', 1)
# -> also <-
# inp:  also fish
# Deleting... ('also fish', 'basmati sushi', 1)
# ADDING: ('fish', 'basmati sushi', 1)
# Deleting... ('fish', 'rice eg basmati sushi', 1)
# ADDING: ('fish', 'rice', 1)
# ADDING: ('fish', 'basmati sushi', 1)
# Deleting... ('venison', 'cherries dried or fresh', 1)
# ADDING: ('venison', 'cherries dried', 1)
# ADDING: ('venison', 'fresh', 1)
# Deleting... ('game', 'cherries dried or fresh', 1)
# ADDING: ('game', 'cherries dried', 1)
# ADDING: ('game', 'fresh', 1)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'cherries dried', 1)
# ADDING: ('game', 'cherries dried', 1)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'black', 1)
# ADDING: ('game', 'black', 1)
# -> see <-
# inp:  in general see
# Deleting... ('in general see', 'cheese', 3)
# -> — <-
# inp:  greens — in general
# Deleting... ('greens — in general', 'cheese', 3)
# ADDING: ('greens', 'cheese', 3)
# -> — <-
# inp:  greens — in general
# Deleting... ('greens — in general', 'cheese', 3)
# ADDING: ('greens', 'cheese', 3)
# -> see <-
# inp:  venison see
# Deleting... ('venison see', 'cherries dried', 1)
# ADDING: ('venison', 'cherries dried', 1)
# -> also <-
# inp:  also game
# Deleting... ('also game', 'fresh', 1)
# ADDING: ('game', 'fresh', 1)
# -> see <-
# inp:  african cuisine see also ethiopian
# Deleting... ('african cuisine see also ethiopian', 'chicken', 1)
# ADDING: ('african cuisine', 'chicken', 1)
# ADDING: ('also ethiopian', 'chicken', 1)
# -> also <-
# inp:  african cuisine see also ethiopian
# Deleting... ('moroccan cuisines', 'chicken', 1)
# ADDING: ('african cuisine see', 'chicken', 1)
# ADDING: ('ethiopian', 'chicken', 1)
# -> and <-
# inp:  also ethiopian and moroccan cuisines
# Deleting... ('also ethiopian and moroccan cuisines', 'chicken', 1)
# ADDING: ('also ethiopian', 'chicken', 1)
# ADDING: ('moroccan cuisines', 'chicken', 1)
# -> also <-
# inp:  also ethiopian and moroccan cuisines
# Deleting... ('african cuisine see', 'chicken', 1)
# ADDING: ('ethiopian and moroccan cuisines', 'chicken', 1)
# -> see <-
# inp:  anise see also anise star
# Deleting... ('anise see also anise star', 'sugar', 1)
# ADDING: ('anise', 'sugar', 1)
# ADDING: ('also anise star', 'sugar', 1)
# -> also <-
# inp:  anise see also anise star
# Deleting... ('fennel', 'sugar', 1)
# ADDING: ('anise see', 'sugar', 1)
# ADDING: ('anise star', 'sugar', 1)
# -> and <-
# inp:  also anise star and fennel
# Deleting... ('also anise star and fennel', 'sugar', 1)
# ADDING: ('also anise star', 'sugar', 1)
# ADDING: ('fennel', 'sugar', 1)
# -> also <-
# inp:  also anise star and fennel
# Deleting... ('anise see', 'sugar', 1)
# ADDING: ('anise star and fennel', 'sugar', 1)
# Deleting... ('apricots', 'cream and ice cream', 3)
# ADDING: ('apricots', 'cream', 3)
# ADDING: ('apricots', 'ice cream', 3)
# -> — <-
# inp:  apricots — in general
# Deleting... ('apricots — in general', 'ice cream', 3)
# ADDING: ('apricots', 'ice cream', 3)
# -> see <-
# inp:  basil see also basil thai
# Deleting... ('basil see also basil thai', 'shrimp', 1)
# ADDING: ('basil', 'shrimp', 1)
# ADDING: ('also basil thai', 'shrimp', 1)
# -> also <-
# inp:  basil see also basil thai
# Deleting... ('lemon basil', 'shrimp', 1)
# ADDING: ('basil see', 'shrimp', 1)
# ADDING: ('basil thai', 'shrimp', 1)
# -> and <-
# inp:  also basil thai and lemon basil
# Deleting... ('also basil thai and lemon basil', 'shrimp', 1)
# ADDING: ('also basil thai', 'shrimp', 1)
# ADDING: ('lemon basil', 'shrimp', 1)
# -> also <-
# inp:  also basil thai and lemon basil
# Deleting... ('basil see', 'shrimp', 1)
# ADDING: ('basil thai and lemon basil', 'shrimp', 1)
# -> aka <-
# inp:  beans fava aka broad beans
# Deleting... ('beans fava aka broad beans', 'greens bitter', 1)
# ADDING: ('beans fava', 'greens bitter', 1)
# ADDING: ('broad beans', 'greens bitter', 1)
# -> or <-
# inp:  broad beans or horse beans
# Deleting... ('broad beans or horse beans', 'greens bitter', 1)
# ADDING: ('broad beans', 'greens bitter', 1)
# ADDING: ('h', 'greens bitter', 1)
# ADDING: ('se beans', 'greens bitter', 1)
# Deleting... ('beef', 'tomatoes and tomato sauce', 1)
# ADDING: ('beef', 'tomatoes', 1)
# ADDING: ('beef', 'tomato sauce', 1)
# -> — <-
# inp:  beef — oxtails
# Deleting... ('beef — oxtails', 'tomatoes', 1)
# ADDING: ('beef', 'tomatoes', 1)
# ADDING: ('oxtails', 'tomatoes', 1)
# Deleting... ('cheese goat', 'tomatoes and tomato jam', 1)
# ADDING: ('cheese goat', 'tomatoes', 1)
# ADDING: ('cheese goat', 'tomato jam', 1)
# -> — <-
# inp:  cheese goat — fresh
# Deleting... ('cheese goat — fresh', 'tomatoes and tomato jam', 1)
# ADDING: ('cheese goat', 'tomatoes and tomato jam', 1)
# ADDING: ('fresh', 'tomatoes and tomato jam', 1)
# Deleting... ('chèvre', 'tomatoes and tomato jam', 1)
# ADDING: ('cheese goat — fresh', 'tomatoes', 1)
# ADDING: ('cheese goat — fresh', 'tomato jam', 1)
# -> — <-
# inp:  cheese goat — fresh eg chèvre
# Deleting... ('cheese goat — fresh eg chèvre', 'tomato jam', 1)
# ADDING: ('cheese goat', 'tomato jam', 1)
# ADDING: ('fresh eg chèvre', 'tomato jam', 1)
# -> eg <-
# inp:  cheese goat — fresh eg chèvre
# Deleting... ('cheese sheep’s milk', 'panforte', 1)
# ADDING: ('cheese goat — fresh', 'tomato jam', 1)
# ADDING: ('chèvre', 'tomato jam', 1)
# -> aka <-
# inp:  chickpeas aka garbanzo beans
# Deleting... ('chickpeas aka garbanzo beans', 'yogurt', 3)
# ADDING: ('chickpeas', 'yogurt', 3)
# ADDING: ('garbanzo beans', 'yogurt', 3)
# Deleting... ('chickpeas', 'yogurt eg indian cuisine', 3)
# ADDING: ('chickpeas', 'yogurt', 3)
# ADDING: ('chickpeas', 'indian cuisine', 3)
# Deleting... ('chocolate / cocoa', 'coffee / espresso esp with dark chocolate', 5)
# ADDING: ('chocolate / cocoa', 'coffee /', 5)
# ADDING: ('chocolate / cocoa', 'resso', 5)
# ADDING: ('chocolate / cocoa', 'with dark chocolate', 5)
# -> / <-
# inp:  chocolate / cocoa
# Deleting... ('chocolate / cocoa — in general', 'coffee /', 5)
# ADDING: ('chocolate', 'coffee / espresso esp with dark chocolate', 5)
# ADDING: ('cocoa', 'coffee / espresso esp with dark chocolate', 5)
# Deleting... ('chocolate / cocoa — in general', 'resso', 5)
# ADDING: ('chocolate / cocoa', 'coffee', 5)
# ADDING: ('chocolate / cocoa', 'espresso esp with dark chocolate', 5)
# Deleting... ('chocolate', 'coffee / espresso esp with dark chocolate', 5)
# ADDING: ('chocolate', 'coffee /', 5)
# ADDING: ('chocolate', 'resso', 5)
# ADDING: ('chocolate', 'with dark chocolate', 5)
# Deleting... ('cocoa — in general', 'coffee / espresso esp with dark chocolate', 5)
# ADDING: ('chocolate', 'coffee', 5)
# ADDING: ('chocolate', 'espresso esp with dark chocolate', 5)
# -> — <-
# inp:  chocolate / cocoa — in general
# Deleting... ('chocolate / cocoa — in general', 'espresso esp with dark chocolate', 5)
# ADDING: ('chocolate / cocoa', 'espresso esp with dark chocolate', 5)
# Deleting... ('coconut', 'blackberries', 1)
# ADDING: ('chocolate / cocoa — in general', 'resso', 5)
# ADDING: ('chocolate / cocoa — in general', 'with dark chocolate', 5)
# -> / <-
# inp:  chocolate / cocoa — in general
# Deleting... ('coconut milk', 'blackberries', 1)
# ADDING: ('chocolate', 'espresso esp with dark chocolate', 5)
# ADDING: ('cocoa — in general', 'espresso esp with dark chocolate', 5)
# -> aka <-
# inp:  crayfish aka crawfish
# Deleting... ('crayfish aka crawfish', 'carrots', 1)
# ADDING: ('crayfish', 'carrots', 1)
# ADDING: ('crawfish', 'carrots', 1)
# Deleting... ('crayfish', 'carrots and carrot juice', 1)
# ADDING: ('crayfish', 'carrots', 1)
# ADDING: ('crayfish', 'carrot juice', 1)
# -> and <-
# inp:  eggs and egg based dishes
# Deleting... ('eggs and egg based dishes', 'scallions', 1)
# ADDING: ('eggs', 'scallions', 1)
# ADDING: ('egg based dishes', 'scallions', 1)
# -> — <-
# inp:  egg based dishes — in general
# Deleting... ('egg based dishes — in general', 'scallions', 1)
# ADDING: ('egg based dishes', 'scallions', 1)
# -> see <-
# inp:  fruit tropical see also specific fruits
# Deleting... ('fruit tropical see also specific fruits', 'strawberries', 1)
# ADDING: ('fruit tropical', 'strawberries', 1)
# ADDING: ('also specific fruits', 'strawberries', 1)
# -> also <-
# inp:  fruit tropical see also specific fruits
# Deleting... ('mangoes papayas pineapples etc', 'strawberries', 1)
# ADDING: ('fruit tropical see', 'strawberries', 1)
# ADDING: ('specific fruits', 'strawberries', 1)
# -> eg <-
# inp:  also specific fruits eg mangoes papayas pineapples etc
# Deleting... ('also specific fruits eg mangoes papayas pineapples etc', 'strawberries', 1)
# ADDING: ('also specific fruits', 'strawberries', 1)
# ADDING: ('mangoes papayas pineapples etc', 'strawberries', 1)
# -> also <-
# inp:  also specific fruits eg mangoes papayas pineapples etc
# Deleting... ('fruit tropical see', 'strawberries', 1)
# ADDING: ('specific fruits eg mangoes papayas pineapples etc', 'strawberries', 1)
# -> also <-
# inp:  also mediterranean cuisines
# Deleting... ('also mediterranean cuisines', 'olives', 1)
# ADDING: ('mediterranean cuisines', 'olives', 1)
# Deleting... ('italian cuisine', 'honey esp in desserts', 1)
# ADDING: ('italian cuisine', 'honey', 1)
# ADDING: ('italian cuisine', 'in desserts', 1)
# -> — <-
# inp:  italian cuisine — in general
# Deleting... ('italian cuisine — in general', 'in desserts', 1)
# ADDING: ('italian cuisine', 'in desserts', 1)
# -> also <-
# inp:  also rutabagas turnips
# Deleting... ('also rutabagas turnips', 'sour cream', 1)
# ADDING: ('rutabagas turnips', 'sour cream', 1)
# -> see <-
# inp:  monkfish see also fish
# Deleting... ('monkfish see also fish', 'salmon', 1)
# ADDING: ('monkfish', 'salmon', 1)
# ADDING: ('also fish', 'salmon', 1)
# -> also <-
# inp:  monkfish see also fish
# Deleting... ('monkfish', 'salmon', 1)
# ADDING: ('monkfish see', 'salmon', 1)
# ADDING: ('fish', 'salmon', 1)
# -> see <-
# inp:  monkfish see
# Deleting... ('monkfish see', 'salmon', 1)
# ADDING: ('monkfish', 'salmon', 1)
# -> see <-
# inp:  in general see also specific mushrooms
# Deleting... ('in general see also specific mushrooms', 'scallions', 1)
# ADDING: ('also specific mushrooms', 'scallions', 1)
# -> also <-
# inp:  in general see also specific mushrooms
# Deleting... ('mushrooms — in general', 'scallions', 1)
# ADDING: ('in general see', 'scallions', 1)
# ADDING: ('specific mushrooms', 'scallions', 1)
# -> — <-
# inp:  mushrooms — in general see
# Deleting... ('mushrooms — in general see', 'scallions', 1)
# ADDING: ('mushrooms', 'scallions', 1)
# ADDING: ('in general see', 'scallions', 1)
# -> see <-
# inp:  mushrooms — in general see
# Deleting... ('specific mushrooms', 'scallions', 1)
# ADDING: ('mushrooms — in general', 'scallions', 1)
# -> / <-
# inp:  porcini / cepes / king bolete
# Deleting... ('porcini / cepes / king bolete', 'spinach', 1)
# ADDING: ('porcini', 'spinach', 1)
# ADDING: ('cepes', 'spinach', 1)
# ADDING: ('king bolete', 'spinach', 1)
# -> also <-
# inp:  also peaches
# Deleting... ('also peaches', 'oatmeal', 1)
# ADDING: ('peaches', 'oatmeal', 1)
# -> and <-
# inp:  oranges mandarin includes clementines and tangerines
# Deleting... ('oranges mandarin includes clementines and tangerines', 'chocolate', 1)
# ADDING: ('oranges m', 'chocolate', 1)
# ADDING: ('arin includes clementines', 'chocolate', 1)
# ADDING: ('tangerines', 'chocolate', 1)
# Deleting... ('oranges m', 'chocolate esp dark', 1)
# ADDING: ('oranges m', 'chocolate', 1)
# ADDING: ('oranges m', 'dark', 1)
# Deleting... ('tangerines', 'chocolate esp dark', 1)
# ADDING: ('tangerines', 'chocolate', 1)
# ADDING: ('tangerines', 'dark', 1)
# -> see <-
# inp:  in general see also snap peas
# Deleting... ('in general see also snap peas', 'sugar', 1)
# ADDING: ('also snap peas', 'sugar', 1)
# -> also <-
# inp:  in general see also snap peas
# Deleting... ('peas — in general', 'sugar', 1)
# ADDING: ('in general see', 'sugar', 1)
# ADDING: ('snap peas', 'sugar', 1)
# -> — <-
# inp:  peas — in general see
# Deleting... ('peas — in general see', 'sugar', 1)
# ADDING: ('peas', 'sugar', 1)
# ADDING: ('in general see', 'sugar', 1)
# -> see <-
# inp:  peas — in general see
# Deleting... ('snap peas', 'sugar', 1)
# ADDING: ('peas — in general', 'sugar', 1)
# -> aka <-
# inp:  plums dried aka prunes
# Deleting... ('plums dried aka prunes', 'port', 1)
# ADDING: ('plums dried', 'port', 1)
# ADDING: ('prunes', 'port', 1)
# Deleting... ('plums dried', 'port esp tawny', 1)
# ADDING: ('plums dried', 'port', 1)
# ADDING: ('plums dried', 'tawny', 1)
# Deleting... ('pork', 'rice or risotto', 1)
# ADDING: ('pork', 'rice', 1)
# ADDING: ('pork', 'risotto', 1)
# -> — <-
# inp:  pork — in general
# Deleting... ('pork — in general', 'risotto', 1)
# ADDING: ('pork', 'risotto', 1)
# -> also <-
# inp:  also squashes winter
# Deleting... ('also squashes winter', 'hazelnuts', 1)
# ADDING: ('squashes winter', 'hazelnuts', 1)
# -> see <-
# inp:  rabbit see also game
# Deleting... ('rabbit see also game', 'saffron', 1)
# ADDING: ('rabbit', 'saffron', 1)
# ADDING: ('also game', 'saffron', 1)
# -> also <-
# inp:  rabbit see also game
# Deleting... ('rabbit', 'saffron', 1)
# ADDING: ('rabbit see', 'saffron', 1)
# ADDING: ('game', 'saffron', 1)
# -> see <-
# inp:  rabbit see
# Deleting... ('rabbit see', 'saffron', 1)
# ADDING: ('rabbit', 'saffron', 1)
# Deleting... ('salmon see also fish', 'olives esp black niçoise picholine provençal', 3)
# ADDING: ('salmon see also fish', 'olives', 3)
# ADDING: ('salmon see also fish', 'black niçoise picholine provençal', 3)
# -> see <-
# inp:  salmon see also fish
# Deleting... ('salmon see also fish — in general', 'olives', 3)
# ADDING: ('salmon', 'olives esp black niçoise picholine provençal', 3)
# ADDING: ('also fish', 'olives esp black niçoise picholine provençal', 3)
# -> also <-
# inp:  salmon see also fish
# Deleting... ('salmon see also fish — in general', 'black niçoise picholine provençal', 3)
# ADDING: ('salmon see', 'olives esp black niçoise picholine provençal', 3)
# ADDING: ('fish', 'olives esp black niçoise picholine provençal', 3)
# -> — <-
# inp:  also fish — in general
# Deleting... ('also fish — in general', 'olives esp black niçoise picholine provençal', 3)
# ADDING: ('also fish', 'olives esp black niçoise picholine provençal', 3)
# Deleting... ('salmon see', 'olives esp black niçoise picholine provençal', 3)
# ADDING: ('also fish — in general', 'olives', 3)
# ADDING: ('also fish — in general', 'black niçoise picholine provençal', 3)
# -> also <-
# inp:  also fish — in general
# Deleting... ('fish — in general', 'olives esp black niçoise picholine provençal', 3)
# ADDING: ('fish — in general', 'olives esp black niçoise picholine provençal', 3)
# -> also <-
# inp:  also chorizo
# Deleting... ('also chorizo', 'salt kosher', 1)
# ADDING: ('chorizo', 'salt kosher', 1)
# -> see <-
# inp:  shellfish see also crab lobster scallops shrimp etc
# Deleting... ('shellfish see also crab lobster scallops shrimp etc', 'wines dry white', 3)
# ADDING: ('shellfish', 'wines dry white', 3)
# ADDING: ('also crab lobster scallops shrimp etc', 'wines dry white', 3)
# -> also <-
# inp:  shellfish see also crab lobster scallops shrimp etc
# Deleting... ('shellfish see also crab lobster scallops shrimp etc', 'sauvighon blanc', 3)
# ADDING: ('shellfish see', 'wines dry white', 3)
# ADDING: ('crab lobster scallops shrimp etc', 'wines dry white', 3)
# Deleting... ('also crab lobster scallops shrimp etc', 'wines dry white eg sauvighon blanc', 3)
# ADDING: ('also crab lobster scallops shrimp etc', 'wines dry white', 3)
# ADDING: ('also crab lobster scallops shrimp etc', 'sauvighon blanc', 3)
# -> also <-
# inp:  also crab lobster scallops shrimp etc
# Deleting... ('shellfish see', 'wines dry white eg sauvighon blanc', 3)
# ADDING: ('crab lobster scallops shrimp etc', 'wines dry white eg sauvighon blanc', 3)
# -> also <-
# inp:  also shellfish
# Deleting... ('also shellfish', 'chives', 1)
# ADDING: ('shellfish', 'chives', 1)
# -> also <-
# inp:  also shellfish
# Deleting... ('also shellfish', 'spinach', 1)
# ADDING: ('shellfish', 'spinach', 1)
# -> see <-
# inp:  squash butternut see also pumpkin squash acorn
# Deleting... ('squash butternut see also pumpkin squash acorn', 'leeks', 1)
# ADDING: ('squash butternut', 'leeks', 1)
# ADDING: ('also pumpkin squash acorn', 'leeks', 1)
# -> also <-
# inp:  squash butternut see also pumpkin squash acorn
# Deleting... ('squash winter', 'leeks', 1)
# ADDING: ('squash butternut see', 'leeks', 1)
# ADDING: ('pumpkin squash acorn', 'leeks', 1)
# -> and <-
# inp:  also pumpkin squash acorn and squash winter
# Deleting... ('also pumpkin squash acorn and squash winter', 'leeks', 1)
# ADDING: ('also pumpkin squash acorn', 'leeks', 1)
# ADDING: ('squash winter', 'leeks', 1)
# -> also <-
# inp:  also pumpkin squash acorn and squash winter
# Deleting... ('squash butternut see', 'leeks', 1)
# ADDING: ('pumpkin squash acorn and squash winter', 'leeks', 1)
# Deleting... ('tangerines see oranges mandarin tarragon', 'gs and', 3)
# ADDING: ('tangerines see oranges mandarin tarragon', 'gs', 3)
# -> see <-
# inp:  tangerines see oranges mandarin tarragon
# Deleting... ('tangerines see oranges mandarin tarragon', 'g dishes', 3)
# ADDING: ('tangerines', 'gs and', 3)
# ADDING: ('oranges mandarin tarragon', 'gs and', 3)
# -> see <-
# inp:  tangerines see oranges mandarin tarragon
# Deleting... ('tangerines see oranges mandarin tarragon', 'g salad', 3)
# ADDING: ('tangerines', 'g salad', 3)
# ADDING: ('oranges mandarin tarragon', 'g salad', 3)
# Deleting... ('tangerines see oranges mandarin tarragon', 'egg dishes eg omelets egg salad', 3)
# ADDING: ('tangerines see oranges mandarin tarragon', 'g dishes', 3)
# ADDING: ('tangerines see oranges mandarin tarragon', 'omelets', 3)
# ADDING: ('tangerines see oranges mandarin tarragon', 'g salad', 3)
# -> see <-
# inp:  tangerines see oranges mandarin tarragon
# Deleting... ('tangerines', 'eggs and egg dishes eg omelets egg salad', 3)
# ADDING: ('tangerines', 'egg dishes eg omelets egg salad', 3)
# ADDING: ('oranges mandarin tarragon', 'egg dishes eg omelets egg salad', 3)
# Deleting... ('veal', 'eggs esp hard-boiled', 1)
# ADDING: ('veal', 'eggs', 1)
# ADDING: ('veal', 'hardboiled', 1)
# -> — <-
# inp:  veal — in general
# Deleting... ('veal — in general', 'hardboiled', 1)
# ADDING: ('veal', 'hardboiled', 1)
# Deleting... ('veal', 'onions esp spanish', 3)
# ADDING: ('veal', 'onions', 3)
# ADDING: ('veal', 'spanish', 3)
# -> — <-
# inp:  veal — breast
# Deleting... ('veal — breast', 'onions', 3)
# ADDING: ('veal', 'onions', 3)
# ADDING: ('breast', 'onions', 3)
# -> see <-
# inp:  walnut oil see oil walnut walnuts see also nuts
# Deleting... ('walnut oil see oil walnut walnuts see also nuts', 'stuffings', 1)
# ADDING: ('walnut oil', 'stuffings', 1)
# ADDING: ('oil walnut walnuts', 'stuffings', 1)
# ADDING: ('also nuts', 'stuffings', 1)
# -> also <-
# inp:  walnut oil see oil walnut walnuts see also nuts
# Deleting... ('walnut oil', 'stuffings', 1)
# ADDING: ('walnut oil see oil walnut walnuts see', 'stuffings', 1)
# ADDING: ('nuts', 'stuffings', 1)
# -> — <-
# inp:  also nuts — in general
# Deleting... ('also nuts — in general', 'stuffings', 1)
# ADDING: ('also nuts', 'stuffings', 1)
# -> also <-
# inp:  also nuts — in general
# Deleting... ('walnut oil see oil walnut walnuts see', 'stuffings', 1)
# ADDING: ('nuts — in general', 'stuffings', 1)
# -> also <-
# inp:  also summer squash
# Deleting... ('also summer squash', 'pasta', 1)
# ADDING: ('summer squash', 'pasta', 1)
# -> also <-
# inp:  also lettuces
# Deleting... ('also lettuces', 'italian cuisine', 3)
# ADDING: ('lettuces', 'italian cuisine', 3)
# -> also <-
# inp:  also basil thai
# Deleting... ('also basil thai', 'veal', 1)
# ADDING: ('basil thai', 'veal', 1)
# -> or <-
# inp:  broad beans or horse beans
# Deleting... ('broad beans or horse beans', 'rice', 1)
# ADDING: ('broad beans', 'rice', 1)
# ADDING: ('h', 'rice', 1)
# ADDING: ('se beans', 'rice', 1)
# Deleting... ('broad beans', 'rice and risotto', 1)
# ADDING: ('broad beans', 'rice', 1)
# ADDING: ('broad beans', 'risotto', 1)
# Deleting... ('se beans', 'rice and risotto', 1)
# ADDING: ('se beans', 'rice', 1)
# ADDING: ('se beans', 'risotto', 1)
# -> see <-
# inp:  in general see also cantaloupe honeydew etc
# Deleting... ('in general see also cantaloupe honeydew etc', 'grand marnier', 3)
# ADDING: ('also cantaloupe honeydew etc', 'grand marnier', 3)
# -> also <-
# inp:  in general see also cantaloupe honeydew etc
# Deleting... ('in general see also cantaloupe honeydew etc', 'in cocktails', 3)
# ADDING: ('in general see', 'grand marnier', 3)
# ADDING: ('cantaloupe honeydew etc', 'grand marnier', 3)
# Deleting... ('in general see', 'grand marnier esp in cocktails', 3)
# ADDING: ('in general see', 'grand marnier', 3)
# ADDING: ('in general see', 'in cocktails', 3)
# -> see <-
# inp:  in general see
# Deleting... ('cantaloupe honeydew etc', 'grand marnier esp in cocktails', 3)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'bread crumbs', 1)
# ADDING: ('fish', 'bread crumbs', 1)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'orange zest', 1)
# ADDING: ('fish', 'orange zest', 1)
# -> also <-
# inp:  also nuts
# Deleting... ('also nuts', 'cream', 1)
# ADDING: ('nuts', 'cream', 1)
# -> also <-
# inp:  also nuts
# Deleting... ('also nuts', 'stuffing', 1)
# ADDING: ('nuts', 'stuffing', 1)
# -> also <-
# inp:  also nuts
# Deleting... ('also nuts', 'chicken', 1)
# ADDING: ('nuts', 'chicken', 1)
# -> also <-
# inp:  also nuts
# Deleting... ('also nuts', 'sugar', 1)
# ADDING: ('nuts', 'sugar', 1)
# -> also <-
# inp:  also game
# Deleting... ('also game', 'bread crumbs', 1)
# ADDING: ('game', 'bread crumbs', 1)
# -> also <-
# inp:  also game
# Deleting... ('also game', 'oregano', 1)
# ADDING: ('game', 'oregano', 1)
# -> also <-
# inp:  also fish
# Deleting... ('also fish', 'butter unsalted', 3)
# ADDING: ('fish', 'butter unsalted', 3)
# -> also <-
# inp:  also fish
# Deleting... ('also fish', 'lemon preserved', 1)
# ADDING: ('fish', 'lemon preserved', 1)
# -> also <-
# inp:  also fish
# Deleting... ('also fish', 'scallops', 1)
# ADDING: ('fish', 'scallops', 1)
# -> also <-
# inp:  also greens
# Deleting... ('also greens', 'mascarpone', 1)
# ADDING: ('greens', 'mascarpone', 1)
# -> also <-
# inp:  also greens
# Deleting... ('also greens', 'walnuts', 1)
# ADDING: ('greens', 'walnuts', 1)
# -> also <-
# inp:  also game
# Deleting... ('also game', 'carrots', 1)
# ADDING: ('game', 'carrots', 1)
# -> also <-
# inp:  also game
# Deleting... ('also game', 'peaches', 1)
# ADDING: ('game', 'peaches', 1)
# -> and <-
# inp:  bitter greens and chicories
# Deleting... ('bitter greens and chicories', 'sea', 1)
# ADDING: ('bitter greens', 'sea', 1)
# ADDING: ('chicories', 'sea', 1)
# Deleting... ('peanuts', 'coconut and coconut milk', 1)
# ADDING: ('peanuts', 'coconut', 1)
# ADDING: ('peanuts', 'coconut milk', 1)
# -> and <-
# inp:  peanuts and peanut butter
# Deleting... ('peanuts and peanut butter', 'coconut', 1)
# ADDING: ('peanuts', 'coconut', 1)
# ADDING: ('peanut butter', 'coconut', 1)
# -> also <-
# inp:  also specific fish
# Deleting... ('also specific fish', 'fruit', 1)
# ADDING: ('specific fish', 'fruit', 1)
# -> and <-
# inp:  specific fish and shellfish
# Deleting... ('specific fish and shellfish', 'fruit', 1)
# ADDING: ('specific fish', 'fruit', 1)
# ADDING: ('shellfish', 'fruit', 1)
# -> also <-
# inp:  also lettuces
# Deleting... ('also lettuces', 'parsley', 1)
# ADDING: ('lettuces', 'parsley', 1)
# -> see <-
# inp:  basil see also basil thai
# Deleting... ('basil see also basil thai', 'ice cream', 1)
# ADDING: ('basil', 'ice cream', 1)
# ADDING: ('also basil thai', 'ice cream', 1)
# -> also <-
# inp:  basil see also basil thai
# Deleting... ('lemon basil', 'ice cream', 1)
# ADDING: ('basil see', 'ice cream', 1)
# ADDING: ('basil thai', 'ice cream', 1)
# -> and <-
# inp:  also basil thai and lemon basil
# Deleting... ('also basil thai and lemon basil', 'ice cream', 1)
# ADDING: ('also basil thai', 'ice cream', 1)
# ADDING: ('lemon basil', 'ice cream', 1)
# -> also <-
# inp:  also basil thai and lemon basil
# Deleting... ('basil see', 'ice cream', 1)
# ADDING: ('basil thai and lemon basil', 'ice cream', 1)
# -> see <-
# inp:  bass see also bass sea
# Deleting... ('bass see also bass sea', 'tomato paste', 1)
# ADDING: ('bass', 'tomato paste', 1)
# ADDING: ('also bass sea', 'tomato paste', 1)
# -> also <-
# inp:  bass see also bass sea
# Deleting... ('bass striped', 'tomato paste', 1)
# ADDING: ('bass see', 'tomato paste', 1)
# ADDING: ('bass sea', 'tomato paste', 1)
# -> and <-
# inp:  also bass sea and bass striped
# Deleting... ('also bass sea and bass striped', 'tomato paste', 1)
# ADDING: ('also bass sea', 'tomato paste', 1)
# ADDING: ('bass striped', 'tomato paste', 1)
# -> also <-
# inp:  also bass sea and bass striped
# Deleting... ('bass see', 'tomato paste', 1)
# ADDING: ('bass sea and bass striped', 'tomato paste', 1)
# Deleting... ('fresh', 'greens salad esp arugula', 1)
# ADDING: ('fresh', 'greens salad', 1)
# ADDING: ('fresh', 'arugula', 1)
# -> eg <-
# inp:  fresh eg chèvre
# Deleting... ('fresh eg chèvre', 'greens salad', 1)
# ADDING: ('fresh', 'greens salad', 1)
# ADDING: ('chèvre', 'greens salad', 1)
# Deleting... ('chile peppers', 'coconut milk esp in asian cuisine', 3)
# ADDING: ('chile peppers', 'coconut milk', 3)
# ADDING: ('chile peppers', 'in asian cuisine', 3)
# -> — <-
# inp:  chile peppers — in general
# Deleting... ('chile peppers — in general', 'in asian cuisine', 3)
# ADDING: ('chile peppers', 'in asian cuisine', 3)
# -> see <-
# inp:  temperature see also winter
# Deleting... ('temperature see also winter', 'cream', 1)
# ADDING: ('temperature', 'cream', 1)
# ADDING: ('also winter', 'cream', 1)
# -> also <-
# inp:  temperature see also winter
# Deleting... ('temperature see also winter', 'creambased sauces', 1)
# ...
# -> see <-
# inp:  peanut butter see
# Deleting... ('peanut butter see', 'lemon juice', 1)
# ADDING: ('peanut butter', 'lemon juice', 1)
# -> and <-
# inp:  peanuts and peanut butter
# Deleting... ('peanuts and peanut butter', 'lemon juice', 1)
# ADDING: ('peanuts', 'lemon juice', 1)
# ADDING: ('peanut butter', 'lemon juice', 1)
# -> see <-
# inp:  in general see
# Deleting... ('in general see', 'sherry dry', 1)
# -> see <-
# inp:  in general see
# Deleting... ('in general see', 'manzanilla', 1)
# -> see <-
# inp:  venison see
# Deleting... ('venison see', 'fresh', 1)
# ADDING: ('venison', 'fresh', 1)
# -> also <-
# inp:  also game
# Deleting... ('also game', 'black', 1)
# ADDING: ('game', 'black', 1)
# Deleting... ('paprika', 'gs esp hardboiled', 1)
# ADDING: ('paprika', 'gs', 1)
# ADDING: ('paprika', 'hardboiled', 1)
# -> see <-
# inp:  asian cuisine see chinese japanese vietnamese etc cuisines
#   asparagus
# Deleting... ('asian cuisine see chinese japanese vietnamese etc cuisines\r\n  asparagus', 'rice', 1)
# ADDING: ('asian cuisine', 'rice', 1)
# ADDING: ('chinese japanese vietnamese etc cuisines\r\n  asparagus', 'rice', 1)
# Deleting... ('asian cuisine', 'rice and risotto', 1)
# ADDING: ('asian cuisine', 'rice', 1)
# ADDING: ('asian cuisine', 'risotto', 1)
# -> see <-
# inp:  avocado oil see oil avocado
#   avocados
# Deleting... ('avocado oil see oil avocado\r\n  avocados', 'shellfish', 1)
# ADDING: ('avocado oil', 'shellfish', 1)
# ADDING: ('oil avocado\r\n  avocados', 'shellfish', 1)
# Deleting... ('avocado oil', 'shellfish eg shrimp', 1)
# ADDING: ('avocado oil', 'shellfish', 1)
# ADDING: ('avocado oil', 'shrimp', 1)
# -> and <-
# inp:  coffee and espresso
# Deleting... ('coffee and espresso', 'liqueurs coffee', 3)
# ADDING: ('coffee', 'liqueurs coffee', 3)
# ADDING: ('espresso', 'liqueurs coffee', 3)
# Deleting... ('coffee', 'liqueurs coffee eg kahlúa tía maria', 3)
# ADDING: ('coffee', 'liqueurs coffee', 3)
# ADDING: ('coffee', 'kahlúa tía maria', 3)
# -> and <-
# inp:  bitter greens and chicories see arugula escarole frisée radicchio
# Deleting... ('bitter greens and chicories see arugula escarole frisée radicchio', 'basil', 1)
# ADDING: ('bitter greens', 'basil', 1)
# ADDING: ('chicories see arugula escarole frisée radicchio', 'basil', 1)
# -> see <-
# inp:  bitter greens and chicories see arugula escarole frisée radicchio
# Deleting... ('lettuces — bitter greens', 'basil', 1)
# ADDING: ('bitter greens and chicories', 'basil', 1)
# ADDING: ('arugula escarole frisée radicchio', 'basil', 1)
# -> — <-
# inp:  lettuces — bitter greens and chicories
# Deleting... ('lettuces — bitter greens and chicories', 'basil', 1)
# ADDING: ('lettuces', 'basil', 1)
# ADDING: ('bitter greens and chicories', 'basil', 1)
# -> and <-
# inp:  lettuces — bitter greens and chicories
# Deleting... ('arugula escarole frisée radicchio', 'basil', 1)
# ADDING: ('lettuces — bitter greens', 'basil', 1)
# ADDING: ('chicories', 'basil', 1)
# -> / <-
# inp:  porcini / cepes / king bolete
# Deleting... ('porcini / cepes / king bolete', 'bacon', 1)
# ADDING: ('porcini', 'bacon', 1)
# ADDING: ('cepes', 'bacon', 1)
# ADDING: ('king bolete', 'bacon', 1)
# -> aka <-
# inp:  carnaroli aka risotto
# Deleting... ('carnaroli aka risotto', 'prosciutto', 1)
# ADDING: ('carnaroli', 'prosciutto', 1)
# ADDING: ('risotto', 'prosciutto', 1)
# -> also <-
# inp:  also fish
# Deleting... ('also fish', 'tomatoes', 3)
# ADDING: ('fish', 'tomatoes', 3)
# -> also <-
# inp:  also ethiopian
# Deleting... ('also ethiopian', 'fruits', 1)
# ADDING: ('ethiopian', 'fruits', 1)
# Deleting... ('ethiopian', 'fruits esp tropical', 1)
# ADDING: ('ethiopian', 'fruits', 1)
# ADDING: ('ethiopian', 'tropical', 1)
# -> see <-
# inp:  chicories see arugula escarole frisée radicchio
# Deleting... ('chicories see arugula escarole frisée radicchio', 'basil', 1)
# ADDING: ('chicories', 'basil', 1)
# ADDING: ('arugula escarole frisée radicchio', 'basil', 1)
# -> and <-
# inp:  bitter greens and chicories
# Deleting... ('bitter greens and chicories', 'basil', 1)
# ADDING: ('bitter greens', 'basil', 1)
# ADDING: ('chicories', 'basil', 1)
# -> see <-
# inp:  almond oil see oil almond
#   almonds
# Deleting... ('almond oil (see oil, almond)\r\n  almonds', 'shellfish', 1)
# ADDING: ('almond oil', 'shellfish', 1)
# ADDING: ('oil almond\r\n  almonds', 'shellfish', 1)
# -> — <-
# inp:  beef — in general
# Deleting... ('beef — in general', 'cornichons', 1)
# ADDING: ('beef', 'cornichons', 1)
# -> — <-
# inp:  beef — short ribs
# Deleting... ('beef — short ribs', 'bay leaf', 1)
# ADDING: ('beef', 'bay leaf', 1)
# ADDING: ('short ribs', 'bay leaf', 1)
# -> — <-
# inp:  cabbage — in general
# Deleting... ('cabbage — in general', 'wine, white (e.g., riesling)', 3)
# ADDING: ('cabbage', 'wine white eg riesling', 3)
# Deleting... ('cabbage, red', 'bacon', 1)
# ADDING: ('cabbage — in general', 'wine white', 3)
# ADDING: ('cabbage — in general', 'riesling', 3)
# -> — <-
# inp:  lamb — in general
# Deleting... ('lamb — in general', 'paprika', 1)
# ADDING: ('lamb', 'paprika', 1)
# -> — <-
# inp:  mint — in general
# Deleting... ('mint — in general', 'middle eastern cuisine', 3)
# ADDING: ('mint', 'middle eastern cuisine', 3)
# -> — <-
# inp:  mushrooms — morels
# Deleting... ('mushrooms — morels', 'crème fraîche', 1)
# ADDING: ('mushrooms', 'crème fraîche', 1)
# ADDING: ('morels', 'crème fraîche', 1)
# -> eg <-
# inp:  onions sweet eg vidalia
# Deleting... ('onions, sweet (e.g., vidalia)', 'salads', 1)
# ADDING: ('onions sweet', 'salads', 1)
# ADDING: ('vidalia', 'salads', 1)
# -> — <-
# inp:  pork — in general
# Deleting... ('pork — in general', 'piquillo peppers', 1)
# ADDING: ('pork', 'piquillo peppers', 1)
# -> — <-
# inp:  pork — ribs
# Deleting... ('pork — ribs', 'soy sauce', 1)
# ADDING: ('pork', 'soy sauce', 1)
# ADDING: ('ribs', 'soy sauce', 1)
# -> aka <-
# inp:  snapper aka red snapper
# Deleting... ('snapper (aka red snapper)', 'grapefruit', 1)
# ADDING: ('snapper', 'grapefruit', 1)
# ADDING: ('red snapper', 'grapefruit', 1)
# -> — <-
# inp:  veal — chop
# Deleting... ('veal — chop', 'garlic', 1)
# ADDING: ('veal', 'garlic', 1)
# ADDING: ('chop', 'garlic', 1)
# -> see <-
# inp:  yams see sweet potatoes yogurt
# Deleting... ('yams (see sweet potatoes) yogurt', 'mangoes', 1)
# ADDING: ('yams', 'mangoes', 1)
# ADDING: ('sweet potatoes yogurt', 'mangoes', 1)
# Deleting... ('chanterelles', 'egg dishes eg omelets', 1)
# ADDING: ('chanterelles', 'g dishes', 1)
# ADDING: ('chanterelles', 'omelets', 1)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'carrots', 1)
# ADDING: ('fish', 'carrots', 1)
# -> — <-
# inp:  nuts — in general
# Deleting... ('nuts — in general', 'sugar', 1)
# ADDING: ('nuts', 'sugar', 1)
# -> see <-
# inp:  shellfish see
# Deleting... ('shellfish see', 'wines dry white', 3)
# ADDING: ('shellfish', 'wines dry white', 3)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'olives', 3)
# ADDING: ('fish', 'olives', 3)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'fresh', 1)
# ADDING: ('game', 'fresh', 1)
# -> — <-
# inp:  beef — cheeks
# Deleting... ('beef — cheeks', 'burgundy', 3)
# ADDING: ('beef', 'burgundy', 3)
# ADDING: ('cheeks', 'burgundy', 3)
# Deleting... ('swiss chard', 'italian cuisine esp pasta', 3)
# ADDING: ('swiss chard', 'italian cuisine', 3)
# ADDING: ('swiss chard', 'pasta', 3)
# Deleting... ('chickpeas aka garbanzo beans', 'cumin esp toasted', 3)
# ADDING: ('chickpeas aka garbanzo beans', 'cumin', 3)
# ADDING: ('chickpeas aka garbanzo beans', 'toasted', 3)
# -> aka <-
# inp:  chickpeas aka garbanzo beans
# Deleting... ('garbanzo beans', 'cumin esp toasted eg indian cuisine etc', 3)
# ADDING: ('chickpeas', 'cumin esp toasted', 3)
# ADDING: ('garbanzo beans', 'cumin esp toasted', 3)
# -> and <-
# inp:  coconut and coconut milk
# Deleting... ('coconut and coconut milk', 'ice cream', 3)
# ADDING: ('coconut', 'ice cream', 3)
# ADDING: ('coconut milk', 'ice cream', 3)
# -> — <-
# inp:  paprika — in general
# Deleting... ('paprika — in general', 'hardboiled and egg dishes eg omelets', 1)
# ADDING: ('paprika', 'hardboiled and egg dishes eg omelets', 1)
# Deleting... ('plums dried', 'cream and ice cream', 1)
# ADDING: ('paprika — in general', 'hardboiled and', 1)
# ADDING: ('paprika — in general', 'g dishes', 1)
# ADDING: ('paprika — in general', 'omelets', 1)
# Deleting... ('pork', 'calvados', 3)
# ADDING: ('paprika — in general', 'hardboiled', 1)
# ADDING: ('paprika — in general', 'egg dishes eg omelets', 1)
# Deleting... ('oranges mandarin tarragon', 'cheese esp goat ricotta', 1)
# ADDING: ('oranges mandarin tarragon', 'cheese', 1)
# ADDING: ('oranges mandarin tarragon', 'goat ricotta', 1)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'italian cuisine', 3)
# ADDING: ('game', 'italian cuisine', 3)
# Deleting... ('also specific mushrooms', 'sherry dry eg manzanilla', 1)
# ADDING: ('also specific mushrooms', 'sherry dry', 1)
# ADDING: ('also specific mushrooms', 'manzanilla', 1)
# -> also <-
# inp:  also specific mushrooms
# Deleting... ('oranges m', 'rum', 1)
# ADDING: ('specific mushrooms', 'sherry dry eg manzanilla', 1)
# -> — <-
# inp:  game — in general
# Deleting... ('game — in general', 'orange zest', 1)
# ADDING: ('game', 'orange zest', 1)
# Deleting... ('game', 'fresh esp black', 1)
# ADDING: ('game', 'fresh', 1)
# ADDING: ('game', 'black', 1)
# -> eg <-
# inp:  fresh eg chèvre
# Deleting... ('fresh eg chèvre', 'tomato jam', 1)
# ADDING: ('fresh', 'tomato jam', 1)
# ADDING: ('chèvre', 'tomato jam', 1)
# Deleting... ('cocoa', 'espresso esp with dark chocolate', 5)
# ADDING: ('cocoa', 'resso', 5)
# ADDING: ('cocoa', 'with dark chocolate', 5)
# Deleting... ('garbanzo beans', 'toasted eg indian cuisine etc', 3)
# ADDING: ('garbanzo beans', 'toasted', 3)
# ADDING: ('garbanzo beans', 'indian cuisine etc', 3)
# -> see <-
# inp:  asian cuisine see chinese japanese vietnamese etc cuisines
#   asparagus
# Deleting... ('asian cuisine see chinese japanese vietnamese etc cuisines\r\n  asparagus', 'risotto', 1)
# ADDING: ('asian cuisine', 'risotto', 1)
# ADDING: ('chinese japanese vietnamese etc cuisines\r\n  asparagus', 'risotto', 1)
# -> see <-
# inp:  avocado oil see oil avocado
#   avocados
# Deleting... ('avocado oil see oil avocado\r\n  avocados', 'shrimp', 1)
# ADDING: ('avocado oil', 'shrimp', 1)
# ADDING: ('oil avocado\r\n  avocados', 'shrimp', 1)
# -> and <-
# inp:  coffee and espresso
# Deleting... ('coffee and espresso', 'kahlúa tía maria', 3)
# ADDING: ('coffee', 'kahlúa tía maria', 3)
# ADDING: ('espresso', 'kahlúa tía maria', 3)
# -> see <-
# inp:  chicories see arugula escarole frisée radicchio
# Deleting... ('chicories see arugula escarole frisée radicchio', 'basil', 1)
# ADDING: ('chicories', 'basil', 1)
# ADDING: ('arugula escarole frisée radicchio', 'basil', 1)
# -> — <-
# inp:  mushrooms — porcini
# Deleting... ('mushrooms — porcini', 'bacon', 1)
# ADDING: ('mushrooms', 'bacon', 1)
# ADDING: ('porcini', 'bacon', 1)
# -> or <-
# inp:  rice arborio or carnaroli
# Deleting... ('rice arborio or carnaroli', 'prosciutto', 1)
# ADDING: ('rice arb', 'prosciutto', 1)
# ADDING: ('io', 'prosciutto', 1)
# ADDING: ('carnaroli', 'prosciutto', 1)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'tomatoes', 3)
# ADDING: ('fish', 'tomatoes', 3)
# -> also <-
# inp:  also ethiopian
# Deleting... ('also ethiopian', 'tropical', 1)
# ADDING: ('ethiopian', 'tropical', 1)
# -> and <-
# inp:  bitter greens and chicories
# Deleting... ('bitter greens and chicories', 'basil', 1)
# ADDING: ('bitter greens', 'basil', 1)
# ADDING: ('chicories', 'basil', 1)
# -> — <-
# inp:  lettuces — bitter greens
# Deleting... ('lettuces — bitter greens', 'basil', 1)
# ADDING: ('lettuces', 'basil', 1)
# ADDING: ('bitter greens', 'basil', 1)
# Deleting... ('cabbage', 'wine white eg riesling', 3)
# ADDING: ('cabbage', 'wine white', 3)
# ADDING: ('cabbage', 'riesling', 3)
# -> — <-
# inp:  cabbage — in general
# Deleting... ('cabbage — in general', 'riesling', 3)
# ADDING: ('cabbage', 'riesling', 3)
# -> aka <-
# inp:  chickpeas aka garbanzo beans
# Deleting... ('chickpeas aka garbanzo beans', 'cumin', 3)
# ADDING: ('chickpeas', 'cumin', 3)
# ADDING: ('garbanzo beans', 'cumin', 3)
# Deleting... ('chickpeas', 'cumin esp toasted', 3)
# ADDING: ('chickpeas', 'cumin', 3)
# ADDING: ('chickpeas', 'toasted', 3)
# Deleting... ('paprika', 'hardboiled and egg dishes eg omelets', 1)
# ADDING: ('paprika', 'hardboiled and', 1)
# ADDING: ('paprika', 'g dishes', 1)
# ADDING: ('paprika', 'omelets', 1)
# Deleting... ('paprika — in general', 'hardboiled and', 1)
# ADDING: ('paprika', 'hardboiled', 1)
# ADDING: ('paprika', 'egg dishes eg omelets', 1)
# -> — <-
# inp:  paprika — in general
# Deleting... ('paprika — in general', 'omelets', 1)
# ADDING: ('paprika', 'omelets', 1)
# -> — <-
# inp:  paprika — in general
# Deleting... ('paprika — in general', 'egg dishes eg omelets', 1)
# ADDING: ('paprika', 'egg dishes eg omelets', 1)
# Deleting... ('oranges mandarin tarragon', 'cheese', 1)
# ADDING: ('paprika — in general', 'g dishes', 1)
# ADDING: ('paprika — in general', 'omelets', 1)
# -> also <-
# inp:  also specific mushrooms
# Deleting... ('also specific mushrooms', 'sherry dry', 1)
# ADDING: ('specific mushrooms', 'sherry dry', 1)
# Deleting... ('specific mushrooms', 'sherry dry eg manzanilla', 1)
# ADDING: ('specific mushrooms', 'sherry dry', 1)
# ADDING: ('specific mushrooms', 'manzanilla', 1)
# Deleting... ('paprika', 'hardboiled and', 1)
# ADDING: ('paprika', 'hardboiled', 1)
# Deleting... ('paprika', 'egg dishes eg omelets', 1)
# ADDING: ('paprika', 'g dishes', 1)
# ADDING: ('paprika', 'omelets', 1)
# Deleting... ('paprika', 'egg dishes eg omelets', 1)
# ADDING: ('paprika', 'g dishes', 1)
# ADDING: ('paprika', 'omelets', 1)
# -> — <-
# inp:  paprika — in general
# Deleting... ('paprika — in general', 'omelets', 1)
# ADDING: ('paprika', 'omelets', 1)
# -> — <-
# inp:  beef — cheeks
# Deleting... ('beef — cheeks', 'garlic', 1)
# ADDING: ('beef', 'garlic', 1)
# ADDING: ('cheeks', 'garlic', 1)
# -> — <-
# inp:  oranges — in general
# Deleting... ('oranges — in general', 'meringue', 1)
# ADDING: ('oranges', 'meringue', 1)
# -> — <-
# inp:  pork — chops
# Deleting... ('pork — chops', 'polenta', 1)
# ADDING: ('pork', 'polenta', 1)
# ADDING: ('chops', 'polenta', 1)
# -> — <-
# inp:  veal — shanks
# Deleting... ('veal — shanks', 'pepper', 1)
# ADDING: ('veal', 'pepper', 1)
# ADDING: ('shanks', 'pepper', 1)
# -> — <-
# inp:  fish — in general
# Deleting... ('fish — in general', 'lemon preserved', 1)
# ADDING: ('fish', 'lemon preserved', 1)
# -> — <-
# inp:  greens — in general
# Deleting... ('greens — in general', 'french cuisine', 3)
# ADDING: ('greens', 'french cuisine', 3)
# Deleting... ('chinese japanese vietnamese etc cuisines\r\n  asparagus', 'rice and risotto', 1)
# ADDING: ('chinese japanese vietnamese etc cuisines\r\n  asparagus', 'rice', 1)
# ADDING: ('chinese japanese vietnamese etc cuisines\r\n  asparagus', 'risotto', 1)
# Deleting... ('espresso', 'liqueurs coffee eg kahlúa tía maria', 3)
# ADDING: ('espresso', 'liqueurs coffee', 3)
# ADDING: ('espresso', 'kahlúa tía maria', 3)
# -> — <-
# inp:  cabbage — in general
# Deleting... ('cabbage — in general', 'wine white', 3)
# ADDING: ('cabbage', 'wine white', 3)
# -> aka <-
# inp:  chickpeas aka garbanzo beans
# Deleting... ('chickpeas aka garbanzo beans', 'toasted', 3)
# ADDING: ('chickpeas', 'toasted', 3)
# ADDING: ('garbanzo beans', 'toasted', 3)
# -> — <-
# inp:  paprika — in general
# Deleting... ('paprika — in general', 'g dishes', 1)
# ADDING: ('paprika', 'g dishes', 1)
# -> also <-
# inp:  also specific mushrooms
# Deleting... ('also specific mushrooms', 'manzanilla', 1)
# ADDING: ('specific mushrooms', 'manzanilla', 1)
# -> — <-
# inp:  paprika — in general
# Deleting... ('paprika — in general', 'g dishes', 1)
# ADDING: ('paprika', 'g dishes', 1)
# -> — <-
# inp:  beef — steak in general
# Deleting... ('beef — steak: in general', 'port', 1)
# ADDING: ('beef', 'port', 1)
# ADDING: ('steak in general', 'port', 1)
# -> — <-
# inp:  pork — tenderloin
# Deleting... ('pork — tenderloin', 'vinegar, balsamic', 1)
# ADDING: ('pork', 'vinegar balsamic', 1)
# ADDING: ('tenderloin', 'vinegar balsamic', 1)
# Deleting... ('oil avocado\r\n  avocados', 'shellfish eg shrimp', 1)
# ADDING: ('oil avocado\r\n  avocados', 'shellfish', 1)
# ADDING: ('oil avocado\r\n  avocados', 'shrimp', 1)
# Deleting... ('garbanzo beans', 'cumin esp toasted', 3)
# ADDING: ('garbanzo beans', 'cumin', 3)
# ADDING: ('garbanzo beans', 'toasted', 3)
# -> — <-
# inp:  paprika — in general
# Deleting... ('paprika — in general', 'hardboiled', 1)
# ADDING: ('paprika', 'hardboiled', 1)

# %%
len(two_ing_pairings)
# Out:
# 32421

# %%
# Check the most common words in the ingredients:

words = []
for ing1, ing2, _ in two_ing_pairings:
  words.extend(ing1.split(' ') + ing2.split(' '))

word_counts = Counter(words)
word_counts.most_common(50)
# Out:
# [('cuisine', 2624),
#  ('oil', 1089),
#  ('fish', 795),
#  ('nuts', 793),
#  ('cream', 790),
#  ('squash', 772),
#  ('basil', 745),
#  ('white', 729),
#  ('beans', 713),
#  ('greens', 679),
#  ('mushrooms', 651),
#  ('beef', 606),
#  ('lemon', 605),
#  ('potatoes', 589),
#  ('chicken', 580),
#  ('cheese', 563),
#  ('pork', 555),
#  ('peppers', 535),
#  ('onions', 528),
#  ('red', 516),
#  ('garlic', 514),
#  ('thyme', 504),
#  ('fennel', 500),
#  ('black', 497),
#  ('juice', 459),
#  ('seeds', 451),
#  ('sauce', 449),
#  ('pumpkin', 446),
#  ('tomatoes', 427),
#  ('sweet', 424),
#  ('rice', 420),
#  ('game', 418),
#  ('ginger', 414),
#  ('dishes', 414),
#  ('coconut', 413),
#  ('leaf', 412),
#  ('olive', 409),
#  ('anise', 406),
#  ('lettuces', 391),
#  ('cheese,', 381),
#  ('fruit', 381),
#  ('chile', 377),
#  ('oranges', 374),
#  ('shellfish', 372),
#  ('green', 370),
#  ('mint', 367),
#  ('butter', 361),
#  ('etc', 359),
#  ('celery', 358),
#  ('peas', 356)]

# %%
two_ing_pairings
# Out:
# [('achiote seeds', 'beef', 1),
#  ('achiote seeds', 'chicken', 1),
#  ('achiote seeds', 'chiles', 1),
#  ('achiote seeds', 'fish', 1),
#  ('achiote seeds', 'garlic', 1),
#  ('achiote seeds', 'pork', 1),
#  ('achiote seeds', 'shrimp', 1),
#  ('african cuisine (south)', 'cinnamon', 1),
#  ('african cuisine (south)', 'cloves', 1),
#  ('african cuisine (south)', 'fenugreek', 1),
#  ('african cuisine (south)', 'garlic', 1),
#  ('african cuisine (south)', 'ginger', 1),
#  ('african cuisine (south)', 'lamb', 1),
#  ('african cuisine (south)', 'onions', 1),
#  ('african cuisine (south)', 'peas', 1),
#  ('african cuisine (south)', 'pumpkin', 1),
#  ('african cuisine (south)', 'stews', 1),
#  ('african cuisine (south)', 'tomatoes', 1),
#  ('african cuisine (south)', 'turmeric', 1),
#  ('african cuisine (west)', 'bananas', 1),
#  ('african cuisine (west)', 'bell peppers', 1),
#  ('african cuisine (west)', 'braised dishes', 1),
#  ('african cuisine (west)', 'chicken', 1),
#  ('african cuisine (west)', 'chile peppers', 1),
#  ('african cuisine (west)', 'corn', 1),
#  ('african cuisine (west)', 'goat', 1),
#  ('african cuisine (west)', 'mangoes', 1),
#  ('african cuisine (west)', 'okra', 1),
#  ('african cuisine (west)', 'papayas', 1),
#  ('african cuisine (west)', 'peanuts', 1),
#  ('african cuisine (west)', 'plantains', 1),
#  ('african cuisine (west)', 'rice', 1),
#  ('african cuisine (west)', 'soups', 1),
#  ('african cuisine (west)', 'stewed dishes', 1),
#  ('african cuisine (west)', 'sweet potatoes', 1),
#  ('african cuisine (west)', 'tomatoes', 1),
#  ('african cuisine (west)', 'wheat', 1),
#  ('african cuisine (west)', 'yams', 1),
#  ('allspice', 'baked goods', 1),
#  ('allspice', 'beans', 1),
#  ('allspice', 'cabbage', 1),
#  ('allspice', 'cakes', 1),
#  ('allspice', 'caribbean cuisine', 3),
#  ('allspice', 'carrots', 1),
#  ('allspice', 'chickpeas', 1),
#  ('allspice', 'chile peppers', 1),
#  ('allspice', 'cinnamon', 1),
#  ('allspice', 'cloves', 1),
#  ('allspice', 'cookies', 1),
#  ('allspice', 'coriander', 1),
#  ('allspice', 'eastern mediterranean cuisine', 3),
#  ('allspice', 'eggplant', 1),
#  ('allspice', 'english cuisine', 3),
#  ('allspice', 'ginger', 1),
#  ('allspice', 'goat', 1),
#  ('allspice', 'grains', 1),
#  ('allspice', 'ham', 1),
#  ('allspice', 'herring, pickled', 1),
#  ('allspice', 'indian cuisine', 3),
#  ('allspice', 'ketchup', 1),
#  ('allspice', 'lamb', 1),
#  ('allspice', 'mace', 1),
#  ('allspice', 'middle eastern cuisine', 3),
#  ('allspice', 'mushrooms', 1),
#  ('allspice', 'mustard', 1),
#  ('allspice', 'north american cuisine', 3),
#  ('allspice', 'nutmeg', 1),
#  ('allspice', 'nuts', 1),
#  ('allspice', 'onions', 1),
#  ('allspice', 'pepper, black', 1),
#  ('allspice', 'pies', 1),
#  ('allspice', 'pineapple', 1),
#  ('allspice', 'pork', 1),
#  ('allspice', 'pumpkin', 3),
#  ('allspice', 'rabbit', 1),
#  ('allspice', 'rice', 1),
#  ('allspice', 'rosemary', 1),
#  ('allspice', 'sauerkraut', 1),
#  ('allspice', 'sausages', 1),
#  ('allspice', 'soups', 1),
#  ('allspice', 'spiced cakes', 1),
#  ('allspice', 'spinach', 1),
#  ('allspice', 'squash, winter', 1),
#  ('allspice', 'stews', 1),
#  ('allspice', 'sweet potatoes', 1),
#  ('allspice', 'thyme', 1),
#  ('allspice', 'tomatoes', 1),
#  ('allspice', 'turnips', 1),
#  ('allspice', 'west indies cuisine', 3),
#  ('amaretto (sweet almond liqueur)', 'almonds', 1),
#  ('amaretto (sweet almond liqueur)', 'apricots', 1),
#  ('amaretto (sweet almond liqueur)', 'butter', 1),
#  ('amaretto (sweet almond liqueur)', 'cherries', 1),
#  ('amaretto (sweet almond liqueur)', 'chocolate', 1),
#  ('amaretto (sweet almond liqueur)', 'coffee', 1),
#  ('amaretto (sweet almond liqueur)', 'cream', 1),
#  ('amaretto (sweet almond liqueur)', 'hazelnuts', 1),
#  ('amaretto (sweet almond liqueur)', 'italian cuisine', 3),
#  ('amaretto (sweet almond liqueur)', 'peaches', 1),
#  ('amaretto (sweet almond liqueur)', 'pork', 1),
#  ('amaretto (sweet almond liqueur)', 'sugar', 1),
#  ('anchovies', 'almonds', 1),
#  ('anchovies', 'basil', 1),
#  ('anchovies', 'beans, green', 1),
#  ('anchovies', 'capers', 1),
#  ('anchovies', 'carrots', 1),
#  ('anchovies', 'cauliflower', 1),
#  ('anchovies', 'celery', 1),
#  ('anchovies', 'chives', 1),
#  ('anchovies', 'eggs, hard-boiled', 1),
#  ('anchovies', 'fennel', 1),
#  ('anchovies', 'garlic', 3),
#  ('anchovies', 'lemon, juice', 1),
#  ('anchovies', 'lobster', 1),
#  ('anchovies', 'mayonnaise', 1),
#  ('anchovies', 'mediterranean cuisine', 3),
#  ('anchovies', 'nectarines', 1),
#  ('anchovies', 'olive oil', 3),
#  ('anchovies', 'onions', 1),
#  ('anchovies', 'orange, zest', 1),
#  ('anchovies', 'parsley, flat-leaf', 1),
#  ('anchovies', 'pasta', 1),
#  ('anchovies', 'peppers, piquillo', 1),
#  ('anchovies', 'pizza', 1),
#  ('anchovies', 'potatoes', 1),
#  ('anchovies', 'puttanesca sauce (key ingredient)', 1),
#  ('anchovies', 'red pepper flakes', 1),
#  ('anchovies', 'romaine lettuce', 1),
#  ('anchovies', 'rosemary', 1),
#  ('anchovies', 'salmon', 1),
#  ('anchovies', 'shallots', 1),
#  ('anchovies', 'sherry, px', 3),
#  ('anchovies', 'tapenade (key ingredient)', 1),
#  ('anchovies', 'thyme', 1),
#  ('anchovies', 'tomatoes', 1),
#  ('anchovies', 'tuna', 1),
#  ('angelica', 'anise', 1),
#  ('angelica', 'apricots', 1),
#  ('angelica', 'candy', 1),
#  ('angelica', 'custards', 1),
#  ('angelica', 'desserts', 1),
#  ('angelica', 'fish', 1),
#  ('angelica', 'fruits', 1),
#  ('angelica', 'hazelnuts', 1),
#  ('angelica', 'juniper berries', 1),
#  ('angelica', 'lavender', 1),
#  ('angelica', 'lemon balm', 1),
#  ('angelica', 'liqueurs', 1),
#  ('angelica', 'mushrooms', 1),
#  ('angelica', 'oranges', 1),
#  ('angelica', 'pepper, black', 1),
#  ('angelica', 'plums', 1),
#  ('angelica', 'rhubarb', 5),
#  ('angelica', 'salads', 1),
#  ('angelica', 'shellfish', 1),
#  ('angelica', 'strawberries', 1),
#  ('anise hyssop', 'cherries', 1),
#  ('anise hyssop', 'chervil', 1),
#  ('anise hyssop', 'chicken', 1),
#  ('anise hyssop', 'currants', 1),
#  ('anise hyssop', 'custards', 1),
#  ('anise hyssop', 'desserts', 1),
#  ('anise hyssop', 'fennel bulb', 1),
#  ('anise hyssop', 'fish', 1),
#  ('anise hyssop', 'honey', 1),
#  ('anise hyssop', 'lavender', 1),
#  ('anise hyssop', 'lemon', 1),
#  ('anise hyssop', 'lychees', 1),
#  ('anise hyssop', 'marjoram', 1),
#  ('anise hyssop', 'melons', 1),
#  ('anise hyssop', 'mint', 1),
#  ('anise hyssop', 'nectarines', 1),
#  ('anise hyssop', 'oranges', 1),
#  ('anise hyssop', 'parsley', 1),
#  ('anise hyssop', 'parsnips', 1),
#  ('anise hyssop', 'peaches', 1),
#  ('anise hyssop', 'pears', 1),
#  ('anise hyssop', 'plums', 1),
#  ('anise hyssop', 'pork', 1),
#  ('anise hyssop', 'raspberries', 1),
#  ('anise hyssop', 'rice', 1),
#  ('anise hyssop', 'shrimp', 1),
#  ('anise hyssop', 'spinach', 1),
#  ('anise hyssop', 'squash, winter', 1),
#  ('anise hyssop', 'sweet potatoes', 1),
#  ('anise hyssop', 'tarragon', 1),
#  ('anise hyssop', 'teas', 1),
#  ('anise hyssop', 'tomatoes', 1),
#  ('anise hyssop', 'vegetables, root', 1),
#  ('anise hyssop', 'watermelon', 1),
#  ('anise hyssop', 'zucchini', 1),
#  ('anise, star', 'beef', 1),
#  ('anise, star', 'beverages', 1),
#  ('anise, star', 'cardamom', 1),
#  ('anise, star', 'chestnuts', 1),
#  ('anise, star', 'chicken', 1),
#  ('anise, star', 'chile peppers', 1),
#  ('anise, star', 'chili powder', 1),
#  ('anise, star', 'chinese cuisine', 3),
#  ('anise, star', 'cinnamon', 1),
#  ('anise, star', 'citrus zest', 1),
#  ('anise, star', 'cloves', 1),
#  ('anise, star', 'coriander', 1),
#  ('anise, star', 'cumin', 1),
#  ('anise, star', 'curry powder (ingredient)', 1),
#  ('anise, star', 'duck', 1),
#  ('anise, star', 'eggs', 1),
#  ('anise, star', 'fennel seeds', 1),
#  ('anise, star', 'figs', 1),
#  ('anise, star', 'fish', 1),
#  ('anise, star', 'five-spice powder', 3),
#  ('anise, star', 'garlic', 1),
#  ('anise, star', 'ginger', 1),
#  ('anise, star', 'indian cuisine', 3),
#  ('anise, star', 'kumquats', 1),
#  ('anise, star', 'leeks', 1),
#  ('anise, star', 'lemongrass', 1),
#  ('anise, star', 'lime, zest', 1),
#  ('anise, star', 'liqueurs', 1),
#  ('anise, star', 'mace', 1),
#  ('anise, star', 'malaysian cuisine', 3),
#  ('anise, star', 'mangoes', 1),
#  ('anise, star', 'maple syrup', 1),
#  ('anise, star', 'nutmeg', 1),
#  ('anise, star', 'orange, zest', 1),
#  ('anise, star', 'oxtails', 1),
#  ('anise, star', 'pineapple', 1),
#  ('anise, star', 'pork', 1),
#  ('anise, star', 'poultry', 1),
#  ('anise, star', 'pumpkin', 1),
#  ('anise, star', 'raspberries', 1),
#  ('anise, star', 'root vegetables', 1),
#  ('anise, star', 'salmon', 1),
#  ('anise, star', 'sauces', 1),
#  ('anise, star', 'scallions', 1),
#  ('anise, star', 'scallops', 1),
#  ('anise, star', 'shellfish', 1),
#  ('anise, star', 'shrimp', 1),
#  ('anise, star', 'soups', 1),
#  ('anise, star', 'soy sauce', 1),
#  ('anise, star', 'stews', 1),
#  ('anise, star', 'sweet potatoes', 1),
#  ('anise, star', 'tamarind', 1),
#  ('anise, star', 'teas', 1),
#  ('anise, star', 'tuna', 1),
#  ('anise, star', 'turmeric', 1),
#  ('anise, star', 'vanilla', 1),
#  ('anise, star', 'vietnamese cuisine (e.g.,pho)', 3),
#  ('anise, star', 'wine, rice', 1),
#  ('apples', 'almonds', 1),
#  ('apples', 'applejack', 1),
#  ('apples', 'armagnac', 3),
#  ('apples', 'bacon', 1),
#  ('apples', 'bay leaf', 1),
#  ('apples', 'beef', 1),
#  ('apples', 'blackberries', 1),
#  ('apples', 'bourbon', 1),
#  ('apples', 'brioche', 1),
#  ('apples', 'butter, unsalted', 3),
#  ('apples', 'butterscotch', 1),
#  ('apples', 'cabbage, red', 1),
#  ('apples', 'calvados', 3),
#  ('apples', 'caramel', 3),
#  ('apples', 'cardamom', 1),
#  ('apples', 'celery', 1),
#  ('apples', 'celery root', 1),
#  ('apples', 'chestnuts', 1),
#  ('apples', 'chicken', 1),
#  ('apples', 'chives', 1),
#  ('apples', 'cider', 1),
#  ('apples', 'cinnamon', 5),
#  ('apples', 'cloves', 1),
#  ('apples', 'cognac', 1),
#  ('apples', 'cointreau', 3),
#  ('apples', 'coriander', 1),
#  ('apples', 'cranberries', 1),
#  ('apples', 'crème anglaise (sauce)', 1),
#  ('apples', 'crème fraîche', 1),
#  ('apples', 'cumin', 1),
#  ('apples', 'custards', 1),
#  ('apples', 'dates', 1),
#  ('apples', 'duck', 1),
#  ('apples', 'eggplant', 1),
#  ('apples', 'fennel', 1),
#  ('apples', 'frisée', 1),
#  ('apples', 'ginger', 1),
#  ('apples', 'goose', 1),
#  ('apples', 'hazelnuts', 1),
#  ('apples', 'horseradish', 1),
#  ('apples', 'ice cream', 1),
#  ('apples', 'kirsch', 3),
#  ('apples', 'lavender', 1),
#  ('apples', 'lemon thyme', 1),
#  ('apples', 'lychees', 1),
#  ('apples', 'madeira', 3),
#  ('apples', 'maple syrup', 1),
#  ('apples', 'mayonnaise', 1),
#  ('apples', 'meringue', 1),
#  ('apples', 'molasses', 1),
#  ('apples', 'mustard', 1),
#  ('apples', 'nutmeg', 1),
#  ('apples', 'nuts', 1),
#  ('apples', 'olive oil', 1),
#  ('apples', 'parsley', 1),
#  ('apples', 'pears', 1),
#  ('apples', 'pecans', 1),
#  ('apples', 'pepper, black', 1),
#  ('apples', 'pies', 1),
#  ('apples', 'pineapple', 1),
#  ('apples', 'pine nuts', 1),
#  ('apples', 'pistachios', 1),
#  ('apples', 'plums', 1),
#  ('apples', 'pomegranates', 1),
#  ('apples', 'pork', 1),
#  ('apples', 'poultry', 1),
#  ('apples', 'prunes', 1),
#  ('apples', 'puff pastry', 1),
#  ('apples', 'pumpkin', 1),
#  ('apples', 'quince', 1),
#  ('apples', 'rhubarb', 1),
#  ('apples', 'rosemary', 1),
#  ('apples', 'salt, kosher', 1),
#  ('apples', 'sauerkraut', 1),
#  ('apples', 'sherry', 1),
#  ('apples', 'soups', 1),
#  ('apples', 'sour cream', 1),
#  ('apples', 'star anise', 1),
#  ('apples', 'sweet potatoes', 1),
#  ('apples', 'tarragon', 1),
#  ('apples', 'tarts', 1),
#  ('apples', 'thyme', 1),
#  ('apples', 'vanilla', 1),
#  ('apples', 'verjus', 1),
#  ('apples', 'vermouth', 1),
#  ('apples', 'walnuts', 3),
#  ('apples', 'yogurt', 1),
#  ('apricots, dried', 'allspice', 1),
#  ('apricots, dried', 'cherries, dried', 1),
#  ('apricots, dried', 'cinnamon', 1),
#  ('apricots, dried', 'currants', 1),
#  ('apricots, dried', 'custard', 1),
#  ('apricots, dried', 'french toast', 3),
#  ('apricots, dried', 'ginger', 1),
#  ('apricots, dried', 'hazelnuts', 1),
#  ('apricots, dried', 'honey', 1),
#  ('apricots, dried', 'ice cream', 1),
#  ('apricots, dried', 'madeira', 3),
#  ('apricots, dried', 'moroccan cuisine', 3),
#  ('apricots, dried', 'pancakes/crepes', 1),
#  ('apricots, dried', 'pistachios', 1),
#  ('apricots, dried', 'pork', 1),
#  ('apricots, dried', 'prunes', 1),
#  ('apricots, dried', 'pumpkin seeds', 1),
#  ('apricots, dried', 'raisins', 1),
#  ('apricots, dried', 'rice pudding', 1),
#  ('apricots, dried', 'sugar', 1),
#  ('apricots, dried', 'tamarind paste', 1),
#  ('apricots, dried', 'vanilla', 1),
#  ('aroma', 'cinnamon', 1),
#  ('aroma', 'herbs', 1),
#  ('aroma', 'pineapple', 1),
#  ('aroma', 'sous-vide cooking', 1),
#  ('aroma', 'spices', 1),
#  ('aroma', 'star anise', 1),
#  ('aroma', 'truffles', 1),
#  ('aroma', 'vanilla', 1),
#  ('artichokes', 'anchovies', 1),
#  ('artichokes', 'arugula', 1),
#  ('artichokes', 'bacon', 1),
#  ('artichokes', 'basil', 1),
#  ('artichokes', 'bay leaf', 1),
#  ('artichokes', 'beans, fava', 1),
#  ('artichokes', 'beets', 1),
#  ('artichokes', 'bread crumbs', 1),
#  ('artichokes', 'butter', 1),
#  ('artichokes', 'capers', 1),
#  ('artichokes', 'carrots', 1),
#  ('artichokes', 'cashews', 1),
#  ('artichokes', 'celery', 1),
#  ('artichokes', 'chervil', 1),
#  ('artichokes', 'chicken', 1),
#  ('artichokes', 'chives', 1),
#  ('artichokes', 'coriander', 1),
#  ('artichokes', 'cream', 1),
#  ('artichokes', 'crème fraîche', 1),
#  ('artichokes', 'french cuisine', 3),
#  ('artichokes', 'garlic', 3),
#  ('artichokes', 'grapefruit', 1),
#  ('artichokes', 'hazelnuts', 1),
#  ('artichokes', 'hollandaise sauce', 1),
#  ('artichokes', 'italian cuisine', 3),
#  ('artichokes', 'leeks', 1),
#  ('artichokes', 'lobster', 1),
#  ('artichokes', 'mayonnaise', 1),
#  ('artichokes', 'mediterranean cuisine', 3),
#  ('artichokes', 'mint', 3),
#  ('artichokes', 'moroccan cuisine', 3),
#  ('artichokes', 'mushrooms', 1),
#  ('artichokes', 'mustard, dijon', 3),
#  ('artichokes', 'olive oil', 3),
#  ('artichokes', 'pancetta', 1),
#  ('artichokes', 'parsley, flat-leaf', 3),
#  ('artichokes', 'pesto', 1),
#  ('artichokes', 'piquillo peppers', 1),
#  ('artichokes', 'potatoes', 1),
#  ('artichokes', 'prosciutto', 1),
#  ('artichokes', 'radicchio', 1),
#  ('artichokes', 'red pepper flakes', 1),
#  ('artichokes', 'rice', 1),
#  ('artichokes', 'risotto', 1),
#  ('artichokes', 'rosemary', 1),
#  ('artichokes', 'saffron', 1),
#  ('artichokes', 'sage', 1),
#  ('artichokes', 'salads', 1),
#  ('artichokes', 'salt, kosher', 3),
#  ('artichokes', 'savory', 1),
#  ('artichokes', 'shallots', 1),
#  ('artichokes', 'sherry, dry', 1),
#  ('artichokes', 'shrimp', 1),
#  ('artichokes', 'soy sauce', 1),
#  ('artichokes', 'spanish cuisine', 3),
#  ('artichokes', 'spinach', 1),
#  ('artichokes', 'stock, chicken', 1),
#  ('artichokes', 'sugar (pinch)', 1),
#  ('artichokes', 'tapenade', 1),
#  ('artichokes', 'tarragon, fresh', 1),
#  ('artichokes', 'thyme, fresh', 3),
#  ('artichokes', 'tomatoes', 3),
#  ('artichokes', 'truffles, black', 1),
#  ('artichokes', 'tuna', 1),
#  ('artichokes', 'vinaigrette', 1),
#  ('artichokes', 'walnuts', 1),
#  ('artichokes', 'wine, dry white', 3),
#  ('artichokes', 'yogurt', 1),
#  ('artichokes, jerusalem', 'bacon', 1),
#  ('artichokes, jerusalem', 'bay leaf', 1),
#  ('artichokes, jerusalem', 'butter', 1),
#  ('artichokes, jerusalem', 'celery', 1),
#  ('artichokes, jerusalem', 'cheese, goat', 1),
#  ('artichokes, jerusalem', 'chervil', 1),
#  ('artichokes, jerusalem', 'chives', 1),
#  ('artichokes, jerusalem', 'coriander', 1),
#  ('artichokes, jerusalem', 'cream', 1),
#  ('artichokes, jerusalem', 'cumin', 1),
#  ('artichokes, jerusalem', 'dill', 1),
#  ('artichokes, jerusalem', 'fennel leaves', 1),
#  ('artichokes, jerusalem', 'fennel seeds', 1),
#  ('artichokes, jerusalem', 'garlic', 1),
#  ('artichokes, jerusalem', 'ginger', 1),
#  ('artichokes, jerusalem', 'hazelnuts', 1),
#  ('artichokes, jerusalem', 'leeks', 1),
#  ('artichokes, jerusalem', 'lemon, juice', 1),
#  ('artichokes, jerusalem', 'mace', 1),
#  ('artichokes, jerusalem', 'morels', 1),
#  ('artichokes, jerusalem', 'nutmeg', 1),
#  ('artichokes, jerusalem', 'olive oil', 1),
#  ('artichokes, jerusalem', 'onions', 1),
#  ('artichokes, jerusalem', 'parsley, flat-leaf', 1),
#  ('artichokes, jerusalem', 'pepper, black', 1),
#  ('artichokes, jerusalem', 'potatoes', 1),
#  ('artichokes, jerusalem', 'rosemary', 1),
#  ('artichokes, jerusalem', 'sage', 1),
#  ('artichokes, jerusalem', 'salmon', 1),
#  ('artichokes, jerusalem', 'salt, sea', 1),
#  ('artichokes, jerusalem', 'shallots', 1),
#  ('artichokes, jerusalem', 'stock, chicken', 1),
#  ('artichokes, jerusalem', 'tarragon', 1),
#  ('artichokes, jerusalem', 'thyme', 1),
#  ('artichokes, jerusalem', 'vinegar', 1),
#  ('artichokes, jerusalem', 'wine, dry white', 1),
#  ('asparagus, white', 'chicken', 1),
#  ('asparagus, white', 'crab', 1),
#  ('asparagus, white', 'ham', 1),
#  ('asparagus, white', 'hazelnuts', 1),
#  ('asparagus, white', 'lemon', 1),
#  ('asparagus, white', 'mustard', 1),
#  ('asparagus, white', 'oil, truffle', 1),
#  ('asparagus, white', 'olive oil', 1),
#  ('asparagus, white', 'parsley', 1),
#  ('asparagus, white', 'pepper, black', 1),
#  ('asparagus, white', 'salt, sea', 1),
#  ('asparagus, white', 'shallots', 1),
#  ('asparagus, white', 'shrimp', 1),
#  ('asparagus, white', 'stock, chicken', 1),
#  ('asparagus, white', 'sugar (pinch)', 1),
#  ('asparagus, white', 'tarragon', 1),
#  ('asparagus, white', 'vinaigrette', 1),
#  ('asparagus, white', 'wine, riesling', 3),
#  ('asparagus, white', 'apples (astringent-sweet)', 1),
#  ('asparagus, white', 'artichokes', 1),
#  ('asparagus, white', 'asparagus', 1),
#  ('asparagus, white', 'bananas, unripe (astringent-sweet)', 1),
#  ('asparagus, white', 'basil', 1),
#  ('asparagus, white', 'beans', 1),
#  ('asparagus, white', 'berries', 1),
#  ('asparagus, white', 'broccoli', 1),
#  ('asparagus, white', 'buckwheat', 1),
#  ('asparagus, white', 'cashews', 1),
#  ('asparagus, white', 'cauliflower', 1),
#  ('asparagus, white', 'coffee', 1),
#  ('asparagus, white', 'cranberries', 1),
#  ('asparagus, white', 'figs (astringent-sweet)', 1),
#  ('asparagus, white', 'grapes (astringent-sour-sweet)', 1),
#  ('asparagus, white', 'hazelnuts', 1),
#  ('asparagus, white', 'herbs', 1),
#  ('asparagus, white', 'honey', 1),
#  ('asparagus, white', 'legumes', 1),
#  ('asparagus, white', 'lentils', 1),
#  ('asparagus, white', 'lettuce', 1),
#  ('asparagus, white', 'mace', 1),
#  ('asparagus, white', 'marjoram', 1),
#  ('asparagus, white', 'okra', 1),
#  ('asparagus, white', 'parsley', 1),
#  ('asparagus, white', 'peaches (astringent-sweet)', 1),
#  ('asparagus, white', 'pears (astringent-sweet)', 1),
#  ('asparagus, white', 'persimmons', 1),
#  ('asparagus, white', 'plums (astringent-sweet)', 1),
#  ('asparagus, white', 'pomegranates (astringent-sour-sweet)', 1),
#  ('asparagus, white', 'quinoa', 1),
#  ('asparagus, white', 'rhubarb', 1),
#  ('asparagus, white', 'rye', 1),
#  ('asparagus, white', 'saffron', 1),
#  ('asparagus, white', 'sprouts', 1),
#  ('asparagus, white', 'tea', 1),
#  ('asparagus, white', 'turmeric', 1),
#  ('asparagus, white', 'turnips', 1),
#  ('asparagus, white', 'vegetables, raw', 1),
#  ('asparagus, white', 'walnuts', 1),
#  ('australian cuisine', 'barbecued foods', 1),
#  ('australian cuisine', 'beef', 1),
#  ('australian cuisine', 'cheese', 1),
#  ('australian cuisine', 'fish', 1),
#  ('australian cuisine', 'fruits, fresh', 1),
#  ('australian cuisine', 'lamb', 1),
#  ('australian cuisine', 'nuts, macadamia', 1),
#  ('australian cuisine', 'seafood', 1),
#  ('australian cuisine', 'vegetables, fresh', 1),
#  ('australian cuisine', 'wines', 1),
#  ('austrian cuisine', 'beer', 1),
#  ('austrian cuisine', 'cinnamon', 1),
#  ('austrian cuisine', 'coffee', 1),
#  ('austrian cuisine', 'cream', 1),
#  ('austrian cuisine', 'desserts', 1),
#  ('austrian cuisine', 'dumplings', 1),
#  ('austrian cuisine', 'goulash', 1),
#  ('austrian cuisine', 'marjoram', 1),
#  ('austrian cuisine', 'parsley', 1),
#  ('austrian cuisine', 'pastries', 1),
#  ('austrian cuisine', 'potatoes', 1),
#  ('austrian cuisine', 'schnitzel', 1),
#  ('austrian cuisine', 'strudel', 1),
#  ('austrian cuisine', 'wine', 1),
#  ('autumn', 'broccoli', 1),
#  ('autumn', 'caramel', 1),
#  ('autumn', 'cauliflower', 1),
#  ('autumn', 'chile peppers', 1),
#  ('autumn', 'dates', 1),
#  ('autumn', 'duck', 1),
#  ('autumn', 'fennel', 1),
#  ('autumn', 'foie gras', 1),
#  ('autumn', 'grains', 1),
#  ('autumn', 'heavier dishes', 1),
#  ('autumn', 'lentils', 1),
#  ('autumn', 'nuts', 1),
#  ('autumn', 'polenta', 1),
#  ('autumn', 'scallops', 1),
#  ('autumn', 'seeds, sunflower', 1),
#  ('autumn', 'stuffing', 1),
#  ('autumn', 'sweetbreads', 1),
#  ('autumn', 'turkey', 1),
#  ('autumn', 'vinegar, red wine', 1),
#  ('autumn', 'walnuts', 1),
#  ('bacon', 'breakfast', 1),
#  ('bacon', 'butter, unsalted', 1),
#  ('bacon', 'celery', 1),
#  ('bacon', 'chervil', 1),
#  ('bacon', 'chicken', 1),
#  ('bacon', 'eggs', 1),
#  ('bacon', 'french cuisine', 3),
#  ('bacon', 'frisée', 1),
#  ('bacon', 'italian cuisine', 3),
#  ('bacon', 'lentils', 1),
#  ('bacon', 'lettuce', 1),
#  ('bacon', 'maple syrup', 1),
#  ('bacon', 'mayonnaise', 1),
#  ('bacon', 'olive oil', 1),
#  ('bacon', 'onions', 1),
#  ('bacon', 'parsnips', 1),
#  ('bacon', 'peas', 1),
#  ('bacon', 'pepper, black', 1),
#  ('bacon', 'potatoes', 1),
#  ('bacon', 'risotto', 1),
#  ('bacon', 'salads', 1),
#  ('bacon', 'salmon', 1),
#  ('bacon', 'salt', 1),
#  ('bacon', 'scallops', 1),
#  ('bacon', 'shallots', 1),
#  ('bacon', 'spinach', 1),
#  ('bacon', 'squash, winter', 1),
#  ('bacon', 'stews', 1),
#  ('bacon', 'stock, chicken', 1),
#  ('bacon', 'tomatoes', 1),
#  ('bacon', 'vinegar', 1),
#  ('bananas', 'almonds', 1),
#  ('bananas', 'apricots', 1),
#  ('bananas', 'armagnac', 3),
#  ('bananas', 'banana liqueur', 1),
#  ('bananas', 'blackberries', 1),
#  ('bananas', 'blueberries', 1),
#  ('bananas', 'brandy', 1),
#  ('bananas', 'breakfast', 1),
#  ('bananas', 'butter, unsalted', 1),
#  ('bananas', 'buttermilk', 1),
#  ('bananas', 'butterscotch', 1),
#  ('bananas', 'cakes', 1),
#  ('bananas', 'calvados', 3),
#  ('bananas', 'caramel', 3),
#  ('bananas', 'cardamom', 1),
#  ('bananas', 'cashews', 1),
#  ('bananas', 'cherries', 1),
#  ('bananas', 'cinnamon', 1),
#  ('bananas', 'cloves', 1),
#  ('bananas', 'coffee', 1),
#  ('bananas', 'cognac', 1),
#  ('bananas', 'cream cheese', 1),
#  ('bananas', 'crème anglaise', 1),
#  ('bananas', 'crème fraîche', 1),
#  ('bananas', 'curries', 1),
#  ('bananas', 'custard', 1),
#  ('bananas', 'dates', 1),
#  ('bananas', 'desserts', 1),
#  ('bananas', 'figs, dried', 1),
#  ('bananas', 'ginger', 1),
#  ('bananas', 'guava', 1),
#  ('bananas', 'hazelnuts', 1),
#  ('bananas', 'honey', 1),
#  ('bananas', 'kirsch', 3),
#  ('bananas', 'lemon, juice', 3),
#  ('bananas', 'lemongrass', 1),
#  ('bananas', 'lime, juice', 1),
#  ('bananas', 'macadamia', 1),
#  ('bananas', 'maple syrup', 1),
#  ('bananas', 'meringue', 1),
#  ('bananas', 'nutmeg', 1),
#  ('bananas', 'oil, vegetable', 1),
#  ('bananas', 'orange', 1),
#  ('bananas', 'pancakes', 1),
#  ('bananas', 'papaya', 1),
#  ('bananas', 'parsley', 1),
#  ('bananas', 'passion fruit', 1),
#  ('bananas', 'pecans', 1),
#  ('bananas', 'pepper, black', 1),
#  ('bananas', 'pineapple', 1),
#  ('bananas', 'pistachios', 1),
#  ('bananas', 'pomegranate', 1),
#  ('bananas', 'puddings', 1),
#  ('bananas', 'raisins', 1),
#  ('bananas', 'rice', 1),
#  ('bananas', 'rum', 3),
#  ('bananas', 'salads, fruit', 1),
#  ('bananas', 'sesame seeds', 1),
#  ('bananas', 'sour cream', 1),
#  ('bananas', 'strawberries', 1),
#  ('bananas', 'sweet potatoes', 1),
#  ('bananas', 'tabasco sauce', 3),
#  ('bananas', 'vanilla', 1),
#  ('bananas', 'vinegar, white', 1),
#  ('bananas', 'walnuts', 1),
#  ('bananas', 'yogurt', 1),
#  ('barley', 'butter', 1),
#  ('barley', 'garlic', 1),
#  ('barley', 'lemon thyme', 1),
#  ('barley', 'mirepoix (carrots, celery, onions)', 1),
#  ('barley', 'olive oil', 1),
#  ('barley', 'onions', 1),
#  ('barley', 'oregano', 1),
#  ('barley', 'parsley, flat-leaf', 1),
#  ('barley', 'pepper, white', 1),
#  ('barley', 'sage', 1),
#  ('barley', 'salt, kosher', 1),
#  ('barley', 'savory', 1),
#  ('barley', 'scallions', 1),
#  ('barley', 'soups', 1),
#  ('barley', 'thyme', 1),
#  ('barley', 'tomatoes', 1),
#  ('barley', 'vinegar, sherry', 1),
#  ('basil, thai', 'ginger', 1),
#  ('basil, thai', 'lemongrass', 1),
#  ('basil, thai', 'salads', 1),
#  ('basil, thai', 'seafood', 1),
#  ('basil, thai', 'thai cuisine', 3),
#  ('basil, thai', 'vegetarian dishes', 1),
#  ('basil, thai', 'venison', 1),
#  ('bass, black', 'celery', 1),
#  ('bass, black', 'chestnuts', 1),
#  ('bass, black', 'chile peppers, jalapeño', 1),
#  ('bass, black', 'chives', 1),
#  ('bass, black', 'chutney', 1),
#  ('bass, black', 'cilantro', 1),
#  ('bass, black', 'coriander', 1),
#  ('bass, black', 'duck, peking', 3),
#  ('bass, black', 'endive', 1),
#  ('bass, black', 'fennel', 1),
#  ('bass, black', 'garlic', 1),
#  ('bass, black', 'ginger', 1),
#  ('bass, black', 'ham', 1),
#  ('bass, black', 'honey', 1),
#  ('bass, black', 'leeks', 1),
#  ('bass, black', 'lemon', 1),
#  ('bass, black', 'lemon, preserved', 1),
#  ('bass, black', 'lime', 1),
#  ('bass, black', 'marjoram', 1),
#  ('bass, black', 'mint', 1),
#  ('bass, black', 'mushrooms, porcini', 1),
#  ('bass, black', 'mustard', 1),
#  ('bass, black', 'olive oil', 1),
#  ('bass, black', 'onions', 1),
#  ('bass, black', 'orange, juice', 1),
#  ('bass, black', 'oregano', 1),
#  ('bass, black', 'papaya', 1),
#  ('bass, black', 'parsley, flat-leaf', 1),
#  ('bass, black', 'parsnips', 1),
#  ('bass, black', 'peas', 1),
#  ('bass, black', 'pepper, white', 1),
#  ('bass, black', 'raisins', 1),
#  ('bass, black', 'saffron', 1),
#  ('bass, black', 'salt, sea', 1),
#  ('bass, black', 'scallions', 1),
#  ('bass, black', 'scallops', 1),
#  ('bass, black', 'shallots', 1),
#  ('bass, black', 'shrimp', 1),
#  ('bass, black', 'stock, chicken', 1),
#  ('bass, black', 'tarragon', 1),
#  ('bass, black', 'thyme', 1),
#  ('bass, black', 'tomatoes', 1),
#  ('bass, black', 'tuna', 1),
#  ('bass, black', 'turnips', 1),
#  ('bass, black', 'zucchini', 1),
#  ('bass, sea', 'anchovies', 1),
#  ('bass, sea', 'artichokes', 1),
#  ('bass, sea', 'bacon', 1),
#  ('bass, sea', 'basil', 1),
#  ('bass, sea', 'bay leaf', 1),
#  ('bass, sea', 'bread crumbs', 1),
#  ('bass, sea', 'capers', 1),
#  ('bass, sea', 'cardamom', 1),
#  ('bass, sea', 'carrots', 1),
#  ('bass, sea', 'cayenne', 1),
#  ('bass, sea', 'celery', 1),
#  ('bass, sea', 'chervil', 1),
#  ('bass, sea', 'chives', 1),
#  ('bass, sea', 'cilantro', 1),
#  ('bass, sea', 'citrus', 1),
#  ('bass, sea', 'coriander', 1),
#  ('bass, sea', 'corn', 1),
#  ('bass, sea', 'cream', 1),
#  ('bass, sea', 'crème fraîche', 1),
#  ('bass, sea', 'fennel', 1),
#  ('bass, sea', 'garlic, fresh', 1),
#  ('bass, sea', 'ginger, fresh', 1),
#  ('bass, sea', 'hazelnuts', 1),
#  ('bass, sea', 'honey', 1),
#  ('bass, sea', 'leeks', 1),
#  ('bass, sea', 'lemon, preserved', 1),
#  ('bass, sea', 'lentils', 1),
#  ('bass, sea', 'lime, juice', 1),
#  ('bass, sea', 'marjoram', 1),
#  ('bass, sea', 'mayonnaise', 1),
#  ('bass, sea', 'mint', 1),
#  ('bass, sea', 'mirepoix (carrots, celery, onions)', 1),
#  ('bass, sea', 'mirin', 1),
#  ('bass, sea', 'new potatoes', 1),
#  ('bass, sea', 'olive oil', 1),
#  ('bass, sea', 'olives, black', 1),
#  ('bass, sea', 'oregano', 1),
#  ('bass, sea', 'parsley, flat-leaf', 1),
#  ('bass, sea', 'radishes', 1),
#  ('bass, sea', 'rhubarb', 1),
#  ('bass, sea', 'saffron', 1),
#  ('bass, sea', 'sake', 1),
#  ('bass, sea', 'salmon roe', 1),
#  ('bass, sea', 'salt, kosher', 3),
#  ('bass, sea', 'scallops', 1),
#  ('bass, sea', 'sesame seeds', 1),
#  ('bass, sea', 'shallots', 1),
#  ('bass, sea', 'shiso', 1),
#  ('bass, sea', 'shrimp', 1),
#  ('bass, sea', 'soy sauce', 1),
#  ('bass, sea', 'spearmint', 1),
#  ('bass, sea', 'star anise', 1),
#  ('bass, sea', 'sugar', 1),
#  ('bass, sea', 'tamarind', 1),
#  ('bass, sea', 'tarragon', 1),
#  ('bass, sea', 'thyme, fresh', 1),
#  ('bass, sea', 'vanilla', 1),
#  ('bass, sea', 'vermouth', 1),
#  ('bass, sea', 'wine, dry white', 1),
#  ('bass, sea', 'yuzu juice', 1),
#  ('bass, sea', 'zucchini', 1),
#  ('bass, striped weight: medium', 'bacon', 1),
#  ('bass, striped weight: medium', 'bay leaf', 1),
#  ('bass, striped weight: medium', 'beets', 1),
#  ('bass, striped weight: medium', 'bok choy', 1),
#  ('bass, striped weight: medium', 'buttermilk', 1),
#  ('bass, striped weight: medium', 'calamari', 1),
#  ('bass, striped weight: medium', 'carrots', 1),
#  ('bass, striped weight: medium', 'cauliflower', 1),
#  ('bass, striped weight: medium', 'cayenne', 1),
#  ('bass, striped weight: medium', 'celery', 1),
#  ('bass, striped weight: medium', 'chanterelles', 1),
#  ('bass, striped weight: medium', 'chervil', 1),
#  ('bass, striped weight: medium', 'chives', 1),
#  ('bass, striped weight: medium', 'cilantro', 1),
#  ('bass, striped weight: medium', 'clams', 1),
#  ('bass, striped weight: medium', 'corn', 1),
#  ('bass, striped weight: medium', 'cream', 1),
#  ('bass, striped weight: medium', 'cucumber', 1),
#  ('bass, striped weight: medium', 'dill', 1),
#  ('bass, striped weight: medium', 'fava beans', 1),
#  ('bass, striped weight: medium', 'fennel', 1),
#  ('bass, striped weight: medium', 'fish sauce', 1),
#  ('bass, striped weight: medium', 'garlic', 1),
#  ('bass, striped weight: medium', 'ginger', 1),
#  ('bass, striped weight: medium', 'hollandaise sauce', 1),
#  ('bass, striped weight: medium', 'horseradish', 1),
#  ('bass, striped weight: medium', 'leeks', 1),
#  ('bass, striped weight: medium', 'lemon verbena', 1),
#  ('bass, striped weight: medium', 'lime, juice', 1),
#  ('bass, striped weight: medium', 'mint', 1),
#  ('bass, striped weight: medium', 'monkfish', 1),
#  ('bass, striped weight: medium', 'mushrooms, shiitake', 1),
#  ('bass, striped weight: medium', 'mustard, dijon', 3),
#  ('bass, striped weight: medium', 'olive oil', 1),
#  ('bass, striped weight: medium', 'olives, picholine', 1),
#  ('bass, striped weight: medium', 'orange', 1),
#  ('bass, striped weight: medium', 'paprika, sweet', 1),
#  ('bass, striped weight: medium', 'parsley, flat-leaf', 1),
#  ('bass, striped weight: medium', 'potatoes', 1),
#  ('bass, striped weight: medium', 'prosciutto', 1),
#  ('bass, striped weight: medium', 'rosemary', 1),
#  ('bass, striped weight: medium', 'sage', 1),
#  ('bass, striped weight: medium', 'sauerkraut', 1),
#  ('bass, striped weight: medium', 'scallions', 1),
#  ('bass, striped weight: medium', 'sesame seeds', 1),
#  ('bass, striped weight: medium', 'shallots', 1),
#  ('bass, striped weight: medium', 'sour cream', 1),
#  ('bass, striped weight: medium', 'soy sauce', 1),
#  ('bass, striped weight: medium', 'squid', 1),
#  ('bass, striped weight: medium', 'squid ink', 1),
#  ('bass, striped weight: medium', 'tabasco sauce', 3),
#  ('bass, striped weight: medium', 'thyme, fresh', 1),
#  ('bass, striped weight: medium', 'tomatoes', 1),
#  ('bass, striped weight: medium', 'truffles, black', 1),
#  ('bass, striped weight: medium', 'walnuts', 1),
#  ('bass, striped weight: medium', 'zucchini', 1),
#  ('bay leaf', 'apples', 1),
#  ('bay leaf', 'beef', 1),
#  ('bay leaf', 'braised dishes', 1),
#  ('bay leaf', 'caramel', 1),
#  ('bay leaf', 'cauliflower', 1),
#  ('bay leaf', 'celery leaf', 1),
#  ('bay leaf', 'cheese dishes', 1),
#  ('bay leaf', 'chestnuts', 1),
#  ('bay leaf', 'chicken', 1),
#  ('bay leaf', 'corn', 1),
#  ('bay leaf', 'custards', 1),
#  ('bay leaf', 'dates', 1),
#  ('bay leaf', 'desserts', 1),
#  ('bay leaf', 'duck', 1),
#  ('bay leaf', 'figs', 1),
#  ('bay leaf', 'fish', 1),
#  ('bay leaf', 'french cuisine', 3),
#  ('bay leaf', 'game', 1),
#  ('bay leaf', 'game birds', 1),
#  ('bay leaf', 'garlic', 1),
#  ('bay leaf', 'grains', 1),
#  ('bay leaf', 'juniper berries', 1),
#  ('bay leaf', 'lamb', 1),
#  ('bay leaf', 'lemon, juice', 1),
#  ('bay leaf', 'lentils', 1),
#  ('bay leaf', 'marinades', 1),
#  ('bay leaf', 'marjoram', 1),
#  ('bay leaf', 'meats', 1),
#  ('bay leaf', 'mediterranean cuisine', 3),
#  ('bay leaf', 'mole sauce', 1),
#  ('bay leaf', 'moroccan cuisine', 3),
#  ('bay leaf', 'onions', 1),
#  ('bay leaf', 'parsley', 1),
#  ('bay leaf', 'pâté', 1),
#  ('bay leaf', 'pears', 1),
#  ('bay leaf', 'pepper, black', 1),
#  ('bay leaf', 'polenta', 1),
#  ('bay leaf', 'pork', 1),
#  ('bay leaf', 'pot roast', 1),
#  ('bay leaf', 'potatoes', 1),
#  ('bay leaf', 'poultry', 1),
#  ('bay leaf', 'prunes', 1),
#  ('bay leaf', 'pumpkin', 1),
#  ('bay leaf', 'quail', 1),
#  ('bay leaf', 'sage', 1),
#  ('bay leaf', 'salmon', 1),
#  ('bay leaf', 'sauces', 1),
#  ('bay leaf', 'sausage', 1),
#  ('bay leaf', 'savory', 1),
#  ('bay leaf', 'shellfish, shrimp', 1),
#  ('bay leaf', 'soups', 3),
#  ('bay leaf', 'spinach', 1),
#  ('bay leaf', 'stews', 3),
#  ('bay leaf', 'strawberries', 1),
#  ('bay leaf', 'swordfish', 1),
#  ('bay leaf', 'thyme', 1),
#  ('bay leaf', 'tuna', 1),
#  ('bay leaf', 'turkey', 1),
#  ('bay leaf', 'turkish cuisine', 3),
#  ('bay leaf', 'vanilla', 1),
#  ('bay leaf', 'veal', 1),
#  ('bay leaf', 'venison', 1),
#  ('bay leaf', 'vinegar', 1),
#  ('beans, black', 'apples', 1),
#  ('beans, black', 'avocado', 1),
#  ('beans, black', 'bacon', 1),
#  ('beans, black', 'bay leaf', 1),
#  ('beans, black', 'beer', 1),
#  ('beans, black', 'butter', 1),
#  ('beans, black', 'carribbean cuisine', 3),
#  ('beans, black', 'carrots', 1),
#  ('beans, black', 'cayenne', 1),
#  ('beans, black', 'celery', 1),
#  ('beans, black', 'celery root', 1),
#  ('beans, black', 'central american cuisine', 3),
#  ('beans, black', 'chili powder, ancho', 1),
#  ('beans, black', 'chives', 1),
#  ('beans, black', 'cilantro', 3),
#  ('beans, black', 'cream', 1),
#  ('beans, black', 'crème fraîche', 1),
#  ('beans, black', 'cumin', 3),
#  ('beans, black', 'duck', 1),
#  ('beans, black', 'epazote', 1),
#  ('beans, black', 'fennel seeds', 1),
#  ('beans, black', 'garlic', 3),
#  ('beans, black', 'ginger', 1),
#  ('beans, black', 'lemon', 1),
#  ('beans, black', 'lime, juice', 1),
#  ('beans, black', 'maple syrup', 1),
#  ('beans, black', 'olive oil', 1),
#  ('beans, black', 'oregano, dried', 1),
#  ('beans, black', 'parsley, flat-leaf', 3),
#  ('beans, black', 'red pepper flakes', 1),
#  ('beans, black', 'rice', 1),
#  ('beans, black', 'rosemary', 1),
#  ('beans, black', 'salsa', 1),
#  ('beans, black', 'salt pork', 1),
#  ('beans, black', 'sausage', 1),
#  ('beans, black', 'savory', 3),
#  ('beans, black', 'scallions', 1),
#  ('beans, black', 'shallots', 1),
#  ('beans, black', 'sherry', 1),
#  ('beans, black', 'shrimp', 1),
#  ('beans, black', 'soups', 1),
#  ('beans, black', 'sour cream', 3),
#  ('beans, black', 'south american cuisine', 3),
#  ('beans, black', 'southwestern cuisine', 3),
#  ('beans, black', 'spinach', 1),
#  ('beans, black', 'tabasco sauce', 3),
#  ('beans, black', 'thyme', 1),
#  ('beans, black', 'yogurt', 1),
#  ('beans, flageolet', 'bay leaf', 1),
#  ('beans, flageolet', 'butter', 1),
#  ('beans, flageolet', 'carrots', 1),
#  ('beans, flageolet', 'cassoulet', 1),
#  ('beans, flageolet', 'celery', 1),
#  ('beans, flageolet', 'cream', 1),
#  ('beans, flageolet', 'fines herbes', 1),
#  ('beans, flageolet', 'garlic', 1),
#  ('beans, flageolet', 'lamb', 5),
#  ('beans, flageolet', 'lemon, juice', 1),
#  ('beans, flageolet', 'lime', 1),
#  ('beans, flageolet', 'marjoram', 1),
#  ('beans, flageolet', 'olive oil', 1),
#  ('beans, flageolet', 'orange', 1),
#  ('beans, flageolet', 'parsley', 3),
#  ('beans, flageolet', 'pasta', 1),
#  ('beans, flageolet', 'pepper, black', 1),
#  ('beans, flageolet', 'poultry', 1),
#  ('beans, flageolet', 'salads', 1),
#  ('beans, flageolet', 'salt', 1),
#  ('beans, flageolet', 'savory', 3),
#  ('beans, flageolet', 'shallots', 1),
#  ('beans, flageolet', 'soups', 1),
#  ('beans, flageolet', 'tarragon', 1),
#  ('beans, flageolet', 'thyme', 1),
#  ('beans, flageolet', 'vinegar, red wine', 1),
#  ('beans, flageolet', 'wine, dry white', 1),
#  ('beans, green', 'anchovies', 1),
#  ('beans, green', 'bacon', 1),
#  ('beans, green', 'basil', 3),
#  ('beans, green', 'bay leaf', 1),
#  ('beans, green', 'beans, shell', 1),
#  ('beans, green', 'bell pepper, red', 1),
#  ('beans, green', 'bread crumbs', 1),
#  ...]

# %% [markdown]
# ## Storing in SQLite

# %%
# Save to database
DB_PATH = '/content/drive/MyDrive/Colab Notebooks/ingredients_recommender/ingredients.db'
conn = sqlite3.connect(DB_PATH)
c = conn.cursor()

# %%
# creating a table for the ingredients
c.execute("""
CREATE TABLE IF NOT EXISTS edges (
  id INTEGER PRIMARY KEY AUTOINCREMENT,
  ingred1 TEXT, 
  ingred2 TEXT, 
  weight INTEGER
);
""")
conn.commit()

# %%
c.execute("""
CREATE TABLE IF NOT EXISTS complex_edges (
  id INTEGER PRIMARY KEY,
  ingred TEXT, 
  key INTEGER
);
""")
conn.commit()

# %%
# Creating a table for the variable pairings
c.execute("""
CREATE TABLE IF NOT EXISTS long_pairings (
  key INTEGER PRIMARY KEY,
  ingred TEXT,  
  next_key INTEGER
);
""")
conn.commit()

# %%
c.executemany(""" INSERT INTO edges (ingred1, ingred2, weight) VALUES (?,?,?); """, two_ing_pairings)
conn.commit()

# %%
c.executemany(""" INSERT INTO complex_edges (ingred, key) VALUES (?,?); """, complex_pairings)
conn.commit()

# %%
c.executemany("""
  INSERT INTO long_pairings (key, ingred, next_key) VALUES (?,?, ?); 
  """,
  [(key, ing, nxt_key) for key, (ing, nxt_key) in variable_pairings.items()]
  )
conn.commit()

# %%
conn.close()
